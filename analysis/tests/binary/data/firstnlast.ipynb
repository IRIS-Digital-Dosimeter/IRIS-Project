# %%
import numpy as np
import os
import matplotlib.pyplot as plt

""" Extract Binary information from our files """
import struct


paths = []
# populate paths with everything in current directory
for root, dirs, files in os.walk(os.getcwd()):
    for file in files:
        if file.endswith('.dat'):
            paths.append(os.path.join(root, file))
# print(paths)


fsls = []

for path in paths:
    arrays = [[], [], [], []]  # Initialize 4 arrays
    with open(path, mode='rb') as file:
        # Read the first 3 values aka 12 bytes into the header
        header = list(struct.unpack('<3I', file.read(12)))

        while True:
            data = file.read(16)  # Reading 16 bytes at a time (4 bytes for each interval)
            if not data:  # If data is empty
                break

            # Extract values using struct.unpack
            values = struct.unpack('<4I', data)

            # Add values to respective arrays
            arrays[0].append(values[0])
            arrays[1].append(values[1])
            arrays[2].append(values[2])
            arrays[3].append(values[3])


    t1 = np.array(arrays[0]) # time before data collection 
    t2 = np.array(arrays[1]) # time after data collection 
    
    fsls.append(t1[0])
    fsls.append(t2[-1])
    
    print('-----------------------------------------------')
    print('File:', path[-10:])
    print('first time:', t1[0])
    print('last time:', t2[-1])
    print('File length (s):', round((t2[-1]-t1[0])/1e6,2))
    print('-----------------------------------------------')


print('Differences between last of one file and first of the next:')
fsls = fsls[1:-1]
for i in range(len(fsls)//2):
    diff = fsls[2*i+1] - fsls[2*i]
    print(f'{round(diff/1e3,3):,}', 'ms')
# Out:
# -----------------------------------------------
# File: 020001.dat
# first time: 2576097
# last time: 72573941
# File length (s): 70.0
# -----------------------------------------------
# -----------------------------------------------
# File: 020002.dat
# first time: 72647761
# last time: 142647949
# File length (s): 70.0
# -----------------------------------------------
# -----------------------------------------------
# File: 020003.dat
# first time: 142718636
# last time: 212718820
# File length (s): 70.0
# -----------------------------------------------
# -----------------------------------------------
# File: 020004.dat
# first time: 212789033
# last time: 282789118
# File length (s): 70.0
# -----------------------------------------------
# -----------------------------------------------
# File: 020005.dat
# first time: 282864902
# last time: 352865600
# File length (s): 70.0
# -----------------------------------------------
# -----------------------------------------------
# File: 030001.dat
# first time: 4223772
# last time: 7223877
# File length (s): 3.0
# -----------------------------------------------
# -----------------------------------------------
# File: 030002.dat
# first time: 7293965
# last time: 10294725
# File length (s): 3.0
# -----------------------------------------------
# -----------------------------------------------
# File: 030003.dat
# first time: 10364785
# last time: 13365195
# File length (s): 3.0
# -----------------------------------------------
# -----------------------------------------------
# File: 030004.dat
# first time: 13435409
# last time: 16435491
# File length (s): 3.0
# -----------------------------------------------
# -----------------------------------------------
# File: 030005.dat
# first time: 16505816
# last time: 19506470
# File length (s): 3.0
# -----------------------------------------------
# -----------------------------------------------
# File: 040001.dat
# first time: 4002160
# last time: 7004061
# File length (s): 3.0
# -----------------------------------------------
# -----------------------------------------------
# File: 040002.dat
# first time: 7070067
# last time: 10071653
# File length (s): 3.0
# -----------------------------------------------
# -----------------------------------------------
# File: 040003.dat
# first time: 10137675
# last time: 13138775
# File length (s): 3.0
# -----------------------------------------------
# -----------------------------------------------
# File: 040004.dat
# first time: 13205129
# last time: 16206055
# File length (s): 3.0
# -----------------------------------------------
# -----------------------------------------------
# File: 040005.dat
# first time: 16272654
# last time: 19273714
# File length (s): 3.0
# -----------------------------------------------
# -----------------------------------------------
# File: 050001.dat
# first time: 2676672
# last time: 72677044
# File length (s): 70.0
# -----------------------------------------------
# -----------------------------------------------
# File: 050002.dat
# first time: 72742625
# last time: 142744019
# File length (s): 70.0
# -----------------------------------------------
# -----------------------------------------------
# File: 050003.dat
# first time: 142809476
# last time: 212809782
# File length (s): 70.0
# -----------------------------------------------
# -----------------------------------------------
# File: 050004.dat
# first time: 212875795
# last time: 282876261
# File length (s): 70.0
# -----------------------------------------------
# -----------------------------------------------
# File: 050005.dat
# first time: 282941968
# last time: 352942829
# File length (s): 70.0
# -----------------------------------------------
# Differences between last of one file and first of the next:
# 73.82 ms
# 70.687 ms
# 70.213 ms
# 75.784 ms
# -348,641.828 ms
# 70.088 ms
# 70.06 ms
# 70.214 ms
# 70.325 ms
# -15,504.31 ms
# 66.006 ms
# 66.022 ms
# 66.354 ms
# 66.599 ms
# -16,597.042 ms
# 65.581 ms
# 65.457 ms
# 66.013 ms
# 65.707 ms
