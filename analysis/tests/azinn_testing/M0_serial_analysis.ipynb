# %%
import os
import pandas as pd
from analysis_plotter_serial import analyze, quickLook

directory_path = 'data_M0/50_50_4/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                              inter_sample_delay=50,
                              inter_average_delay=50,
                              samples_to_av=4, 
                              gap_sizeL_us=1100, 
                              gap_sizeS_us=800)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_50_50_4 = pd.DataFrame(all_dictionaries).transpose()
df_M0_50_50_4
# Out:
#                                                               0  \
# Filename                                   20231205_174514_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Theoretical_Frequency_KHz                                   4.0
# Sample_Frequency_KHz                                      0.009
# Large_Gap_selected_ms                                       1.1
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            843.25
# Count_of_gaps_larger_than_Large_Gap                          10
# Largest_Gaps_ms                                            1.25
# Smallest_Gap_ms                                            0.76
# Sum_of_Durations_Larger_than_Small_Gap_ms                 736.3
# Time_Length_of_File_ms                               109742.365
# Time_Length_of_File_s                                   109.742
# Dead_Time_Percentage                                      0.671
#
#                                                               1  \
# Filename                                   20231205_174515_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Theoretical_Frequency_KHz                                   4.0
# Sample_Frequency_KHz                                      0.009
# Large_Gap_selected_ms                                       1.1
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                             839.5
# Count_of_gaps_larger_than_Large_Gap                          15
# Largest_Gaps_ms                                            1.33
# Smallest_Gap_ms                                            0.76
# Sum_of_Durations_Larger_than_Small_Gap_ms                691.41
# Time_Length_of_File_ms                                110593.57
# Time_Length_of_File_s                                   110.594
# Dead_Time_Percentage                                      0.625
#
#                                                               2  \
# Filename                                   20231205_174516_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Theoretical_Frequency_KHz                                   4.0
# Sample_Frequency_KHz                                      0.009
# Large_Gap_selected_ms                                       1.1
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                             838.5
# Count_of_gaps_larger_than_Large_Gap                           5
# Largest_Gaps_ms                                            1.26
# Smallest_Gap_ms                                            0.76
# Sum_of_Durations_Larger_than_Small_Gap_ms                732.74
# Time_Length_of_File_ms                                112289.54
# Time_Length_of_File_s                                    112.29
# Dead_Time_Percentage                                      0.653
#
#                                                               3  \
# Filename                                   20231205_174517_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Theoretical_Frequency_KHz                                   4.0
# Sample_Frequency_KHz                                      0.009
# Large_Gap_selected_ms                                       1.1
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                             840.0
# Count_of_gaps_larger_than_Large_Gap                          24
# Largest_Gaps_ms                                            1.43
# Smallest_Gap_ms                                            0.76
# Sum_of_Durations_Larger_than_Small_Gap_ms                723.54
# Time_Length_of_File_ms                               113143.559
# Time_Length_of_File_s                                   113.144
# Dead_Time_Percentage                                      0.639
#
#                                                               4  \
# Filename                                   20231205_174518_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Theoretical_Frequency_KHz                                   4.0
# Sample_Frequency_KHz                                      0.009
# Large_Gap_selected_ms                                       1.1
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                             841.0
# Count_of_gaps_larger_than_Large_Gap                          17
# Largest_Gaps_ms                                            1.26
# Smallest_Gap_ms                                            0.76
# Sum_of_Durations_Larger_than_Small_Gap_ms                699.66
# Time_Length_of_File_ms                                113995.97
# Time_Length_of_File_s                                   113.996
# Dead_Time_Percentage                                      0.614
#
#                                                               5  \
# Filename                                   20231205_174519_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Theoretical_Frequency_KHz                                   4.0
# Sample_Frequency_KHz                                      0.009
# Large_Gap_selected_ms                                       1.1
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                             840.5
# Count_of_gaps_larger_than_Large_Gap                          34
# Largest_Gaps_ms                                            1.62
# Smallest_Gap_ms                                            0.77
# Sum_of_Durations_Larger_than_Small_Gap_ms                 700.2
# Time_Length_of_File_ms                               114857.329
# Time_Length_of_File_s                                   114.857
# Dead_Time_Percentage                                       0.61
#
#                                                               6  \
# Filename                                   20231205_174520_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Theoretical_Frequency_KHz                                   4.0
# Sample_Frequency_KHz                                      0.009
# Large_Gap_selected_ms                                       1.1
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                             837.5
# Count_of_gaps_larger_than_Large_Gap                          16
# Largest_Gaps_ms                                            1.25
# Smallest_Gap_ms                                            0.76
# Sum_of_Durations_Larger_than_Small_Gap_ms                678.83
# Time_Length_of_File_ms                               115703.053
# Time_Length_of_File_s                                   115.703
# Dead_Time_Percentage                                      0.587
#
#                                                               7  \
# Filename                                   20231205_174521_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Theoretical_Frequency_KHz                                   4.0
# Sample_Frequency_KHz                                      0.009
# Large_Gap_selected_ms                                       1.1
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                             832.5
# Count_of_gaps_larger_than_Large_Gap                           1
# Largest_Gaps_ms                                            1.15
# Smallest_Gap_ms                                            0.77
# Sum_of_Durations_Larger_than_Small_Gap_ms                660.28
# Time_Length_of_File_ms                               117389.068
# Time_Length_of_File_s                                   117.389
# Dead_Time_Percentage                                      0.562
#
#                                                               8
# Filename                                   20231205_174522_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Theoretical_Frequency_KHz                                   4.0
# Sample_Frequency_KHz                                      0.003
# Large_Gap_selected_ms                                       1.1
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                             840.0
# Count_of_gaps_larger_than_Large_Gap                           8
# Largest_Gaps_ms                                            1.32
# Smallest_Gap_ms                                            0.77
# Sum_of_Durations_Larger_than_Small_Gap_ms                276.88
# Time_Length_of_File_ms                               117734.378
# Time_Length_of_File_s                                   117.734
# Dead_Time_Percentage                                      0.235

# %%
import os
import pandas as pd
from analysis_plotter_serial import analyze, quickLook

directory_path = 'data_M0/50_500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                              inter_sample_delay=50,
                              inter_average_delay=500,
                              samples_to_av=20, 
                              gap_sizeL_us=3000, 
                              gap_sizeS_us=3000)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_50_500_20 = pd.DataFrame(all_dictionaries).transpose()
df_M0_50_500_20
# Out:
#                                                               0  \
# Filename                                   20231205_174832_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                         500
# Theoretical_Frequency_KHz                                 0.667
# Sample_Frequency_KHz                                      0.021
# Large_Gap_selected_ms                                       3.0
# Small_Gap_selected_ms                                       3.0
# Median_Gap_us                                            3037.0
# Count_of_gaps_larger_than_Large_Gap                         588
# Largest_Gaps_ms                                            3.79
# Smallest_Gap_ms                                            2.74
# Sum_of_Durations_Larger_than_Small_Gap_ms               1864.24
# Time_Length_of_File_ms                                46727.068
# Time_Length_of_File_s                                    46.727
# Dead_Time_Percentage                                       3.99
#
#                                                               1  \
# Filename                                   20231205_174835_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                         500
# Theoretical_Frequency_KHz                                 0.667
# Sample_Frequency_KHz                                       0.02
# Large_Gap_selected_ms                                       3.0
# Small_Gap_selected_ms                                       3.0
# Median_Gap_us                                            3085.5
# Count_of_gaps_larger_than_Large_Gap                         653
# Largest_Gaps_ms                                            3.66
# Smallest_Gap_ms                                            2.77
# Sum_of_Durations_Larger_than_Small_Gap_ms               2086.07
# Time_Length_of_File_ms                                49820.302
# Time_Length_of_File_s                                     49.82
# Dead_Time_Percentage                                      4.187
#
#                                                               2  \
# Filename                                   20231205_174838_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                         500
# Theoretical_Frequency_KHz                                 0.667
# Sample_Frequency_KHz                                      0.019
# Large_Gap_selected_ms                                       3.0
# Small_Gap_selected_ms                                       3.0
# Median_Gap_us                                            3091.5
# Count_of_gaps_larger_than_Large_Gap                         698
# Largest_Gaps_ms                                             3.7
# Smallest_Gap_ms                                            2.74
# Sum_of_Durations_Larger_than_Small_Gap_ms               2221.73
# Time_Length_of_File_ms                                52919.226
# Time_Length_of_File_s                                    52.919
# Dead_Time_Percentage                                      4.198
#
#                                                               3  \
# Filename                                   20231205_174842_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                         500
# Theoretical_Frequency_KHz                                 0.667
# Sample_Frequency_KHz                                      0.018
# Large_Gap_selected_ms                                       3.0
# Small_Gap_selected_ms                                       3.0
# Median_Gap_us                                            3101.0
# Count_of_gaps_larger_than_Large_Gap                         670
# Largest_Gaps_ms                                            3.67
# Smallest_Gap_ms                                            2.72
# Sum_of_Durations_Larger_than_Small_Gap_ms               2141.77
# Time_Length_of_File_ms                                56009.542
# Time_Length_of_File_s                                     56.01
# Dead_Time_Percentage                                      3.824
#
#                                                               4  \
# Filename                                   20231205_174845_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                         500
# Theoretical_Frequency_KHz                                 0.667
# Sample_Frequency_KHz                                      0.017
# Large_Gap_selected_ms                                       3.0
# Small_Gap_selected_ms                                       3.0
# Median_Gap_us                                            3080.5
# Count_of_gaps_larger_than_Large_Gap                         640
# Largest_Gaps_ms                                            3.78
# Smallest_Gap_ms                                            2.73
# Sum_of_Durations_Larger_than_Small_Gap_ms               2041.77
# Time_Length_of_File_ms                                59091.334
# Time_Length_of_File_s                                    59.091
# Dead_Time_Percentage                                      3.455
#
#                                                               5  \
# Filename                                   20231205_174848_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                         500
# Theoretical_Frequency_KHz                                 0.667
# Sample_Frequency_KHz                                      0.016
# Large_Gap_selected_ms                                       3.0
# Small_Gap_selected_ms                                       3.0
# Median_Gap_us                                            3101.0
# Count_of_gaps_larger_than_Large_Gap                         675
# Largest_Gaps_ms                                            3.62
# Smallest_Gap_ms                                            2.72
# Sum_of_Durations_Larger_than_Small_Gap_ms               2161.45
# Time_Length_of_File_ms                                62190.999
# Time_Length_of_File_s                                    62.191
# Dead_Time_Percentage                                      3.476
#
#                                                               6  \
# Filename                                   20231205_174851_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                         500
# Theoretical_Frequency_KHz                                 0.667
# Sample_Frequency_KHz                                      0.015
# Large_Gap_selected_ms                                       3.0
# Small_Gap_selected_ms                                       3.0
# Median_Gap_us                                            3105.5
# Count_of_gaps_larger_than_Large_Gap                         674
# Largest_Gaps_ms                                            3.67
# Smallest_Gap_ms                                            2.74
# Sum_of_Durations_Larger_than_Small_Gap_ms                2166.3
# Time_Length_of_File_ms                                 65299.86
# Time_Length_of_File_s                                      65.3
# Dead_Time_Percentage                                      3.317
#
#                                                               7
# Filename                                   20231205_174854_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                         500
# Theoretical_Frequency_KHz                                 0.667
# Sample_Frequency_KHz                                      0.012
# Large_Gap_selected_ms                                       3.0
# Small_Gap_selected_ms                                       3.0
# Median_Gap_us                                            3120.0
# Count_of_gaps_larger_than_Large_Gap                         567
# Largest_Gaps_ms                                            3.68
# Smallest_Gap_ms                                            2.77
# Sum_of_Durations_Larger_than_Small_Gap_ms               1817.94
# Time_Length_of_File_ms                                67766.085
# Time_Length_of_File_s                                    67.766
# Dead_Time_Percentage                                      2.683

# %%
import os
import pandas as pd
from analysis_plotter_serial import analyze, quickLook

directory_path = 'data_M0/50_1500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                              inter_sample_delay=50,
                              inter_average_delay=1500,
                              samples_to_av=20, 
                              gap_sizeL_us=4500, 
                              gap_sizeS_us=4000)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_50_1500_20 = pd.DataFrame(all_dictionaries).transpose()
df_M0_50_1500_20
# Out:
#                                                               0  \
# Filename                                   20231205_174211_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.002
# Large_Gap_selected_ms                                       4.5
# Small_Gap_selected_ms                                       4.0
# Median_Gap_us                                            4164.0
# Count_of_gaps_larger_than_Large_Gap                          38
# Largest_Gaps_ms                                            4.78
# Smallest_Gap_ms                                            3.77
# Sum_of_Durations_Larger_than_Small_Gap_ms               3388.71
# Time_Length_of_File_ms                               534277.592
# Time_Length_of_File_s                                   534.278
# Dead_Time_Percentage                                      0.634
#
#                                                               1  \
# Filename                                   20231205_174215_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.002
# Large_Gap_selected_ms                                       4.5
# Small_Gap_selected_ms                                       4.0
# Median_Gap_us                                            4166.0
# Count_of_gaps_larger_than_Large_Gap                          53
# Largest_Gaps_ms                                            4.75
# Smallest_Gap_ms                                            3.75
# Sum_of_Durations_Larger_than_Small_Gap_ms                3237.9
# Time_Length_of_File_ms                               538444.228
# Time_Length_of_File_s                                   538.444
# Dead_Time_Percentage                                      0.601
#
#                                                               2  \
# Filename                                   20231205_174219_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.002
# Large_Gap_selected_ms                                       4.5
# Small_Gap_selected_ms                                       4.0
# Median_Gap_us                                            4154.5
# Count_of_gaps_larger_than_Large_Gap                          37
# Largest_Gaps_ms                                            4.72
# Smallest_Gap_ms                                            3.74
# Sum_of_Durations_Larger_than_Small_Gap_ms               3294.73
# Time_Length_of_File_ms                               542600.663
# Time_Length_of_File_s                                   542.601
# Dead_Time_Percentage                                      0.607
#
#                                                               3  \
# Filename                                   20231205_174224_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.002
# Large_Gap_selected_ms                                       4.5
# Small_Gap_selected_ms                                       4.0
# Median_Gap_us                                            4171.5
# Count_of_gaps_larger_than_Large_Gap                          40
# Largest_Gaps_ms                                            4.73
# Smallest_Gap_ms                                            3.75
# Sum_of_Durations_Larger_than_Small_Gap_ms               3333.25
# Time_Length_of_File_ms                               546767.444
# Time_Length_of_File_s                                   546.767
# Dead_Time_Percentage                                       0.61
#
#                                                               4
# Filename                                   20231205_174228_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.001
# Large_Gap_selected_ms                                       4.5
# Small_Gap_selected_ms                                       4.0
# Median_Gap_us                                           4161.75
# Count_of_gaps_larger_than_Large_Gap                          27
# Largest_Gaps_ms                                            4.63
# Smallest_Gap_ms                                            3.76
# Sum_of_Durations_Larger_than_Small_Gap_ms               2240.61
# Time_Length_of_File_ms                               549659.172
# Time_Length_of_File_s                                   549.659
# Dead_Time_Percentage                                      0.408

# %%
result = pd.concat([df_M0_50_50_4,df_M0_50_500_20,df_M0_50_1500_20], axis=1, ignore_index=True)

result
# Out:
#                                                              0   \
# Filename                                   20231205_174514_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Theoretical_Frequency_KHz                                   4.0
# Sample_Frequency_KHz                                      0.009
# Large_Gap_selected_ms                                       1.1
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            843.25
# Count_of_gaps_larger_than_Large_Gap                          10
# Largest_Gaps_ms                                            1.25
# Smallest_Gap_ms                                            0.76
# Sum_of_Durations_Larger_than_Small_Gap_ms                 736.3
# Time_Length_of_File_ms                               109742.365
# Time_Length_of_File_s                                   109.742
# Dead_Time_Percentage                                      0.671
#
#                                                              1   \
# Filename                                   20231205_174515_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Theoretical_Frequency_KHz                                   4.0
# Sample_Frequency_KHz                                      0.009
# Large_Gap_selected_ms                                       1.1
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                             839.5
# Count_of_gaps_larger_than_Large_Gap                          15
# Largest_Gaps_ms                                            1.33
# Smallest_Gap_ms                                            0.76
# Sum_of_Durations_Larger_than_Small_Gap_ms                691.41
# Time_Length_of_File_ms                                110593.57
# Time_Length_of_File_s                                   110.594
# Dead_Time_Percentage                                      0.625
#
#                                                              2   \
# Filename                                   20231205_174516_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Theoretical_Frequency_KHz                                   4.0
# Sample_Frequency_KHz                                      0.009
# Large_Gap_selected_ms                                       1.1
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                             838.5
# Count_of_gaps_larger_than_Large_Gap                           5
# Largest_Gaps_ms                                            1.26
# Smallest_Gap_ms                                            0.76
# Sum_of_Durations_Larger_than_Small_Gap_ms                732.74
# Time_Length_of_File_ms                                112289.54
# Time_Length_of_File_s                                    112.29
# Dead_Time_Percentage                                      0.653
#
#                                                              3   \
# Filename                                   20231205_174517_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Theoretical_Frequency_KHz                                   4.0
# Sample_Frequency_KHz                                      0.009
# Large_Gap_selected_ms                                       1.1
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                             840.0
# Count_of_gaps_larger_than_Large_Gap                          24
# Largest_Gaps_ms                                            1.43
# Smallest_Gap_ms                                            0.76
# Sum_of_Durations_Larger_than_Small_Gap_ms                723.54
# Time_Length_of_File_ms                               113143.559
# Time_Length_of_File_s                                   113.144
# Dead_Time_Percentage                                      0.639
#
#                                                              4   \
# Filename                                   20231205_174518_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Theoretical_Frequency_KHz                                   4.0
# Sample_Frequency_KHz                                      0.009
# Large_Gap_selected_ms                                       1.1
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                             841.0
# Count_of_gaps_larger_than_Large_Gap                          17
# Largest_Gaps_ms                                            1.26
# Smallest_Gap_ms                                            0.76
# Sum_of_Durations_Larger_than_Small_Gap_ms                699.66
# Time_Length_of_File_ms                                113995.97
# Time_Length_of_File_s                                   113.996
# Dead_Time_Percentage                                      0.614
#
#                                                              5   \
# Filename                                   20231205_174519_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Theoretical_Frequency_KHz                                   4.0
# Sample_Frequency_KHz                                      0.009
# Large_Gap_selected_ms                                       1.1
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                             840.5
# Count_of_gaps_larger_than_Large_Gap                          34
# Largest_Gaps_ms                                            1.62
# Smallest_Gap_ms                                            0.77
# Sum_of_Durations_Larger_than_Small_Gap_ms                 700.2
# Time_Length_of_File_ms                               114857.329
# Time_Length_of_File_s                                   114.857
# Dead_Time_Percentage                                       0.61
#
#                                                              6   \
# Filename                                   20231205_174520_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Theoretical_Frequency_KHz                                   4.0
# Sample_Frequency_KHz                                      0.009
# Large_Gap_selected_ms                                       1.1
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                             837.5
# Count_of_gaps_larger_than_Large_Gap                          16
# Largest_Gaps_ms                                            1.25
# Smallest_Gap_ms                                            0.76
# Sum_of_Durations_Larger_than_Small_Gap_ms                678.83
# Time_Length_of_File_ms                               115703.053
# Time_Length_of_File_s                                   115.703
# Dead_Time_Percentage                                      0.587
#
#                                                              7   \
# Filename                                   20231205_174521_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Theoretical_Frequency_KHz                                   4.0
# Sample_Frequency_KHz                                      0.009
# Large_Gap_selected_ms                                       1.1
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                             832.5
# Count_of_gaps_larger_than_Large_Gap                           1
# Largest_Gaps_ms                                            1.15
# Smallest_Gap_ms                                            0.77
# Sum_of_Durations_Larger_than_Small_Gap_ms                660.28
# Time_Length_of_File_ms                               117389.068
# Time_Length_of_File_s                                   117.389
# Dead_Time_Percentage                                      0.562
#
#                                                              8   \
# Filename                                   20231205_174522_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Theoretical_Frequency_KHz                                   4.0
# Sample_Frequency_KHz                                      0.003
# Large_Gap_selected_ms                                       1.1
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                             840.0
# Count_of_gaps_larger_than_Large_Gap                           8
# Largest_Gaps_ms                                            1.32
# Smallest_Gap_ms                                            0.77
# Sum_of_Durations_Larger_than_Small_Gap_ms                276.88
# Time_Length_of_File_ms                               117734.378
# Time_Length_of_File_s                                   117.734
# Dead_Time_Percentage                                      0.235
#
#                                                              9   ...  \
# Filename                                   20231205_174832_.txt  ...
# Samples_Averaged                                             20  ...
# Inter_Sample_delay                                           50  ...
# Inter_Average_delay                                         500  ...
# Theoretical_Frequency_KHz                                 0.667  ...
# Sample_Frequency_KHz                                      0.021  ...
# Large_Gap_selected_ms                                       3.0  ...
# Small_Gap_selected_ms                                       3.0  ...
# Median_Gap_us                                            3037.0  ...
# Count_of_gaps_larger_than_Large_Gap                         588  ...
# Largest_Gaps_ms                                            3.79  ...
# Smallest_Gap_ms                                            2.74  ...
# Sum_of_Durations_Larger_than_Small_Gap_ms               1864.24  ...
# Time_Length_of_File_ms                                46727.068  ...
# Time_Length_of_File_s                                    46.727  ...
# Dead_Time_Percentage                                       3.99  ...
#
#                                                              12  \
# Filename                                   20231205_174842_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                         500
# Theoretical_Frequency_KHz                                 0.667
# Sample_Frequency_KHz                                      0.018
# Large_Gap_selected_ms                                       3.0
# Small_Gap_selected_ms                                       3.0
# Median_Gap_us                                            3101.0
# Count_of_gaps_larger_than_Large_Gap                         670
# Largest_Gaps_ms                                            3.67
# Smallest_Gap_ms                                            2.72
# Sum_of_Durations_Larger_than_Small_Gap_ms               2141.77
# Time_Length_of_File_ms                                56009.542
# Time_Length_of_File_s                                     56.01
# Dead_Time_Percentage                                      3.824
#
#                                                              13  \
# Filename                                   20231205_174845_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                         500
# Theoretical_Frequency_KHz                                 0.667
# Sample_Frequency_KHz                                      0.017
# Large_Gap_selected_ms                                       3.0
# Small_Gap_selected_ms                                       3.0
# Median_Gap_us                                            3080.5
# Count_of_gaps_larger_than_Large_Gap                         640
# Largest_Gaps_ms                                            3.78
# Smallest_Gap_ms                                            2.73
# Sum_of_Durations_Larger_than_Small_Gap_ms               2041.77
# Time_Length_of_File_ms                                59091.334
# Time_Length_of_File_s                                    59.091
# Dead_Time_Percentage                                      3.455
#
#                                                              14  \
# Filename                                   20231205_174848_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                         500
# Theoretical_Frequency_KHz                                 0.667
# Sample_Frequency_KHz                                      0.016
# Large_Gap_selected_ms                                       3.0
# Small_Gap_selected_ms                                       3.0
# Median_Gap_us                                            3101.0
# Count_of_gaps_larger_than_Large_Gap                         675
# Largest_Gaps_ms                                            3.62
# Smallest_Gap_ms                                            2.72
# Sum_of_Durations_Larger_than_Small_Gap_ms               2161.45
# Time_Length_of_File_ms                                62190.999
# Time_Length_of_File_s                                    62.191
# Dead_Time_Percentage                                      3.476
#
#                                                              15  \
# Filename                                   20231205_174851_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                         500
# Theoretical_Frequency_KHz                                 0.667
# Sample_Frequency_KHz                                      0.015
# Large_Gap_selected_ms                                       3.0
# Small_Gap_selected_ms                                       3.0
# Median_Gap_us                                            3105.5
# Count_of_gaps_larger_than_Large_Gap                         674
# Largest_Gaps_ms                                            3.67
# Smallest_Gap_ms                                            2.74
# Sum_of_Durations_Larger_than_Small_Gap_ms                2166.3
# Time_Length_of_File_ms                                 65299.86
# Time_Length_of_File_s                                      65.3
# Dead_Time_Percentage                                      3.317
#
#                                                              16  \
# Filename                                   20231205_174854_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                         500
# Theoretical_Frequency_KHz                                 0.667
# Sample_Frequency_KHz                                      0.012
# Large_Gap_selected_ms                                       3.0
# Small_Gap_selected_ms                                       3.0
# Median_Gap_us                                            3120.0
# Count_of_gaps_larger_than_Large_Gap                         567
# Largest_Gaps_ms                                            3.68
# Smallest_Gap_ms                                            2.77
# Sum_of_Durations_Larger_than_Small_Gap_ms               1817.94
# Time_Length_of_File_ms                                67766.085
# Time_Length_of_File_s                                    67.766
# Dead_Time_Percentage                                      2.683
#
#                                                              17  \
# Filename                                   20231205_174211_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.002
# Large_Gap_selected_ms                                       4.5
# Small_Gap_selected_ms                                       4.0
# Median_Gap_us                                            4164.0
# Count_of_gaps_larger_than_Large_Gap                          38
# Largest_Gaps_ms                                            4.78
# Smallest_Gap_ms                                            3.77
# Sum_of_Durations_Larger_than_Small_Gap_ms               3388.71
# Time_Length_of_File_ms                               534277.592
# Time_Length_of_File_s                                   534.278
# Dead_Time_Percentage                                      0.634
#
#                                                              18  \
# Filename                                   20231205_174215_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.002
# Large_Gap_selected_ms                                       4.5
# Small_Gap_selected_ms                                       4.0
# Median_Gap_us                                            4166.0
# Count_of_gaps_larger_than_Large_Gap                          53
# Largest_Gaps_ms                                            4.75
# Smallest_Gap_ms                                            3.75
# Sum_of_Durations_Larger_than_Small_Gap_ms                3237.9
# Time_Length_of_File_ms                               538444.228
# Time_Length_of_File_s                                   538.444
# Dead_Time_Percentage                                      0.601
#
#                                                              19  \
# Filename                                   20231205_174219_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.002
# Large_Gap_selected_ms                                       4.5
# Small_Gap_selected_ms                                       4.0
# Median_Gap_us                                            4154.5
# Count_of_gaps_larger_than_Large_Gap                          37
# Largest_Gaps_ms                                            4.72
# Smallest_Gap_ms                                            3.74
# Sum_of_Durations_Larger_than_Small_Gap_ms               3294.73
# Time_Length_of_File_ms                               542600.663
# Time_Length_of_File_s                                   542.601
# Dead_Time_Percentage                                      0.607
#
#                                                              20  \
# Filename                                   20231205_174224_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.002
# Large_Gap_selected_ms                                       4.5
# Small_Gap_selected_ms                                       4.0
# Median_Gap_us                                            4171.5
# Count_of_gaps_larger_than_Large_Gap                          40
# Largest_Gaps_ms                                            4.73
# Smallest_Gap_ms                                            3.75
# Sum_of_Durations_Larger_than_Small_Gap_ms               3333.25
# Time_Length_of_File_ms                               546767.444
# Time_Length_of_File_s                                   546.767
# Dead_Time_Percentage                                       0.61
#
#                                                              21
# Filename                                   20231205_174228_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.001
# Large_Gap_selected_ms                                       4.5
# Small_Gap_selected_ms                                       4.0
# Median_Gap_us                                           4161.75
# Count_of_gaps_larger_than_Large_Gap                          27
# Largest_Gaps_ms                                            4.63
# Smallest_Gap_ms                                            3.76
# Sum_of_Durations_Larger_than_Small_Gap_ms               2240.61
# Time_Length_of_File_ms                               549659.172
# Time_Length_of_File_s                                   549.659
# Dead_Time_Percentage                                      0.408
#
# [16 rows x 22 columns]
