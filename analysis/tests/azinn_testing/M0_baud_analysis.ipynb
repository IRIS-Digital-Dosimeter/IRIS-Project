# %%
import os
import pandas as pd
from analysis_plotter_serial import analyze, quickLook

directory_path = 'data_M0_baud/230400/50_1500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                              inter_sample_delay=50,
                              inter_average_delay=1500,
                              samples_to_av=20, 
                              gap_sizeL_us=500, 
                              gap_sizeS_us=800)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_230400 = pd.DataFrame(all_dictionaries).transpose()
df_M0_230400

# 1.5 ms gap & tgf started in the gap causes an issue
# inter sample = 100 us
# 2 ms over which collect 
# inter av = 500 us 
# 20 samples
# Out:
#                                                               0  \
# Filename                                   20231210_155736_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.006
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1354.0
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                            2.67
# Smallest_Gap_ms                                             1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms               1426.81
# Time_Length_of_File_ms                                177652.92
# Time_Length_of_File_s                                   177.653
# Dead_Time_Percentage                                      0.803
#
#                                                               1  \
# Filename                                   20231210_155737_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.006
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1342.0
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                            2.56
# Smallest_Gap_ms                                            1.19
# Sum_of_Durations_Larger_than_Small_Gap_ms               1430.91
# Time_Length_of_File_ms                               179085.061
# Time_Length_of_File_s                                   179.085
# Dead_Time_Percentage                                      0.799
#
#                                                               2  \
# Filename                                   20231210_155739_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.006
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1509.0
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                            2.77
# Smallest_Gap_ms                                             1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms               1579.79
# Time_Length_of_File_ms                               180666.078
# Time_Length_of_File_s                                   180.666
# Dead_Time_Percentage                                      0.874
#
#                                                               3  \
# Filename                                   20231210_155740_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.005
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1564.0
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                            2.77
# Smallest_Gap_ms                                             1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms               1630.54
# Time_Length_of_File_ms                               182298.408
# Time_Length_of_File_s                                   182.298
# Dead_Time_Percentage                                      0.894
#
#                                                               4  \
# Filename                                   20231210_155742_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.005
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1491.5
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                            2.71
# Smallest_Gap_ms                                            1.19
# Sum_of_Durations_Larger_than_Small_Gap_ms               1561.64
# Time_Length_of_File_ms                                183861.81
# Time_Length_of_File_s                                   183.862
# Dead_Time_Percentage                                      0.849
#
#                                                               5  \
# Filename                                   20231210_155743_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.005
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1610.5
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                            2.73
# Smallest_Gap_ms                                             1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms                1653.8
# Time_Length_of_File_ms                               185517.374
# Time_Length_of_File_s                                   185.517
# Dead_Time_Percentage                                      0.891
#
#                                                               6
# Filename                                   20231210_155745_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.005
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1554.5
# Count_of_gaps_larger_than_Large_Gap                         904
# Largest_Gaps_ms                                            2.78
# Smallest_Gap_ms                                             1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms               1459.64
# Time_Length_of_File_ms                               186979.012
# Time_Length_of_File_s                                   186.979
# Dead_Time_Percentage                                      0.781

# %%
import os
import pandas as pd
from analysis_plotter_serial import analyze, quickLook

directory_path = 'data_M0_baud/250_000/50_1500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                              inter_sample_delay=50,
                              inter_average_delay=1500,
                              samples_to_av=20, 
                              gap_sizeL_us=2500, 
                              gap_sizeS_us=1600)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_250_000 = pd.DataFrame(all_dictionaries).transpose()
df_M0_250_000

# 1.5 ms gap & tgf started in the gap causes an issue
# inter sample = 100 us
# 2 ms over which collect 
# inter av = 500 us 
# 20 samples
# Out:
#                                                               0  \
# Filename                                   20231210_160909_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.072
# Large_Gap_selected_ms                                       2.5
# Small_Gap_selected_ms                                       1.6
# Median_Gap_us                                            1533.0
# Count_of_gaps_larger_than_Large_Gap                          15
# Largest_Gaps_ms                                            2.77
# Smallest_Gap_ms                                             1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms                758.37
# Time_Length_of_File_ms                                 13787.15
# Time_Length_of_File_s                                    13.787
# Dead_Time_Percentage                                      5.501
#
#                                                               1  \
# Filename                                   20231210_160910_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.065
# Large_Gap_selected_ms                                       2.5
# Small_Gap_selected_ms                                       1.6
# Median_Gap_us                                            1532.0
# Count_of_gaps_larger_than_Large_Gap                          21
# Largest_Gaps_ms                                            2.66
# Smallest_Gap_ms                                             1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms                826.58
# Time_Length_of_File_ms                                15400.926
# Time_Length_of_File_s                                    15.401
# Dead_Time_Percentage                                      5.367
#
#                                                               2  \
# Filename                                   20231210_160912_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.059
# Large_Gap_selected_ms                                       2.5
# Small_Gap_selected_ms                                       1.6
# Median_Gap_us                                            1511.0
# Count_of_gaps_larger_than_Large_Gap                          13
# Largest_Gaps_ms                                            2.69
# Smallest_Gap_ms                                             1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms                749.42
# Time_Length_of_File_ms                                16988.878
# Time_Length_of_File_s                                    16.989
# Dead_Time_Percentage                                      4.411
#
#                                                               3  \
# Filename                                   20231210_160913_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.054
# Large_Gap_selected_ms                                       2.5
# Small_Gap_selected_ms                                       1.6
# Median_Gap_us                                            1537.0
# Count_of_gaps_larger_than_Large_Gap                          32
# Largest_Gaps_ms                                            2.84
# Smallest_Gap_ms                                             1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms                881.81
# Time_Length_of_File_ms                                 18630.91
# Time_Length_of_File_s                                    18.631
# Dead_Time_Percentage                                      4.733
#
#                                                               4  \
# Filename                                   20231210_160915_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.049
# Large_Gap_selected_ms                                       2.5
# Small_Gap_selected_ms                                       1.6
# Median_Gap_us                                            1590.5
# Count_of_gaps_larger_than_Large_Gap                          26
# Largest_Gaps_ms                                            2.87
# Smallest_Gap_ms                                            1.19
# Sum_of_Durations_Larger_than_Small_Gap_ms                961.39
# Time_Length_of_File_ms                                20301.408
# Time_Length_of_File_s                                    20.301
# Dead_Time_Percentage                                      4.736
#
#                                                               5  \
# Filename                                   20231210_160917_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.046
# Large_Gap_selected_ms                                       2.5
# Small_Gap_selected_ms                                       1.6
# Median_Gap_us                                            1401.0
# Count_of_gaps_larger_than_Large_Gap                          41
# Largest_Gaps_ms                                            2.82
# Smallest_Gap_ms                                             1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms                581.58
# Time_Length_of_File_ms                                21835.365
# Time_Length_of_File_s                                    21.835
# Dead_Time_Percentage                                      2.663
#
#                                                               6  \
# Filename                                   20231210_160918_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.043
# Large_Gap_selected_ms                                       2.5
# Small_Gap_selected_ms                                       1.6
# Median_Gap_us                                            1514.5
# Count_of_gaps_larger_than_Large_Gap                          20
# Largest_Gaps_ms                                            2.82
# Smallest_Gap_ms                                            1.19
# Sum_of_Durations_Larger_than_Small_Gap_ms                796.23
# Time_Length_of_File_ms                                23455.646
# Time_Length_of_File_s                                    23.456
# Dead_Time_Percentage                                      3.395
#
#                                                               7
# Filename                                   20231210_160920_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.026
# Large_Gap_selected_ms                                       2.5
# Small_Gap_selected_ms                                       1.6
# Median_Gap_us                                           1569.75
# Count_of_gaps_larger_than_Large_Gap                          25
# Largest_Gaps_ms                                            2.82
# Smallest_Gap_ms                                            1.21
# Sum_of_Durations_Larger_than_Small_Gap_ms                608.63
# Time_Length_of_File_ms                                24545.972
# Time_Length_of_File_s                                    24.546
# Dead_Time_Percentage                                       2.48

# %%
directory_path = 'data_M0_baud/115200/50_1500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                              inter_sample_delay=50,
                              inter_average_delay=1500,
                              samples_to_av=20, 
                              gap_sizeL_us=500, 
                              gap_sizeS_us=800)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_115200 = pd.DataFrame(all_dictionaries).transpose()
df_M0_115200
# Out:
#                                                               0  \
# Filename                                   20231210_155312_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.092
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                           1310.25
# Count_of_gaps_larger_than_Large_Gap                         998
# Largest_Gaps_ms                                            2.69
# Smallest_Gap_ms                                            1.19
# Sum_of_Durations_Larger_than_Small_Gap_ms               1409.13
# Time_Length_of_File_ms                                10827.262
# Time_Length_of_File_s                                    10.827
# Dead_Time_Percentage                                     13.015
#
#                                                               1  \
# Filename                                   20231210_155313_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.082
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1307.5
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                            2.69
# Smallest_Gap_ms                                            1.19
# Sum_of_Durations_Larger_than_Small_Gap_ms               1381.51
# Time_Length_of_File_ms                                12210.256
# Time_Length_of_File_s                                     12.21
# Dead_Time_Percentage                                     11.314
#
#                                                               2  \
# Filename                                   20231210_155315_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.073
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1381.5
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                            2.63
# Smallest_Gap_ms                                            1.19
# Sum_of_Durations_Larger_than_Small_Gap_ms               1395.77
# Time_Length_of_File_ms                                13607.261
# Time_Length_of_File_s                                    13.607
# Dead_Time_Percentage                                     10.258
#
#                                                               3  \
# Filename                                   20231210_155316_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.066
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1490.5
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                            2.81
# Smallest_Gap_ms                                            1.19
# Sum_of_Durations_Larger_than_Small_Gap_ms               1546.84
# Time_Length_of_File_ms                                15155.478
# Time_Length_of_File_s                                    15.155
# Dead_Time_Percentage                                     10.206
#
#                                                               4  \
# Filename                                   20231210_155318_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                       0.06
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1501.0
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                             2.8
# Smallest_Gap_ms                                            1.19
# Sum_of_Durations_Larger_than_Small_Gap_ms                1607.7
# Time_Length_of_File_ms                                16764.467
# Time_Length_of_File_s                                    16.764
# Dead_Time_Percentage                                       9.59
#
#                                                               5
# Filename                                   20231210_155319_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.039
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1397.5
# Count_of_gaps_larger_than_Large_Gap                         689
# Largest_Gaps_ms                                            2.78
# Smallest_Gap_ms                                            1.19
# Sum_of_Durations_Larger_than_Small_Gap_ms               1041.46
# Time_Length_of_File_ms                                17807.748
# Time_Length_of_File_s                                    17.808
# Dead_Time_Percentage                                      5.848

# %%
import os
import pandas as pd
from analysis_plotter_serial import analyze, quickLook

directory_path = 'data_M0_baud/460800/50_1500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                              inter_sample_delay=50,
                              inter_average_delay=1500,
                              samples_to_av=20, 
                              gap_sizeL_us=500, 
                              gap_sizeS_us=800)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_460800 = pd.DataFrame(all_dictionaries).transpose()
df_M0_460800

# 1.5 ms gap & tgf started in the gap causes an issue
# inter sample = 100 us
# 2 ms over which collect 
# inter av = 500 us 
# 20 samples
# Out:
#                                                               0  \
# Filename                                   20231210_161126_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.013
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1521.0
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                            2.75
# Smallest_Gap_ms                                            1.19
# Sum_of_Durations_Larger_than_Small_Gap_ms               1552.43
# Time_Length_of_File_ms                                74790.154
# Time_Length_of_File_s                                     74.79
# Dead_Time_Percentage                                      2.076
#
#                                                               1  \
# Filename                                   20231210_161127_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.013
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1530.0
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                            2.79
# Smallest_Gap_ms                                             1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms               1627.38
# Time_Length_of_File_ms                                76419.229
# Time_Length_of_File_s                                    76.419
# Dead_Time_Percentage                                       2.13
#
#                                                               2  \
# Filename                                   20231210_161129_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.013
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1622.0
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                            2.84
# Smallest_Gap_ms                                             1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms               1655.47
# Time_Length_of_File_ms                                78076.448
# Time_Length_of_File_s                                    78.076
# Dead_Time_Percentage                                       2.12
#
#                                                               3  \
# Filename                                   20231210_161130_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.013
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1519.5
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                            2.85
# Smallest_Gap_ms                                            1.19
# Sum_of_Durations_Larger_than_Small_Gap_ms                1564.0
# Time_Length_of_File_ms                                79641.858
# Time_Length_of_File_s                                    79.642
# Dead_Time_Percentage                                      1.964
#
#                                                               4  \
# Filename                                   20231210_161132_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.012
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1519.0
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                             2.8
# Smallest_Gap_ms                                            1.19
# Sum_of_Durations_Larger_than_Small_Gap_ms               1591.33
# Time_Length_of_File_ms                                81234.508
# Time_Length_of_File_s                                    81.235
# Dead_Time_Percentage                                      1.959
#
#                                                               5  \
# Filename                                   20231210_161134_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.012
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1524.5
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                            2.69
# Smallest_Gap_ms                                            1.21
# Sum_of_Durations_Larger_than_Small_Gap_ms               1566.33
# Time_Length_of_File_ms                                 82802.46
# Time_Length_of_File_s                                    82.802
# Dead_Time_Percentage                                      1.892
#
#                                                               6  \
# Filename                                   20231210_161135_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.012
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1453.0
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                            2.79
# Smallest_Gap_ms                                             1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms               1539.54
# Time_Length_of_File_ms                                  84343.6
# Time_Length_of_File_s                                    84.344
# Dead_Time_Percentage                                      1.825
#
#                                                               7  \
# Filename                                   20231210_161137_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.012
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1568.5
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                            2.79
# Smallest_Gap_ms                                            1.19
# Sum_of_Durations_Larger_than_Small_Gap_ms               1615.14
# Time_Length_of_File_ms                                85961.229
# Time_Length_of_File_s                                    85.961
# Dead_Time_Percentage                                      1.879
#
#                                                               8
# Filename                                   20231210_161138_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                        0.0
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1526.5
# Count_of_gaps_larger_than_Large_Gap                          20
# Largest_Gaps_ms                                             2.0
# Smallest_Gap_ms                                            1.26
# Sum_of_Durations_Larger_than_Small_Gap_ms                 31.53
# Time_Length_of_File_ms                                 85994.29
# Time_Length_of_File_s                                    85.994
# Dead_Time_Percentage                                      0.037

# %%
directory_path = 'data_M0_baud/500_000/50_1500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                              inter_sample_delay=50,
                              inter_average_delay=1500,
                              samples_to_av=20, 
                              gap_sizeL_us=500, 
                              gap_sizeS_us=800)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_500_000 = pd.DataFrame(all_dictionaries).transpose()
df_M0_500_000
# Out:
#                                                               0  \
# Filename                                   20231210_161831_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.052
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1541.5
# Count_of_gaps_larger_than_Large_Gap                         998
# Largest_Gaps_ms                                             2.7
# Smallest_Gap_ms                                             1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms               1588.78
# Time_Length_of_File_ms                                19229.444
# Time_Length_of_File_s                                    19.229
# Dead_Time_Percentage                                      8.262
#
#                                                               1  \
# Filename                                   20231210_161832_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.048
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1576.5
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                            2.72
# Smallest_Gap_ms                                             1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms                1657.1
# Time_Length_of_File_ms                                20888.348
# Time_Length_of_File_s                                    20.888
# Dead_Time_Percentage                                      7.933
#
#                                                               2  \
# Filename                                   20231210_161834_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.044
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1668.5
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                            2.88
# Smallest_Gap_ms                                            1.19
# Sum_of_Durations_Larger_than_Small_Gap_ms               1707.71
# Time_Length_of_File_ms                                 22597.44
# Time_Length_of_File_s                                    22.597
# Dead_Time_Percentage                                      7.557
#
#                                                               3  \
# Filename                                   20231210_161836_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.041
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1575.0
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                            2.78
# Smallest_Gap_ms                                            1.21
# Sum_of_Durations_Larger_than_Small_Gap_ms               1625.13
# Time_Length_of_File_ms                                 24224.46
# Time_Length_of_File_s                                    24.224
# Dead_Time_Percentage                                      6.709
#
#                                                               4
# Filename                                   20231210_161837_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.011
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1513.5
# Count_of_gaps_larger_than_Large_Gap                         267
# Largest_Gaps_ms                                            2.61
# Smallest_Gap_ms                                            1.19
# Sum_of_Durations_Larger_than_Small_Gap_ms                428.76
# Time_Length_of_File_ms                                24655.588
# Time_Length_of_File_s                                    24.656
# Dead_Time_Percentage                                      1.739

# %%
result = pd.concat([df_M0_230400,df_M0_250_000,df_M0_115200,df_M0_460800,df_M0_500_000], axis=1, ignore_index=True)

result
# Out:
#                                                              0   \
# Filename                                   20231210_155736_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.006
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1354.0
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                            2.67
# Smallest_Gap_ms                                             1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms               1426.81
# Time_Length_of_File_ms                                177652.92
# Time_Length_of_File_s                                   177.653
# Dead_Time_Percentage                                      0.803
#
#                                                              1   \
# Filename                                   20231210_155737_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.006
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1342.0
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                            2.56
# Smallest_Gap_ms                                            1.19
# Sum_of_Durations_Larger_than_Small_Gap_ms               1430.91
# Time_Length_of_File_ms                               179085.061
# Time_Length_of_File_s                                   179.085
# Dead_Time_Percentage                                      0.799
#
#                                                              2   \
# Filename                                   20231210_155739_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.006
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1509.0
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                            2.77
# Smallest_Gap_ms                                             1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms               1579.79
# Time_Length_of_File_ms                               180666.078
# Time_Length_of_File_s                                   180.666
# Dead_Time_Percentage                                      0.874
#
#                                                              3   \
# Filename                                   20231210_155740_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.005
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1564.0
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                            2.77
# Smallest_Gap_ms                                             1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms               1630.54
# Time_Length_of_File_ms                               182298.408
# Time_Length_of_File_s                                   182.298
# Dead_Time_Percentage                                      0.894
#
#                                                              4   \
# Filename                                   20231210_155742_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.005
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1491.5
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                            2.71
# Smallest_Gap_ms                                            1.19
# Sum_of_Durations_Larger_than_Small_Gap_ms               1561.64
# Time_Length_of_File_ms                                183861.81
# Time_Length_of_File_s                                   183.862
# Dead_Time_Percentage                                      0.849
#
#                                                              5   \
# Filename                                   20231210_155743_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.005
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1610.5
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                            2.73
# Smallest_Gap_ms                                             1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms                1653.8
# Time_Length_of_File_ms                               185517.374
# Time_Length_of_File_s                                   185.517
# Dead_Time_Percentage                                      0.891
#
#                                                              6   \
# Filename                                   20231210_155745_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.005
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1554.5
# Count_of_gaps_larger_than_Large_Gap                         904
# Largest_Gaps_ms                                            2.78
# Smallest_Gap_ms                                             1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms               1459.64
# Time_Length_of_File_ms                               186979.012
# Time_Length_of_File_s                                   186.979
# Dead_Time_Percentage                                      0.781
#
#                                                              7   \
# Filename                                   20231210_160909_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.072
# Large_Gap_selected_ms                                       2.5
# Small_Gap_selected_ms                                       1.6
# Median_Gap_us                                            1533.0
# Count_of_gaps_larger_than_Large_Gap                          15
# Largest_Gaps_ms                                            2.77
# Smallest_Gap_ms                                             1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms                758.37
# Time_Length_of_File_ms                                 13787.15
# Time_Length_of_File_s                                    13.787
# Dead_Time_Percentage                                      5.501
#
#                                                              8   \
# Filename                                   20231210_160910_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.065
# Large_Gap_selected_ms                                       2.5
# Small_Gap_selected_ms                                       1.6
# Median_Gap_us                                            1532.0
# Count_of_gaps_larger_than_Large_Gap                          21
# Largest_Gaps_ms                                            2.66
# Smallest_Gap_ms                                             1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms                826.58
# Time_Length_of_File_ms                                15400.926
# Time_Length_of_File_s                                    15.401
# Dead_Time_Percentage                                      5.367
#
#                                                              9   ...  \
# Filename                                   20231210_160912_.txt  ...
# Samples_Averaged                                             20  ...
# Inter_Sample_delay                                           50  ...
# Inter_Average_delay                                        1500  ...
# Theoretical_Frequency_KHz                                   0.4  ...
# Sample_Frequency_KHz                                      0.059  ...
# Large_Gap_selected_ms                                       2.5  ...
# Small_Gap_selected_ms                                       1.6  ...
# Median_Gap_us                                            1511.0  ...
# Count_of_gaps_larger_than_Large_Gap                          13  ...
# Largest_Gaps_ms                                            2.69  ...
# Smallest_Gap_ms                                             1.2  ...
# Sum_of_Durations_Larger_than_Small_Gap_ms                749.42  ...
# Time_Length_of_File_ms                                16988.878  ...
# Time_Length_of_File_s                                    16.989  ...
# Dead_Time_Percentage                                      4.411  ...
#
#                                                              25  \
# Filename                                   20231210_161132_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.012
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1519.0
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                             2.8
# Smallest_Gap_ms                                            1.19
# Sum_of_Durations_Larger_than_Small_Gap_ms               1591.33
# Time_Length_of_File_ms                                81234.508
# Time_Length_of_File_s                                    81.235
# Dead_Time_Percentage                                      1.959
#
#                                                              26  \
# Filename                                   20231210_161134_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.012
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1524.5
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                            2.69
# Smallest_Gap_ms                                            1.21
# Sum_of_Durations_Larger_than_Small_Gap_ms               1566.33
# Time_Length_of_File_ms                                 82802.46
# Time_Length_of_File_s                                    82.802
# Dead_Time_Percentage                                      1.892
#
#                                                              27  \
# Filename                                   20231210_161135_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.012
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1453.0
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                            2.79
# Smallest_Gap_ms                                             1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms               1539.54
# Time_Length_of_File_ms                                  84343.6
# Time_Length_of_File_s                                    84.344
# Dead_Time_Percentage                                      1.825
#
#                                                              28  \
# Filename                                   20231210_161137_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.012
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1568.5
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                            2.79
# Smallest_Gap_ms                                            1.19
# Sum_of_Durations_Larger_than_Small_Gap_ms               1615.14
# Time_Length_of_File_ms                                85961.229
# Time_Length_of_File_s                                    85.961
# Dead_Time_Percentage                                      1.879
#
#                                                              29  \
# Filename                                   20231210_161138_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                        0.0
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1526.5
# Count_of_gaps_larger_than_Large_Gap                          20
# Largest_Gaps_ms                                             2.0
# Smallest_Gap_ms                                            1.26
# Sum_of_Durations_Larger_than_Small_Gap_ms                 31.53
# Time_Length_of_File_ms                                 85994.29
# Time_Length_of_File_s                                    85.994
# Dead_Time_Percentage                                      0.037
#
#                                                              30  \
# Filename                                   20231210_161831_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.052
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1541.5
# Count_of_gaps_larger_than_Large_Gap                         998
# Largest_Gaps_ms                                             2.7
# Smallest_Gap_ms                                             1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms               1588.78
# Time_Length_of_File_ms                                19229.444
# Time_Length_of_File_s                                    19.229
# Dead_Time_Percentage                                      8.262
#
#                                                              31  \
# Filename                                   20231210_161832_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.048
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1576.5
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                            2.72
# Smallest_Gap_ms                                             1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms                1657.1
# Time_Length_of_File_ms                                20888.348
# Time_Length_of_File_s                                    20.888
# Dead_Time_Percentage                                      7.933
#
#                                                              32  \
# Filename                                   20231210_161834_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.044
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1668.5
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                            2.88
# Smallest_Gap_ms                                            1.19
# Sum_of_Durations_Larger_than_Small_Gap_ms               1707.71
# Time_Length_of_File_ms                                 22597.44
# Time_Length_of_File_s                                    22.597
# Dead_Time_Percentage                                      7.557
#
#                                                              33  \
# Filename                                   20231210_161836_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.041
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1575.0
# Count_of_gaps_larger_than_Large_Gap                         999
# Largest_Gaps_ms                                            2.78
# Smallest_Gap_ms                                            1.21
# Sum_of_Durations_Larger_than_Small_Gap_ms               1625.13
# Time_Length_of_File_ms                                 24224.46
# Time_Length_of_File_s                                    24.224
# Dead_Time_Percentage                                      6.709
#
#                                                              34
# Filename                                   20231210_161837_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.011
# Large_Gap_selected_ms                                       0.5
# Small_Gap_selected_ms                                       0.8
# Median_Gap_us                                            1513.5
# Count_of_gaps_larger_than_Large_Gap                         267
# Largest_Gaps_ms                                            2.61
# Smallest_Gap_ms                                            1.19
# Sum_of_Durations_Larger_than_Small_Gap_ms                428.76
# Time_Length_of_File_ms                                24655.588
# Time_Length_of_File_s                                    24.656
# Dead_Time_Percentage                                      1.739
#
# [16 rows x 35 columns]

# %% [markdown]
# # Conclusions
# As we increase the baud rate the data is more sporadic

# %% [markdown]
# # Quick Look

# %%
subdirs = ["230400","250_000","115200","460800","500_000"]

directory_path = f'data_M0_baud/{subdirs[4]}/50_1500_20/'
print(directory_path)

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        quickLook(file_path,samples_to_av=20)
# Out:
# data_M0_baud/500_000/50_1500_20/
