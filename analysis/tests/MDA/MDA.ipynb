# %% [markdown]
# # First look at MDA Testing

# %%
import os
import pandas as pd
from analysis_one_pin import analyze, quickLook

directory_path = 'data/'

# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=True, gap_sizeL_us= 1000)
        quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df = pd.DataFrame(all_dictionaries).transpose()
df
# Out:
# inter_sample:  50.0
# inter_average:  50.0
# Expected Frequency from Median gap (KHz): 4.000
# Sample Frequency from Median gap (KHz): 0.907
#
# LARGE GAP ANALYSIS: 1.000 ms
# Largest gaps (ms):  205.713
# Count of long gaps:  284
# Median gap (us):  483.0
#
# SMALL GAP ANALYSIS: 0.500 ms
# Sum of durations larger than 0.50 ms (ms): 5753.919
#
# File info & Dead Time:
# Expected file duration assuming no overhead (ms,s): 2267.750 , 2.268
# Actual file duration (ms,s): 9999.770 , 10.000
#
# Dead time = (sum durations > 0.500 ms/Time length of file)
# Dead time %: 57.541
# inter_sample:  50.0
# inter_average:  500.0
# Expected Frequency from Median gap (KHz): 0.667
# Sample Frequency from Median gap (KHz): 0.355
#
# LARGE GAP ANALYSIS: 1.000 ms
# Largest gaps (ms):  214.718
# Count of long gaps:  3511
# Median gap (us):  2121.0
#
# SMALL GAP ANALYSIS: 0.500 ms
# Sum of durations larger than 0.50 ms (ms): 9891.032
#
# File info & Dead Time:
# Expected file duration assuming no overhead (ms,s): 5268.000 , 5.268
# Actual file duration (ms,s): 9891.032 , 9.891
#
# Dead time = (sum durations > 0.500 ms/Time length of file)
# Dead time %: 100.000
# inter_sample:  50.0
# inter_average:  500.0
# Expected Frequency from Median gap (KHz): 0.182
# Sample Frequency from Median gap (KHz): 0.112
#
# LARGE GAP ANALYSIS: 1.000 ms
# Largest gaps (ms):  212.658
# Count of long gaps:  1119
# Median gap (us):  8173.0
#
# SMALL GAP ANALYSIS: 0.500 ms
# Sum of durations larger than 0.50 ms (ms): 9994.443
#
# File info & Dead Time:
# Expected file duration assuming no overhead (ms,s): 6160.000 , 6.160
# Actual file duration (ms,s): 9994.443 , 9.994
#
# Dead time = (sum durations > 0.500 ms/Time length of file)
# Dead time %: 100.000
# inter_sample:  50.0
# inter_average:  500.0
# Expected Frequency from Median gap (KHz): 0.182
# Sample Frequency from Median gap (KHz): 0.113
#
# LARGE GAP ANALYSIS: 1.000 ms
# Largest gaps (ms):  212.529
# Count of long gaps:  1131
# Median gap (us):  8160.0
#
# SMALL GAP ANALYSIS: 0.500 ms
# Sum of durations larger than 0.50 ms (ms): 9995.548
#
# File info & Dead Time:
# Expected file duration assuming no overhead (ms,s): 6226.000 , 6.226
# Actual file duration (ms,s): 9995.548 , 9.996
#
# Dead time = (sum durations > 0.500 ms/Time length of file)
# Dead time %: 100.000
# inter_sample:  50.0
# inter_average:  500.0
# Expected Frequency from Median gap (KHz): 0.182
# Sample Frequency from Median gap (KHz): 0.112
#
# LARGE GAP ANALYSIS: 1.000 ms
# Largest gaps (ms):  214.214
# Count of long gaps:  1115
# Median gap (us):  8110.0
#
# SMALL GAP ANALYSIS: 0.500 ms
# Sum of durations larger than 0.50 ms (ms): 9999.206
#
# File info & Dead Time:
# Expected file duration assuming no overhead (ms,s): 6138.000 , 6.138
# Actual file duration (ms,s): 9999.206 , 9.999
#
# Dead time = (sum durations > 0.500 ms/Time length of file)
# Dead time %: 100.000
#                                                       0             1  \
# Filename                                   21100002.TXT  21340001.TXT
# Samples_Averaged                                      4            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                                50.0         500.0
# Theoretical_Frequency_KHz                        4000.0       666.667
# Sample_Frequency_KHz                              0.907         0.355
# Large_Gap_selected_ms                               1.0           1.0
# Small_Gap_selected_ms                               0.5           0.5
# Median_Gap_us                                     483.0        2121.0
# Count_of_gaps_larger_than_Large_Gap                 284          3511
# Largest_Gaps_ms                                  205.71        214.72
# Smallest_Gap_ms                                    0.48          2.12
# Sum_of_Durations_Larger_than_Small_Gap_ms       5753.92       9891.03
# Expected_file_duration_ms                       2267.75        5268.0
# Expected_file_duration_s                          2.268         5.268
# Actual_file_duration_ms                         9999.77      9891.032
# Actual_file_duration_s                             10.0         9.891
# Dead_Time_Percentage                             57.541         100.0
#
#                                                       2             3  \
# Filename                                   21580001.TXT  21640001.TXT
# Samples_Averaged                                    100           100
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                               500.0         500.0
# Theoretical_Frequency_KHz                       181.818       181.818
# Sample_Frequency_KHz                              0.112         0.113
# Large_Gap_selected_ms                               1.0           1.0
# Small_Gap_selected_ms                               0.5           0.5
# Median_Gap_us                                    8173.0        8160.0
# Count_of_gaps_larger_than_Large_Gap                1119          1131
# Largest_Gaps_ms                                  212.66        212.53
# Smallest_Gap_ms                                    8.16          8.15
# Sum_of_Durations_Larger_than_Small_Gap_ms       9994.44       9995.55
# Expected_file_duration_ms                        6160.0        6226.0
# Expected_file_duration_s                           6.16         6.226
# Actual_file_duration_ms                        9994.443      9995.548
# Actual_file_duration_s                            9.994         9.996
# Dead_Time_Percentage                              100.0         100.0
#
#                                                       4
# Filename                                   21650001.TXT
# Samples_Averaged                                    100
# Inter_Sample_delay                                 50.0
# Inter_Average_delay                               500.0
# Theoretical_Frequency_KHz                       181.818
# Sample_Frequency_KHz                              0.112
# Large_Gap_selected_ms                               1.0
# Small_Gap_selected_ms                               0.5
# Median_Gap_us                                    8110.0
# Count_of_gaps_larger_than_Large_Gap                1115
# Largest_Gaps_ms                                  214.21
# Smallest_Gap_ms                                    8.09
# Sum_of_Durations_Larger_than_Small_Gap_ms       9999.21
# Expected_file_duration_ms                        6138.0
# Expected_file_duration_s                          6.138
# Actual_file_duration_ms                        9999.206
# Actual_file_duration_s                            9.999
# Dead_Time_Percentage                              100.0
