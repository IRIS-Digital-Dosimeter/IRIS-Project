# %%
from analysis_IRIS import analyze, quickLook
import pandas as pd
import os

directory_path = 'data/M0_tLinear/50_50_4/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        quickLook(file_path, save_png=False, plot_all=False, plot_hist_sampletime=True)
        
        result_dict = analyze(file_path,prints=False)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_50_50_4 = pd.DataFrame(all_dictionaries).transpose()
df_M0_50_50_4
# Out:
#                                            0             1             2  \
# Filename                        05080001.TXT  05080002.TXT  05080003.TXT
# Samples_Averaged                           4             4             4
# Inter_Sample_delay_us                   50.0          50.0          50.0
# Inter_Average_delay_us                  50.0          50.0          50.0
# Number_of_samples                       6125          6108          6120
# Number_of_gaps                          6124          6107          6119
# Expected_sample_time_us                200.0         200.0         200.0
# Actual_sample_time_us                  396.0         396.0         396.0
# Median_gap_us                          591.5         592.0         593.0
# Expected_freq_KHz                        5.0           5.0           5.0
# Actual_freq_KHz                        1.225         1.222         1.224
# Expected_file_duration_ms             1225.0        1221.6        1224.0
# Actual_file_duration_ms              4999.83      4999.727      4999.742
# dead_vs_expectation                    3.081         3.093         3.085
# dead_time_due_to_gaps                  1.061         1.067         1.063
# OLD_ANALYSIS                               -             -             -
# Largest_gap_ms                        14.271        23.934        12.219
# Number_of_large_gaps                     347           346           346
# Smallest_gap_us                        590.0         590.0         591.0
# Sum_of_gaps_larger_than_med_ms      3417.892      3411.099      3423.324
# Old_dead_time_%                        68.36        68.226         68.47
#
#                                            3             4
# Filename                        05080004.TXT  05080005.TXT
# Samples_Averaged                           4             4
# Inter_Sample_delay_us                   50.0          50.0
# Inter_Average_delay_us                  50.0          50.0
# Number_of_samples                       6106          5857
# Number_of_gaps                          6105          5856
# Expected_sample_time_us                200.0         200.0
# Actual_sample_time_us                  396.0         396.0
# Median_gap_us                          593.0         593.0
# Expected_freq_KHz                        5.0           5.0
# Actual_freq_KHz                        1.222         1.172
# Expected_file_duration_ms             1221.2        1171.4
# Actual_file_duration_ms             4997.744      4999.522
# dead_vs_expectation                    3.092         3.268
# dead_time_due_to_gaps                  1.067         1.156
# OLD_ANALYSIS                               -             -
# Largest_gap_ms                        12.353       124.965
# Number_of_large_gaps                     345           331
# Smallest_gap_us                        591.0         591.0
# Sum_of_gaps_larger_than_med_ms      3416.285      3276.066
# Old_dead_time_%                       68.357        65.528

# %%
from analysis_IRIS import analyze, quickLook
import pandas as pd
import os

directory_path = 'data/M0_tLinear/50_500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        quickLook(file_path, save_png=False, plot_all=False, plot_hist_sampletime=True)
        
        result_dict = analyze(file_path,prints=False)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_50_500_20 = pd.DataFrame(all_dictionaries).transpose()
df_M0_50_500_20
# Out:
#                                            0             1             2  \
# Filename                        05090001.TXT  05090002.TXT  05090003.TXT
# Samples_Averaged                          20            20            20
# Inter_Sample_delay_us                   50.0          50.0          50.0
# Inter_Average_delay_us                 500.0         500.0         500.0
# Number_of_samples                       1748          1747          1747
# Number_of_gaps                          1747          1746          1746
# Expected_sample_time_us               1000.0        1000.0        1000.0
# Actual_sample_time_us                 1972.0        1972.0        1972.0
# Median_gap_us                         2626.0        2627.0        2627.5
# Expected_freq_KHz                        1.0           1.0           1.0
# Actual_freq_KHz                         0.35         0.349         0.349
# Expected_file_duration_ms             1748.0        1747.0        1747.0
# Actual_file_duration_ms             4997.105       4998.74      4999.542
# dead_vs_expectation                    1.859         1.861         1.862
# dead_time_due_to_gaps                   0.45         0.451         0.451
# OLD_ANALYSIS                               -             -             -
# Largest_gap_ms                         8.327         8.392         8.396
# Number_of_large_gaps                     105           105           105
# Smallest_gap_us                       2621.5        2622.5        2624.5
# Sum_of_gaps_larger_than_med_ms      4311.492      4310.878      4311.614
# Old_dead_time_%                        86.28        86.239         86.24
#
#                                            3             4
# Filename                        05090004.TXT  05090005.TXT
# Samples_Averaged                          20            20
# Inter_Sample_delay_us                   50.0          50.0
# Inter_Average_delay_us                 500.0         500.0
# Number_of_samples                       1748          1745
# Number_of_gaps                          1747          1744
# Expected_sample_time_us               1000.0        1000.0
# Actual_sample_time_us                 1972.0        1972.0
# Median_gap_us                         2627.5        2627.5
# Expected_freq_KHz                        1.0           1.0
# Actual_freq_KHz                         0.35         0.349
# Expected_file_duration_ms             1748.0        1745.0
# Actual_file_duration_ms             4997.434       4999.83
# dead_vs_expectation                    1.859         1.865
# dead_time_due_to_gaps                   0.45         0.453
# OLD_ANALYSIS                               -             -
# Largest_gap_ms                         7.859       11.7275
# Number_of_large_gaps                     105           105
# Smallest_gap_us                       2624.5        2623.5
# Sum_of_gaps_larger_than_med_ms      4314.402      4306.238
# Old_dead_time_%                       86.332        86.128

# %%
from analysis_IRIS import analyze, quickLook
import pandas as pd
import os

directory_path = 'data/M0_tLinear/50_1500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        quickLook(file_path, save_png=False, plot_all=False, plot_hist_sampletime=True)
        
        result_dict = analyze(file_path,prints=False)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_50_1500_20 = pd.DataFrame(all_dictionaries).transpose()
df_M0_50_1500_20
# Out:
#                                            0             1             2  \
# Filename                        05100001.TXT  05100002.TXT  05100003.TXT
# Samples_Averaged                          20            20            20
# Inter_Sample_delay_us                   50.0          50.0          50.0
# Inter_Average_delay_us                1500.0        1500.0        1500.0
# Number_of_samples                       1296          1295          1295
# Number_of_gaps                          1295          1294          1294
# Expected_sample_time_us               1000.0        1000.0        1000.0
# Actual_sample_time_us                 1972.0        1972.0        1972.0
# Median_gap_us                         3625.0        3625.0        3625.5
# Expected_freq_KHz                        1.0           1.0           1.0
# Actual_freq_KHz                        0.259         0.259         0.259
# Expected_file_duration_ms             1296.0        1295.0        1295.0
# Actual_file_duration_ms             4998.038      4996.579      4996.984
# dead_vs_expectation                    2.857         2.858         2.859
# dead_time_due_to_gaps                  0.956         0.957         0.957
# OLD_ANALYSIS                               -             -             -
# Largest_gap_ms                         8.759         8.909         8.916
# Number_of_large_gaps                      78            78            78
# Smallest_gap_us                       3622.5        3621.5        3621.5
# Sum_of_gaps_larger_than_med_ms      4411.892       4408.17      4408.438
# Old_dead_time_%                       88.272        88.224        88.222
#
#                                            3             4
# Filename                        05100004.TXT  05100005.TXT
# Samples_Averaged                          20            20
# Inter_Sample_delay_us                   50.0          50.0
# Inter_Average_delay_us                1500.0        1500.0
# Number_of_samples                       1296          1191
# Number_of_gaps                          1295          1190
# Expected_sample_time_us               1000.0        1000.0
# Actual_sample_time_us                 1972.0        1972.0
# Median_gap_us                         3626.0        3627.0
# Expected_freq_KHz                        1.0           1.0
# Actual_freq_KHz                        0.259         0.238
# Expected_file_duration_ms             1296.0        1191.0
# Actual_file_duration_ms              4999.06      4999.733
# dead_vs_expectation                    2.857         3.198
# dead_time_due_to_gaps                  0.956         1.129
# OLD_ANALYSIS                               -             -
# Largest_gap_ms                        8.8545       149.832
# Number_of_large_gaps                      78            72
# Smallest_gap_us                       3621.5        3624.0
# Sum_of_gaps_larger_than_med_ms      4412.742      4055.184
# Old_dead_time_%                       88.271        81.108

# %%
from analysis_IRIS import analyze, quickLook
import pandas as pd
import os

directory_path = 'data/M0_tLinear/100_500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        quickLook(file_path, save_png=False, plot_all=False, plot_hist_sampletime=True)
        
        result_dict = analyze(file_path,prints=False)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_100_500_20 = pd.DataFrame(all_dictionaries).transpose()
df_M0_100_500_20
# Out:
#                                            0             1             2
# Filename                        09060001.TXT  09060002.TXT  09060003.TXT
# Samples_Averaged                          20            20            20
# Inter_Sample_delay_us                  100.0         100.0         100.0
# Inter_Average_delay_us                 500.0         500.0         500.0
# Number_of_samples                       1324          1325          1325
# Number_of_gaps                          1323          1324          1324
# Expected_sample_time_us               2000.0        2000.0        2000.0
# Actual_sample_time_us                 2959.0        2959.0        2959.0
# Median_gap_us                         3601.5        3601.5        3602.0
# Expected_freq_KHz                        0.5           0.5           0.5
# Actual_freq_KHz                        0.265         0.265         0.265
# Expected_file_duration_ms             2648.0        2650.0        2650.0
# Actual_file_duration_ms             4997.962      4998.692      4997.021
# dead_vs_expectation                    0.887         0.886         0.886
# dead_time_due_to_gaps                  0.276         0.275         0.275
# OLD_ANALYSIS                               -             -             -
# Largest_gap_ms                          14.4          14.4        14.421
# Number_of_large_gaps                      75            75            75
# Smallest_gap_us                       3597.5        3598.5        3598.0
# Sum_of_gaps_larger_than_med_ms       4494.43      4498.176      4498.801
# Old_dead_time_%                       89.925        89.987         90.03

# %%
result = pd.concat([df_M0_50_50_4,df_M0_50_500_20,df_M0_50_1500_20,df_M0_100_500_20], axis=1, ignore_index=True)

result
# Out:
#                                           0             1             2   \
# Filename                        05080001.TXT  05080002.TXT  05080003.TXT
# Samples_Averaged                           4             4             4
# Inter_Sample_delay_us                   50.0          50.0          50.0
# Inter_Average_delay_us                  50.0          50.0          50.0
# Number_of_samples                       6125          6108          6120
# Number_of_gaps                          6124          6107          6119
# Expected_sample_time_us                200.0         200.0         200.0
# Actual_sample_time_us                  396.0         396.0         396.0
# Median_gap_us                          591.5         592.0         593.0
# Expected_freq_KHz                        5.0           5.0           5.0
# Actual_freq_KHz                        1.225         1.222         1.224
# Expected_file_duration_ms             1225.0        1221.6        1224.0
# Actual_file_duration_ms              4999.83      4999.727      4999.742
# dead_vs_expectation                    3.081         3.093         3.085
# dead_time_due_to_gaps                  1.061         1.067         1.063
# OLD_ANALYSIS                               -             -             -
# Largest_gap_ms                        14.271        23.934        12.219
# Number_of_large_gaps                     347           346           346
# Smallest_gap_us                        590.0         590.0         591.0
# Sum_of_gaps_larger_than_med_ms      3417.892      3411.099      3423.324
# Old_dead_time_%                        68.36        68.226         68.47
#
#                                           3             4             5   \
# Filename                        05080004.TXT  05080005.TXT  05090001.TXT
# Samples_Averaged                           4             4            20
# Inter_Sample_delay_us                   50.0          50.0          50.0
# Inter_Average_delay_us                  50.0          50.0         500.0
# Number_of_samples                       6106          5857          1748
# Number_of_gaps                          6105          5856          1747
# Expected_sample_time_us                200.0         200.0        1000.0
# Actual_sample_time_us                  396.0         396.0        1972.0
# Median_gap_us                          593.0         593.0        2626.0
# Expected_freq_KHz                        5.0           5.0           1.0
# Actual_freq_KHz                        1.222         1.172          0.35
# Expected_file_duration_ms             1221.2        1171.4        1748.0
# Actual_file_duration_ms             4997.744      4999.522      4997.105
# dead_vs_expectation                    3.092         3.268         1.859
# dead_time_due_to_gaps                  1.067         1.156          0.45
# OLD_ANALYSIS                               -             -             -
# Largest_gap_ms                        12.353       124.965         8.327
# Number_of_large_gaps                     345           331           105
# Smallest_gap_us                        591.0         591.0        2621.5
# Sum_of_gaps_larger_than_med_ms      3416.285      3276.066      4311.492
# Old_dead_time_%                       68.357        65.528         86.28
#
#                                           6             7             8   \
# Filename                        05090002.TXT  05090003.TXT  05090004.TXT
# Samples_Averaged                          20            20            20
# Inter_Sample_delay_us                   50.0          50.0          50.0
# Inter_Average_delay_us                 500.0         500.0         500.0
# Number_of_samples                       1747          1747          1748
# Number_of_gaps                          1746          1746          1747
# Expected_sample_time_us               1000.0        1000.0        1000.0
# Actual_sample_time_us                 1972.0        1972.0        1972.0
# Median_gap_us                         2627.0        2627.5        2627.5
# Expected_freq_KHz                        1.0           1.0           1.0
# Actual_freq_KHz                        0.349         0.349          0.35
# Expected_file_duration_ms             1747.0        1747.0        1748.0
# Actual_file_duration_ms              4998.74      4999.542      4997.434
# dead_vs_expectation                    1.861         1.862         1.859
# dead_time_due_to_gaps                  0.451         0.451          0.45
# OLD_ANALYSIS                               -             -             -
# Largest_gap_ms                         8.392         8.396         7.859
# Number_of_large_gaps                     105           105           105
# Smallest_gap_us                       2622.5        2624.5        2624.5
# Sum_of_gaps_larger_than_med_ms      4310.878      4311.614      4314.402
# Old_dead_time_%                       86.239         86.24        86.332
#
#                                           9             10            11  \
# Filename                        05090005.TXT  05100001.TXT  05100002.TXT
# Samples_Averaged                          20            20            20
# Inter_Sample_delay_us                   50.0          50.0          50.0
# Inter_Average_delay_us                 500.0        1500.0        1500.0
# Number_of_samples                       1745          1296          1295
# Number_of_gaps                          1744          1295          1294
# Expected_sample_time_us               1000.0        1000.0        1000.0
# Actual_sample_time_us                 1972.0        1972.0        1972.0
# Median_gap_us                         2627.5        3625.0        3625.0
# Expected_freq_KHz                        1.0           1.0           1.0
# Actual_freq_KHz                        0.349         0.259         0.259
# Expected_file_duration_ms             1745.0        1296.0        1295.0
# Actual_file_duration_ms              4999.83      4998.038      4996.579
# dead_vs_expectation                    1.865         2.857         2.858
# dead_time_due_to_gaps                  0.453         0.956         0.957
# OLD_ANALYSIS                               -             -             -
# Largest_gap_ms                       11.7275         8.759         8.909
# Number_of_large_gaps                     105            78            78
# Smallest_gap_us                       2623.5        3622.5        3621.5
# Sum_of_gaps_larger_than_med_ms      4306.238      4411.892       4408.17
# Old_dead_time_%                       86.128        88.272        88.224
#
#                                           12            13            14  \
# Filename                        05100003.TXT  05100004.TXT  05100005.TXT
# Samples_Averaged                          20            20            20
# Inter_Sample_delay_us                   50.0          50.0          50.0
# Inter_Average_delay_us                1500.0        1500.0        1500.0
# Number_of_samples                       1295          1296          1191
# Number_of_gaps                          1294          1295          1190
# Expected_sample_time_us               1000.0        1000.0        1000.0
# Actual_sample_time_us                 1972.0        1972.0        1972.0
# Median_gap_us                         3625.5        3626.0        3627.0
# Expected_freq_KHz                        1.0           1.0           1.0
# Actual_freq_KHz                        0.259         0.259         0.238
# Expected_file_duration_ms             1295.0        1296.0        1191.0
# Actual_file_duration_ms             4996.984       4999.06      4999.733
# dead_vs_expectation                    2.859         2.857         3.198
# dead_time_due_to_gaps                  0.957         0.956         1.129
# OLD_ANALYSIS                               -             -             -
# Largest_gap_ms                         8.916        8.8545       149.832
# Number_of_large_gaps                      78            78            72
# Smallest_gap_us                       3621.5        3621.5        3624.0
# Sum_of_gaps_larger_than_med_ms      4408.438      4412.742      4055.184
# Old_dead_time_%                       88.222        88.271        81.108
#
#                                           15            16            17
# Filename                        09060001.TXT  09060002.TXT  09060003.TXT
# Samples_Averaged                          20            20            20
# Inter_Sample_delay_us                  100.0         100.0         100.0
# Inter_Average_delay_us                 500.0         500.0         500.0
# Number_of_samples                       1324          1325          1325
# Number_of_gaps                          1323          1324          1324
# Expected_sample_time_us               2000.0        2000.0        2000.0
# Actual_sample_time_us                 2959.0        2959.0        2959.0
# Median_gap_us                         3601.5        3601.5        3602.0
# Expected_freq_KHz                        0.5           0.5           0.5
# Actual_freq_KHz                        0.265         0.265         0.265
# Expected_file_duration_ms             2648.0        2650.0        2650.0
# Actual_file_duration_ms             4997.962      4998.692      4997.021
# dead_vs_expectation                    0.887         0.886         0.886
# dead_time_due_to_gaps                  0.276         0.275         0.275
# OLD_ANALYSIS                               -             -             -
# Largest_gap_ms                          14.4          14.4        14.421
# Number_of_large_gaps                      75            75            75
# Smallest_gap_us                       3597.5        3598.5        3598.0
# Sum_of_gaps_larger_than_med_ms       4494.43      4498.176      4498.801
# Old_dead_time_%                       89.925        89.987         90.03
