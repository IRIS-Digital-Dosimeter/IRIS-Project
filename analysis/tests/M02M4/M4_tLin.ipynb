# %%
from analysis_IRIS import analyze, quickLook
import pandas as pd
import os

directory_path = 'data/M4_tLinear/50_50_4/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        quickLook(file_path, save_png=False, plot_all=False, plot_hist_sampletime=True)
        
        result_dict = analyze(file_path,prints=False)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M4_50_50_4 = pd.DataFrame(all_dictionaries).transpose()
df_M4_50_50_4
# Out:
#                                            0             1             2  \
# Filename                        05070001.TXT  05070002.TXT  05070003.TXT
# Samples_Averaged                           4             4             4
# Inter_Sample_delay_us                   50.0          50.0          50.0
# Inter_Average_delay_us                  50.0          50.0          50.0
# Number_of_samples                       5844          5627          5894
# Number_of_gaps                          5843          5626          5893
# Expected_sample_time_us                200.0         200.0         200.0
# Actual_sample_time_us                  415.0         415.0         415.0
# Median_gap_us                          488.0         488.0         488.0
# Expected_freq_KHz                        5.0           5.0           5.0
# Actual_freq_KHz                        1.169         1.125         1.187
# Expected_file_duration_ms             1168.8        1125.4        1178.8
# Actual_file_duration_ms             4999.637      4999.665      4963.646
# dead_vs_expectation                    3.278         3.443         3.211
# dead_time_due_to_gaps                  1.061         1.141         1.029
# OLD_ANALYSIS                               -             -             -
# Largest_gap_ms                        53.868      100.3225       52.9175
# Number_of_large_gaps                      43            44            42
# Smallest_gap_us                        484.5         485.5         485.0
# Sum_of_gaps_larger_than_med_ms      2838.994      2732.388      2864.285
# Old_dead_time_%                       56.784        54.651        57.705
#
#                                            3             4
# Filename                        05070004.TXT  05070005.TXT
# Samples_Averaged                           4             4
# Inter_Sample_delay_us                   50.0          50.0
# Inter_Average_delay_us                  50.0          50.0
# Number_of_samples                       5655          5869
# Number_of_gaps                          5654          5868
# Expected_sample_time_us                200.0         200.0
# Actual_sample_time_us                  415.0         415.0
# Median_gap_us                          488.0         488.0
# Expected_freq_KHz                        5.0           5.0
# Actual_freq_KHz                        1.131         1.174
# Expected_file_duration_ms             1131.0        1173.8
# Actual_file_duration_ms             4999.643      4999.826
# dead_vs_expectation                    3.421          3.26
# dead_time_due_to_gaps                   1.13         1.053
# OLD_ANALYSIS                               -             -
# Largest_gap_ms                        55.054         55.07
# Number_of_large_gaps                      45            43
# Smallest_gap_us                        485.5         485.0
# Sum_of_gaps_larger_than_med_ms      2746.161      2851.871
# Old_dead_time_%                       54.927        57.039

# %%
from analysis_IRIS import analyze, quickLook
import pandas as pd
import os

directory_path = 'data/M4_tLinear/50_500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        quickLook(file_path, save_png=False, plot_all=False, plot_hist_sampletime=True)
        
        result_dict = analyze(file_path,prints=False)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M4_50_500_20 = pd.DataFrame(all_dictionaries).transpose()
df_M4_50_500_20
# Out:
#                                            0             1             2  \
# Filename                        05080001.TXT  05080002.TXT  05080003.TXT
# Samples_Averaged                          20            20            20
# Inter_Sample_delay_us                   50.0          50.0          50.0
# Inter_Average_delay_us                 500.0         500.0         500.0
# Number_of_samples                       1656          1674          1675
# Number_of_gaps                          1655          1673          1674
# Expected_sample_time_us               1000.0        1000.0        1000.0
# Actual_sample_time_us                 2075.0        2075.0        2075.0
# Median_gap_us                         2598.0        2597.5        2598.0
# Expected_freq_KHz                        1.0           1.0           1.0
# Actual_freq_KHz                        0.334         0.335         0.335
# Expected_file_duration_ms             1656.0        1674.0        1675.0
# Actual_file_duration_ms             4955.474      4997.878      4999.548
# dead_vs_expectation                    1.992         1.986         1.985
# dead_time_due_to_gaps                  0.442         0.439         0.438
# OLD_ANALYSIS                               -             -             -
# Largest_gap_ms                       55.3765         55.51        55.603
# Number_of_large_gaps                      13            13            13
# Smallest_gap_us                       2592.5        2593.0        2591.5
# Sum_of_gaps_larger_than_med_ms      4267.836      4314.532      4317.238
# Old_dead_time_%                       86.124        86.327        86.353
#
#                                            3             4
# Filename                        05080004.TXT  05080005.TXT
# Samples_Averaged                          20            20
# Inter_Sample_delay_us                   50.0          50.0
# Inter_Average_delay_us                 500.0         500.0
# Number_of_samples                       1674          1674
# Number_of_gaps                          1673          1673
# Expected_sample_time_us               1000.0        1000.0
# Actual_sample_time_us                 2075.0        2075.0
# Median_gap_us                         2598.0        2598.0
# Expected_freq_KHz                        1.0           1.0
# Actual_freq_KHz                        0.335         0.335
# Expected_file_duration_ms             1674.0        1674.0
# Actual_file_duration_ms             4997.474       4999.63
# dead_vs_expectation                    1.985         1.987
# dead_time_due_to_gaps                  0.439         0.439
# OLD_ANALYSIS                               -             -
# Largest_gap_ms                        55.672        59.434
# Number_of_large_gaps                      13            13
# Smallest_gap_us                       2593.0        2590.0
# Sum_of_gaps_larger_than_med_ms      4314.658      4314.723
# Old_dead_time_%                       86.337        86.301

# %%
from analysis_IRIS import analyze, quickLook
import pandas as pd
import os

directory_path = 'data/M4_tLinear/50_1500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        quickLook(file_path, save_png=False, plot_all=False, plot_hist_sampletime=True)
        
        result_dict = analyze(file_path,prints=False)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M4_50_1500_20 = pd.DataFrame(all_dictionaries).transpose()
df_M4_50_1500_20
# Out:
#                                            0             1             2  \
# Filename                        05090001.TXT  05090002.TXT  05090003.TXT
# Samples_Averaged                          20            20            20
# Inter_Sample_delay_us                   50.0          50.0          50.0
# Inter_Average_delay_us                1500.0        1500.0        1500.0
# Number_of_samples                       1249          1209          1265
# Number_of_gaps                          1248          1208          1264
# Expected_sample_time_us               1000.0        1000.0        1000.0
# Actual_sample_time_us                 2075.0        2075.0        2075.0
# Median_gap_us                         3597.5        3598.0        3597.5
# Expected_freq_KHz                        1.0           1.0           1.0
# Actual_freq_KHz                         0.25         0.242         0.253
# Expected_file_duration_ms             1249.0        1209.0        1265.0
# Actual_file_duration_ms             4997.372      4999.757      4996.622
# dead_vs_expectation                    3.001         3.135          2.95
# dead_time_due_to_gaps                  0.928         0.993         0.904
# OLD_ANALYSIS                               -             -             -
# Largest_gap_ms                        58.275        56.756       54.9755
# Number_of_large_gaps                      10            13             9
# Smallest_gap_us                       3592.5        3593.5        3592.5
# Sum_of_gaps_larger_than_med_ms      4455.597      4300.988      4516.792
# Old_dead_time_%                       89.159        86.024        90.397
#
#                                            3             4
# Filename                        05090004.TXT  05090005.TXT
# Samples_Averaged                          20            20
# Inter_Sample_delay_us                   50.0          50.0
# Inter_Average_delay_us                1500.0        1500.0
# Number_of_samples                       1264          1264
# Number_of_gaps                          1263          1263
# Expected_sample_time_us               1000.0        1000.0
# Actual_sample_time_us                 2075.0        2075.0
# Median_gap_us                         3597.5        3597.5
# Expected_freq_KHz                        1.0           1.0
# Actual_freq_KHz                        0.253         0.253
# Expected_file_duration_ms             1264.0        1264.0
# Actual_file_duration_ms             4996.984      4997.202
# dead_vs_expectation                    2.953         2.953
# dead_time_due_to_gaps                  0.905         0.905
# OLD_ANALYSIS                               -             -
# Largest_gap_ms                       58.8335        58.907
# Number_of_large_gaps                       9             9
# Smallest_gap_us                       3592.5        3593.5
# Sum_of_gaps_larger_than_med_ms      4513.306      4513.272
# Old_dead_time_%                       90.321        90.316

# %%
result = pd.concat([df_M4_50_50_4,df_M4_50_500_20,df_M4_50_1500_20], axis=1, ignore_index=True)

result
# Out:
#                                           0             1             2   \
# Filename                        05070001.TXT  05070002.TXT  05070003.TXT
# Samples_Averaged                           4             4             4
# Inter_Sample_delay_us                   50.0          50.0          50.0
# Inter_Average_delay_us                  50.0          50.0          50.0
# Number_of_samples                       5844          5627          5894
# Number_of_gaps                          5843          5626          5893
# Expected_sample_time_us                200.0         200.0         200.0
# Actual_sample_time_us                  415.0         415.0         415.0
# Median_gap_us                          488.0         488.0         488.0
# Expected_freq_KHz                        5.0           5.0           5.0
# Actual_freq_KHz                        1.169         1.125         1.187
# Expected_file_duration_ms             1168.8        1125.4        1178.8
# Actual_file_duration_ms             4999.637      4999.665      4963.646
# dead_vs_expectation                    3.278         3.443         3.211
# dead_time_due_to_gaps                  1.061         1.141         1.029
# OLD_ANALYSIS                               -             -             -
# Largest_gap_ms                        53.868      100.3225       52.9175
# Number_of_large_gaps                      43            44            42
# Smallest_gap_us                        484.5         485.5         485.0
# Sum_of_gaps_larger_than_med_ms      2838.994      2732.388      2864.285
# Old_dead_time_%                       56.784        54.651        57.705
#
#                                           3             4             5   \
# Filename                        05070004.TXT  05070005.TXT  05080001.TXT
# Samples_Averaged                           4             4            20
# Inter_Sample_delay_us                   50.0          50.0          50.0
# Inter_Average_delay_us                  50.0          50.0         500.0
# Number_of_samples                       5655          5869          1656
# Number_of_gaps                          5654          5868          1655
# Expected_sample_time_us                200.0         200.0        1000.0
# Actual_sample_time_us                  415.0         415.0        2075.0
# Median_gap_us                          488.0         488.0        2598.0
# Expected_freq_KHz                        5.0           5.0           1.0
# Actual_freq_KHz                        1.131         1.174         0.334
# Expected_file_duration_ms             1131.0        1173.8        1656.0
# Actual_file_duration_ms             4999.643      4999.826      4955.474
# dead_vs_expectation                    3.421          3.26         1.992
# dead_time_due_to_gaps                   1.13         1.053         0.442
# OLD_ANALYSIS                               -             -             -
# Largest_gap_ms                        55.054         55.07       55.3765
# Number_of_large_gaps                      45            43            13
# Smallest_gap_us                        485.5         485.0        2592.5
# Sum_of_gaps_larger_than_med_ms      2746.161      2851.871      4267.836
# Old_dead_time_%                       54.927        57.039        86.124
#
#                                           6             7             8   \
# Filename                        05080002.TXT  05080003.TXT  05080004.TXT
# Samples_Averaged                          20            20            20
# Inter_Sample_delay_us                   50.0          50.0          50.0
# Inter_Average_delay_us                 500.0         500.0         500.0
# Number_of_samples                       1674          1675          1674
# Number_of_gaps                          1673          1674          1673
# Expected_sample_time_us               1000.0        1000.0        1000.0
# Actual_sample_time_us                 2075.0        2075.0        2075.0
# Median_gap_us                         2597.5        2598.0        2598.0
# Expected_freq_KHz                        1.0           1.0           1.0
# Actual_freq_KHz                        0.335         0.335         0.335
# Expected_file_duration_ms             1674.0        1675.0        1674.0
# Actual_file_duration_ms             4997.878      4999.548      4997.474
# dead_vs_expectation                    1.986         1.985         1.985
# dead_time_due_to_gaps                  0.439         0.438         0.439
# OLD_ANALYSIS                               -             -             -
# Largest_gap_ms                         55.51        55.603        55.672
# Number_of_large_gaps                      13            13            13
# Smallest_gap_us                       2593.0        2591.5        2593.0
# Sum_of_gaps_larger_than_med_ms      4314.532      4317.238      4314.658
# Old_dead_time_%                       86.327        86.353        86.337
#
#                                           9             10            11  \
# Filename                        05080005.TXT  05090001.TXT  05090002.TXT
# Samples_Averaged                          20            20            20
# Inter_Sample_delay_us                   50.0          50.0          50.0
# Inter_Average_delay_us                 500.0        1500.0        1500.0
# Number_of_samples                       1674          1249          1209
# Number_of_gaps                          1673          1248          1208
# Expected_sample_time_us               1000.0        1000.0        1000.0
# Actual_sample_time_us                 2075.0        2075.0        2075.0
# Median_gap_us                         2598.0        3597.5        3598.0
# Expected_freq_KHz                        1.0           1.0           1.0
# Actual_freq_KHz                        0.335          0.25         0.242
# Expected_file_duration_ms             1674.0        1249.0        1209.0
# Actual_file_duration_ms              4999.63      4997.372      4999.757
# dead_vs_expectation                    1.987         3.001         3.135
# dead_time_due_to_gaps                  0.439         0.928         0.993
# OLD_ANALYSIS                               -             -             -
# Largest_gap_ms                        59.434        58.275        56.756
# Number_of_large_gaps                      13            10            13
# Smallest_gap_us                       2590.0        3592.5        3593.5
# Sum_of_gaps_larger_than_med_ms      4314.723      4455.597      4300.988
# Old_dead_time_%                       86.301        89.159        86.024
#
#                                           12            13            14
# Filename                        05090003.TXT  05090004.TXT  05090005.TXT
# Samples_Averaged                          20            20            20
# Inter_Sample_delay_us                   50.0          50.0          50.0
# Inter_Average_delay_us                1500.0        1500.0        1500.0
# Number_of_samples                       1265          1264          1264
# Number_of_gaps                          1264          1263          1263
# Expected_sample_time_us               1000.0        1000.0        1000.0
# Actual_sample_time_us                 2075.0        2075.0        2075.0
# Median_gap_us                         3597.5        3597.5        3597.5
# Expected_freq_KHz                        1.0           1.0           1.0
# Actual_freq_KHz                        0.253         0.253         0.253
# Expected_file_duration_ms             1265.0        1264.0        1264.0
# Actual_file_duration_ms             4996.622      4996.984      4997.202
# dead_vs_expectation                     2.95         2.953         2.953
# dead_time_due_to_gaps                  0.904         0.905         0.905
# OLD_ANALYSIS                               -             -             -
# Largest_gap_ms                       54.9755       58.8335        58.907
# Number_of_large_gaps                       9             9             9
# Smallest_gap_us                       3592.5        3592.5        3593.5
# Sum_of_gaps_larger_than_med_ms      4516.792      4513.306      4513.272
# Old_dead_time_%                       90.397        90.321        90.316
