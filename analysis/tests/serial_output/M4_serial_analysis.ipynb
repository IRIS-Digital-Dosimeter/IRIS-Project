# %%
import os
import pandas as pd
from analysis_IRIS import analyze, quickLook

directory_path = 'data/M4/50_50_4/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                              inter_sample_delay=50,
                              inter_average_delay=50,
                              samples_averaged=4)
        quickLook(file_path, save_png=False, plot_all=False, plot_hist_sampletime=True)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_50_50_4 = pd.DataFrame(all_dictionaries).transpose()
df_M0_50_50_4
# Out:
#                                                    0                     1  \
# Filename                        20231205_184828_.txt  20231205_184829_.txt
# Samples_Averaged                                   4                     4
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                            50                    50
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                          200                   200
# Actual_sample_time_us                          409.0                 409.0
# Median_gap_us                                  813.0                 792.0
# Expected_freq_KHz                                5.0                   5.0
# Actual_freq_KHz                                 1.21                 1.251
# Expected_file_duration_ms                      200.0                 200.0
# Actual_file_duration_ms                      826.524                799.54
# dead_vs_expectation                            3.133                 2.998
# dead_time_due_to_gaps                          1.021                 0.955
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                1.3995                1.0045
# Number_of_large_gaps                             464                   270
# Smallest_gap_us                                749.0                 750.0
# Sum_of_gaps_larger_than_med_ms               420.474               569.408
# Old_dead_time_%                               50.872                71.217
#
#                                                    2                     3  \
# Filename                        20231205_184830_.txt  20231205_184831_.txt
# Samples_Averaged                                   4                     4
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                            50                    50
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                          200                   200
# Actual_sample_time_us                          409.0                 410.0
# Median_gap_us                                  800.0                 801.0
# Expected_freq_KHz                                5.0                   5.0
# Actual_freq_KHz                                1.223                 1.211
# Expected_file_duration_ms                      200.0                 200.0
# Actual_file_duration_ms                      817.804               826.088
# dead_vs_expectation                            3.089                  3.13
# dead_time_due_to_gaps                            1.0                 1.015
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                1.1685                1.2685
# Number_of_large_gaps                             401                   414
# Smallest_gap_us                                748.5                 748.0
# Sum_of_gaps_larger_than_med_ms               467.562               457.169
# Old_dead_time_%                               57.173                55.341
#
#                                                    4                     5  \
# Filename                        20231205_184832_.txt  20231205_184833_.txt
# Samples_Averaged                                   4                     4
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                            50                    50
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                          200                   200
# Actual_sample_time_us                          409.0                 409.0
# Median_gap_us                                  810.5                 796.5
# Expected_freq_KHz                                5.0                   5.0
# Actual_freq_KHz                                1.208                 1.223
# Expected_file_duration_ms                      200.0                 200.0
# Actual_file_duration_ms                      827.874               817.753
# dead_vs_expectation                            3.139                 3.089
# dead_time_due_to_gaps                          1.024                 0.999
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                1.2065                1.5275
# Number_of_large_gaps                             462                   345
# Smallest_gap_us                                748.5                 748.5
# Sum_of_gaps_larger_than_med_ms                420.93               510.464
# Old_dead_time_%                               50.845                62.423
#
#                                                    6                     7
# Filename                        20231205_184834_.txt  20231205_184835_.txt
# Samples_Averaged                                   4                     4
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                            50                    50
# Number_of_samples                               1000                   117
# Number_of_gaps                                   999                   116
# Expected_sample_time_us                          200                   200
# Actual_sample_time_us                          409.0                 409.0
# Median_gap_us                                  799.5                 777.0
# Expected_freq_KHz                                5.0                   5.0
# Actual_freq_KHz                                1.209                 1.277
# Expected_file_duration_ms                      200.0                  23.4
# Actual_file_duration_ms                      827.234                91.644
# dead_vs_expectation                            3.136                 2.916
# dead_time_due_to_gaps                          1.023                 0.915
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                1.3065                 0.989
# Number_of_large_gaps                             391                    22
# Smallest_gap_us                                748.5                 748.0
# Sum_of_gaps_larger_than_med_ms               475.416                72.808
# Old_dead_time_%                               57.471                79.446

# %%
import os
import pandas as pd
from analysis_IRIS import analyze, quickLook

directory_path = 'data/M4/50_500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                              inter_sample_delay=50,
                              inter_average_delay=500,
                              samples_averaged=20)
        quickLook(file_path, save_png=False, plot_all=False, plot_hist_sampletime=True)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_50_500_4 = pd.DataFrame(all_dictionaries).transpose()
df_M0_50_500_4
# Out:
#                                                    0                     1  \
# Filename                        20231205_184952_.txt  20231205_184955_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                           500                   500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                         2047.0                2047.0
# Median_gap_us                                 3172.5                3210.5
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.315                 0.311
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                      3173.15              3215.611
# dead_vs_expectation                            2.173                 2.216
# dead_time_due_to_gaps                           0.55                 0.571
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                3.6635                3.6855
# Number_of_large_gaps                               0                     0
# Smallest_gap_us                               2853.0                2864.5
# Sum_of_gaps_larger_than_med_ms               3173.15              3215.611
# Old_dead_time_%                                100.0                 100.0
#
#                                                    2                     3  \
# Filename                        20231205_184958_.txt  20231205_185002_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                           500                   500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                         2047.0                2047.0
# Median_gap_us                                 3210.0                3217.5
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.311                 0.311
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                     3210.553              3218.814
# dead_vs_expectation                            2.211                 2.219
# dead_time_due_to_gaps                          0.568                 0.572
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                 3.758                3.7395
# Number_of_large_gaps                               0                     0
# Smallest_gap_us                               2888.0                2844.0
# Sum_of_gaps_larger_than_med_ms              3210.553              3218.814
# Old_dead_time_%                                100.0                 100.0
#
#                                                    4                     5  \
# Filename                        20231205_185005_.txt  20231205_185008_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                           500                   500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                         2047.0                2047.0
# Median_gap_us                                 3222.0                3220.5
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.311                  0.31
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                     3217.995              3225.049
# dead_vs_expectation                            2.218                 2.225
# dead_time_due_to_gaps                          0.572                 0.576
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                3.7485                3.8095
# Number_of_large_gaps                               0                     0
# Smallest_gap_us                               2848.5                2844.5
# Sum_of_gaps_larger_than_med_ms              3217.995              3225.049
# Old_dead_time_%                                100.0                 100.0
#
#                                                    6
# Filename                        20231205_185011_.txt
# Samples_Averaged                                  20
# Inter_Sample_delay_us                             50
# Inter_Average_delay_us                           500
# Number_of_samples                                422
# Number_of_gaps                                   421
# Expected_sample_time_us                         1000
# Actual_sample_time_us                         2047.0
# Median_gap_us                                 3161.5
# Expected_freq_KHz                                1.0
# Actual_freq_KHz                                0.317
# Expected_file_duration_ms                      422.0
# Actual_file_duration_ms                      1331.68
# dead_vs_expectation                            2.156
# dead_time_due_to_gaps                          0.542
# OLD_ANALYSIS                                       -
# Largest_gap_ms                                3.6425
# Number_of_large_gaps                               0
# Smallest_gap_us                               2859.0
# Sum_of_gaps_larger_than_med_ms               1331.68
# Old_dead_time_%                                100.0

# %%
import os
import pandas as pd
from analysis_IRIS import analyze, quickLook

directory_path = 'data/M4/50_1500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                              inter_sample_delay=50,
                              inter_average_delay=1500,
                              samples_averaged=20)
        quickLook(file_path, save_png=False, plot_all=False, plot_hist_sampletime=True)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_50_1500_4 = pd.DataFrame(all_dictionaries).transpose()
df_M0_50_1500_4
# Out:
#                                                    0                     1  \
# Filename                        20231205_185115_.txt  20231205_185119_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                         2047.0                2047.0
# Median_gap_us                                 4233.0                4225.5
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.236                 0.236
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                     4235.409              4237.168
# dead_vs_expectation                            3.235                 3.237
# dead_time_due_to_gaps                          1.069                  1.07
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                4.9785                4.8225
# Number_of_large_gaps                             747                   747
# Smallest_gap_us                               3847.0                3851.0
# Sum_of_gaps_larger_than_med_ms              1008.458               1007.71
# Old_dead_time_%                                23.81                23.783
#
#                                                    2                     3  \
# Filename                        20231205_185124_.txt  20231205_185128_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                         2047.0                2047.0
# Median_gap_us                                 4247.0                4272.0
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.236                 0.234
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                     4243.448              4272.176
# dead_vs_expectation                            3.243                 3.272
# dead_time_due_to_gaps                          1.073                 1.087
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                 4.943                4.9315
# Number_of_large_gaps                             745                   803
# Smallest_gap_us                               3864.5                3871.0
# Sum_of_gaps_larger_than_med_ms              1017.988               784.086
# Old_dead_time_%                                23.99                18.353
#
#                                                    4                     5  \
# Filename                        20231205_185132_.txt  20231205_185136_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                         2047.0                2047.0
# Median_gap_us                                 4204.5                4141.5
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.238                  0.24
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                     4209.319              4168.046
# dead_vs_expectation                            3.209                 3.168
# dead_time_due_to_gaps                          1.056                 1.036
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                 4.854                 4.788
# Number_of_large_gaps                             701                   564
# Smallest_gap_us                               3850.5                3868.0
# Sum_of_gaps_larger_than_med_ms              1192.636              1736.942
# Old_dead_time_%                               28.333                41.673
#
#                                                    6
# Filename                        20231205_185140_.txt
# Samples_Averaged                                  20
# Inter_Sample_delay_us                             50
# Inter_Average_delay_us                          1500
# Number_of_samples                                423
# Number_of_gaps                                   422
# Expected_sample_time_us                         1000
# Actual_sample_time_us                         2047.0
# Median_gap_us                                4184.75
# Expected_freq_KHz                                1.0
# Actual_freq_KHz                                0.239
# Expected_file_duration_ms                      423.0
# Actual_file_duration_ms                     1767.537
# dead_vs_expectation                            3.179
# dead_time_due_to_gaps                          1.041
# OLD_ANALYSIS                                       -
# Largest_gap_ms                                4.6735
# Number_of_large_gaps                             272
# Smallest_gap_us                               3865.5
# Sum_of_gaps_larger_than_med_ms               598.607
# Old_dead_time_%                               33.867

# %%
result = pd.concat([df_M0_50_50_4,df_M0_50_500_4,df_M0_50_1500_4], axis=1, ignore_index=True)

result
# Out:
#                                                   0                     1   \
# Filename                        20231205_184828_.txt  20231205_184829_.txt
# Samples_Averaged                                   4                     4
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                            50                    50
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                          200                   200
# Actual_sample_time_us                          409.0                 409.0
# Median_gap_us                                  813.0                 792.0
# Expected_freq_KHz                                5.0                   5.0
# Actual_freq_KHz                                 1.21                 1.251
# Expected_file_duration_ms                      200.0                 200.0
# Actual_file_duration_ms                      826.524                799.54
# dead_vs_expectation                            3.133                 2.998
# dead_time_due_to_gaps                          1.021                 0.955
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                1.3995                1.0045
# Number_of_large_gaps                             464                   270
# Smallest_gap_us                                749.0                 750.0
# Sum_of_gaps_larger_than_med_ms               420.474               569.408
# Old_dead_time_%                               50.872                71.217
#
#                                                   2                     3   \
# Filename                        20231205_184830_.txt  20231205_184831_.txt
# Samples_Averaged                                   4                     4
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                            50                    50
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                          200                   200
# Actual_sample_time_us                          409.0                 410.0
# Median_gap_us                                  800.0                 801.0
# Expected_freq_KHz                                5.0                   5.0
# Actual_freq_KHz                                1.223                 1.211
# Expected_file_duration_ms                      200.0                 200.0
# Actual_file_duration_ms                      817.804               826.088
# dead_vs_expectation                            3.089                  3.13
# dead_time_due_to_gaps                            1.0                 1.015
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                1.1685                1.2685
# Number_of_large_gaps                             401                   414
# Smallest_gap_us                                748.5                 748.0
# Sum_of_gaps_larger_than_med_ms               467.562               457.169
# Old_dead_time_%                               57.173                55.341
#
#                                                   4                     5   \
# Filename                        20231205_184832_.txt  20231205_184833_.txt
# Samples_Averaged                                   4                     4
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                            50                    50
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                          200                   200
# Actual_sample_time_us                          409.0                 409.0
# Median_gap_us                                  810.5                 796.5
# Expected_freq_KHz                                5.0                   5.0
# Actual_freq_KHz                                1.208                 1.223
# Expected_file_duration_ms                      200.0                 200.0
# Actual_file_duration_ms                      827.874               817.753
# dead_vs_expectation                            3.139                 3.089
# dead_time_due_to_gaps                          1.024                 0.999
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                1.2065                1.5275
# Number_of_large_gaps                             462                   345
# Smallest_gap_us                                748.5                 748.5
# Sum_of_gaps_larger_than_med_ms                420.93               510.464
# Old_dead_time_%                               50.845                62.423
#
#                                                   6                     7   \
# Filename                        20231205_184834_.txt  20231205_184835_.txt
# Samples_Averaged                                   4                     4
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                            50                    50
# Number_of_samples                               1000                   117
# Number_of_gaps                                   999                   116
# Expected_sample_time_us                          200                   200
# Actual_sample_time_us                          409.0                 409.0
# Median_gap_us                                  799.5                 777.0
# Expected_freq_KHz                                5.0                   5.0
# Actual_freq_KHz                                1.209                 1.277
# Expected_file_duration_ms                      200.0                  23.4
# Actual_file_duration_ms                      827.234                91.644
# dead_vs_expectation                            3.136                 2.916
# dead_time_due_to_gaps                          1.023                 0.915
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                1.3065                 0.989
# Number_of_large_gaps                             391                    22
# Smallest_gap_us                                748.5                 748.0
# Sum_of_gaps_larger_than_med_ms               475.416                72.808
# Old_dead_time_%                               57.471                79.446
#
#                                                   8                     9   \
# Filename                        20231205_184952_.txt  20231205_184955_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                           500                   500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                         2047.0                2047.0
# Median_gap_us                                 3172.5                3210.5
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.315                 0.311
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                      3173.15              3215.611
# dead_vs_expectation                            2.173                 2.216
# dead_time_due_to_gaps                           0.55                 0.571
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                3.6635                3.6855
# Number_of_large_gaps                               0                     0
# Smallest_gap_us                               2853.0                2864.5
# Sum_of_gaps_larger_than_med_ms               3173.15              3215.611
# Old_dead_time_%                                100.0                 100.0
#
#                                 ...                    12  \
# Filename                        ...  20231205_185005_.txt
# Samples_Averaged                ...                    20
# Inter_Sample_delay_us           ...                    50
# Inter_Average_delay_us          ...                   500
# Number_of_samples               ...                  1000
# Number_of_gaps                  ...                   999
# Expected_sample_time_us         ...                  1000
# Actual_sample_time_us           ...                2047.0
# Median_gap_us                   ...                3222.0
# Expected_freq_KHz               ...                   1.0
# Actual_freq_KHz                 ...                 0.311
# Expected_file_duration_ms       ...                1000.0
# Actual_file_duration_ms         ...              3217.995
# dead_vs_expectation             ...                 2.218
# dead_time_due_to_gaps           ...                 0.572
# OLD_ANALYSIS                    ...                     -
# Largest_gap_ms                  ...                3.7485
# Number_of_large_gaps            ...                     0
# Smallest_gap_us                 ...                2848.5
# Sum_of_gaps_larger_than_med_ms  ...              3217.995
# Old_dead_time_%                 ...                 100.0
#
#                                                   13                    14  \
# Filename                        20231205_185008_.txt  20231205_185011_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                           500                   500
# Number_of_samples                               1000                   422
# Number_of_gaps                                   999                   421
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                         2047.0                2047.0
# Median_gap_us                                 3220.5                3161.5
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                 0.31                 0.317
# Expected_file_duration_ms                     1000.0                 422.0
# Actual_file_duration_ms                     3225.049               1331.68
# dead_vs_expectation                            2.225                 2.156
# dead_time_due_to_gaps                          0.576                 0.542
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                3.8095                3.6425
# Number_of_large_gaps                               0                     0
# Smallest_gap_us                               2844.5                2859.0
# Sum_of_gaps_larger_than_med_ms              3225.049               1331.68
# Old_dead_time_%                                100.0                 100.0
#
#                                                   15                    16  \
# Filename                        20231205_185115_.txt  20231205_185119_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                         2047.0                2047.0
# Median_gap_us                                 4233.0                4225.5
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.236                 0.236
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                     4235.409              4237.168
# dead_vs_expectation                            3.235                 3.237
# dead_time_due_to_gaps                          1.069                  1.07
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                4.9785                4.8225
# Number_of_large_gaps                             747                   747
# Smallest_gap_us                               3847.0                3851.0
# Sum_of_gaps_larger_than_med_ms              1008.458               1007.71
# Old_dead_time_%                                23.81                23.783
#
#                                                   17                    18  \
# Filename                        20231205_185124_.txt  20231205_185128_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                         2047.0                2047.0
# Median_gap_us                                 4247.0                4272.0
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.236                 0.234
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                     4243.448              4272.176
# dead_vs_expectation                            3.243                 3.272
# dead_time_due_to_gaps                          1.073                 1.087
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                 4.943                4.9315
# Number_of_large_gaps                             745                   803
# Smallest_gap_us                               3864.5                3871.0
# Sum_of_gaps_larger_than_med_ms              1017.988               784.086
# Old_dead_time_%                                23.99                18.353
#
#                                                   19                    20  \
# Filename                        20231205_185132_.txt  20231205_185136_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                         2047.0                2047.0
# Median_gap_us                                 4204.5                4141.5
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.238                  0.24
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                     4209.319              4168.046
# dead_vs_expectation                            3.209                 3.168
# dead_time_due_to_gaps                          1.056                 1.036
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                 4.854                 4.788
# Number_of_large_gaps                             701                   564
# Smallest_gap_us                               3850.5                3868.0
# Sum_of_gaps_larger_than_med_ms              1192.636              1736.942
# Old_dead_time_%                               28.333                41.673
#
#                                                   21
# Filename                        20231205_185140_.txt
# Samples_Averaged                                  20
# Inter_Sample_delay_us                             50
# Inter_Average_delay_us                          1500
# Number_of_samples                                423
# Number_of_gaps                                   422
# Expected_sample_time_us                         1000
# Actual_sample_time_us                         2047.0
# Median_gap_us                                4184.75
# Expected_freq_KHz                                1.0
# Actual_freq_KHz                                0.239
# Expected_file_duration_ms                      423.0
# Actual_file_duration_ms                     1767.537
# dead_vs_expectation                            3.179
# dead_time_due_to_gaps                          1.041
# OLD_ANALYSIS                                       -
# Largest_gap_ms                                4.6735
# Number_of_large_gaps                             272
# Smallest_gap_us                               3865.5
# Sum_of_gaps_larger_than_med_ms               598.607
# Old_dead_time_%                               33.867
#
# [21 rows x 22 columns]
