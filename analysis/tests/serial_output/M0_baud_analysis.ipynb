# %%
import os
import pandas as pd
from analysis_IRIS import analyze, quickLook

directory_path = 'data/M0_baud/230400/50_1500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                              inter_sample_delay=50,
                              inter_average_delay=1500,
                              samples_averaged=20)
        quickLook(file_path, save_png=False, plot_all=False, plot_hist_sampletime=True)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_230400 = pd.DataFrame(all_dictionaries).transpose()
df_M0_230400

# 1.5 ms gap & tgf started in the gap causes an issue
# inter sample = 100 us
# 2 ms over which collect 
# inter av = 500 us 
# 20 samples
# Out:
#                                                    0                     1  \
# Filename                        20231210_155736_.txt  20231210_155737_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                          854.0                 854.0
# Median_gap_us                                 1354.0                1342.0
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.701                 0.699
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                     1426.806              1430.908
# dead_vs_expectation                            0.427                 0.431
# dead_time_due_to_gaps                          0.671                 0.676
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                2.6715                2.5555
# Number_of_large_gaps                              92                   125
# Smallest_gap_us                               1199.0                1193.0
# Sum_of_gaps_larger_than_med_ms              1256.986               1187.66
# Old_dead_time_%                               88.098                  83.0
#
#                                                    2                     3  \
# Filename                        20231210_155739_.txt  20231210_155740_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                          854.0                 854.0
# Median_gap_us                                 1509.0                1564.0
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.633                 0.613
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                      1579.79               1630.54
# dead_vs_expectation                             0.58                 0.631
# dead_time_due_to_gaps                           0.85                 0.909
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                 2.771                2.7675
# Number_of_large_gaps                             278                   362
# Smallest_gap_us                               1198.0                1201.0
# Sum_of_gaps_larger_than_med_ms              1031.754               917.447
# Old_dead_time_%                                65.31                56.266
#
#                                                    4                     5  \
# Filename                        20231210_155742_.txt  20231210_155743_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                          854.0                 854.0
# Median_gap_us                                 1491.5                1610.5
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                 0.64                 0.605
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                     1561.636              1653.796
# dead_vs_expectation                            0.562                 0.654
# dead_time_due_to_gaps                          0.829                 0.937
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                2.7135                2.7345
# Number_of_large_gaps                             292                   428
# Smallest_gap_us                               1194.5                1196.5
# Sum_of_gaps_larger_than_med_ms               995.696                821.12
# Old_dead_time_%                                63.76                49.651
#
#                                                    6
# Filename                        20231210_155745_.txt
# Samples_Averaged                                  20
# Inter_Sample_delay_us                             50
# Inter_Average_delay_us                          1500
# Number_of_samples                                905
# Number_of_gaps                                   904
# Expected_sample_time_us                         1000
# Actual_sample_time_us                          854.0
# Median_gap_us                                 1554.5
# Expected_freq_KHz                                1.0
# Actual_freq_KHz                                 0.62
# Expected_file_duration_ms                      905.0
# Actual_file_duration_ms                      1459.64
# dead_vs_expectation                            0.613
# dead_time_due_to_gaps                          0.889
# OLD_ANALYSIS                                       -
# Largest_gap_ms                                 2.777
# Number_of_large_gaps                             334
# Smallest_gap_us                               1195.5
# Sum_of_gaps_larger_than_med_ms               810.986
# Old_dead_time_%                               55.561

# %%
import os
import pandas as pd
from analysis_IRIS import analyze, quickLook

directory_path = 'data/M0_baud/250_000/50_1500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                              inter_sample_delay=50,
                              inter_average_delay=1500,
                              samples_averaged=20)
        quickLook(file_path, save_png=False, plot_all=False, plot_hist_sampletime=True)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_250_000 = pd.DataFrame(all_dictionaries).transpose()
df_M0_250_000

# 1.5 ms gap & tgf started in the gap causes an issue
# inter sample = 100 us
# 2 ms over which collect 
# inter av = 500 us 
# 20 samples
# Out:
#                                                    0                     1  \
# Filename                        20231210_160909_.txt  20231210_160910_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                                999                  1000
# Number_of_gaps                                   998                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                          854.0                 854.0
# Median_gap_us                                 1533.0                1532.0
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.628                  0.62
# Expected_file_duration_ms                      999.0                1000.0
# Actual_file_duration_ms                     1591.624              1612.159
# dead_vs_expectation                            0.593                 0.612
# dead_time_due_to_gaps                          0.866                 0.888
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                 2.766                2.6585
# Number_of_large_gaps                             309                   344
# Smallest_gap_us                               1201.5                1196.0
# Sum_of_gaps_larger_than_med_ms               991.253               922.826
# Old_dead_time_%                               62.279                57.242
#
#                                                    2                     3  \
# Filename                        20231210_160912_.txt  20231210_160913_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                          854.0                 854.0
# Median_gap_us                                 1511.0                1537.0
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                 0.63                 0.609
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                     1586.576              1640.778
# dead_vs_expectation                            0.587                 0.641
# dead_time_due_to_gaps                          0.858                 0.921
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                2.6905                 2.845
# Number_of_large_gaps                             309                   398
# Smallest_gap_us                               1203.5                1196.5
# Sum_of_gaps_larger_than_med_ms               971.184                831.47
# Old_dead_time_%                               61.213                50.675
#
#                                                    4                     5  \
# Filename                        20231210_160915_.txt  20231210_160917_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                          854.0                 854.0
# Median_gap_us                                 1590.5                1401.0
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.599                 0.653
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                     1669.014              1532.449
# dead_vs_expectation                            0.669                 0.532
# dead_time_due_to_gaps                          0.954                 0.794
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                2.8735                 2.823
# Number_of_large_gaps                             428                   224
# Smallest_gap_us                               1187.5                1199.0
# Sum_of_gaps_larger_than_med_ms               810.272              1064.408
# Old_dead_time_%                               48.548                69.458
#
#                                                    6                     7
# Filename                        20231210_160918_.txt  20231210_160920_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                               1000                   647
# Number_of_gaps                                   999                   646
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                          854.0                 854.0
# Median_gap_us                                 1514.5               1569.75
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.618                 0.594
# Expected_file_duration_ms                     1000.0                 647.0
# Actual_file_duration_ms                     1618.902              1088.603
# dead_vs_expectation                            0.619                 0.683
# dead_time_due_to_gaps                          0.896                  0.97
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                2.8215                2.8165
# Number_of_large_gaps                             342                   255
# Smallest_gap_us                               1194.0                1209.0
# Sum_of_gaps_larger_than_med_ms               926.672               567.408
# Old_dead_time_%                               57.241                52.123

# %%
import os
import pandas as pd
from analysis_IRIS import analyze, quickLook

directory_path = 'data/M0_baud/115200/50_1500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                              inter_sample_delay=50,
                              inter_average_delay=1500,
                              samples_averaged=20)
        quickLook(file_path, save_png=False, plot_all=False, plot_hist_sampletime=True)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_115200 = pd.DataFrame(all_dictionaries).transpose()
df_M0_115200
# Out:
#                                                    0                     1  \
# Filename                        20231210_155312_.txt  20231210_155313_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                                999                  1000
# Number_of_gaps                                   998                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                          854.0                 854.0
# Median_gap_us                                1310.25                1307.5
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.709                 0.724
# Expected_file_duration_ms                      999.0                1000.0
# Actual_file_duration_ms                     1409.131              1381.511
# dead_vs_expectation                            0.411                 0.382
# dead_time_due_to_gaps                          0.652                 0.618
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                2.6945                 2.692
# Number_of_large_gaps                             112                    84
# Smallest_gap_us                               1188.0                1194.0
# Sum_of_gaps_larger_than_med_ms              1199.556              1220.232
# Old_dead_time_%                               85.127                88.326
#
#                                                    2                     3  \
# Filename                        20231210_155315_.txt  20231210_155316_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                          854.0                 854.0
# Median_gap_us                                 1381.5                1490.5
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.716                 0.646
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                     1395.772               1546.84
# dead_vs_expectation                            0.396                 0.547
# dead_time_due_to_gaps                          0.634                 0.811
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                 2.633                 2.807
# Number_of_large_gaps                              12                   224
# Smallest_gap_us                               1187.5                1189.0
# Sum_of_gaps_larger_than_med_ms              1371.766              1102.989
# Old_dead_time_%                                98.28                71.306
#
#                                                    4                     5
# Filename                        20231210_155318_.txt  20231210_155319_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                               1000                   690
# Number_of_gaps                                   999                   689
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                          854.0                 854.0
# Median_gap_us                                 1501.0                1397.5
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.622                 0.663
# Expected_file_duration_ms                     1000.0                 690.0
# Actual_file_duration_ms                     1607.698              1041.461
# dead_vs_expectation                            0.608                 0.509
# dead_time_due_to_gaps                          0.883                 0.767
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                 2.795                2.7805
# Number_of_large_gaps                             333                   160
# Smallest_gap_us                               1189.0                1189.5
# Sum_of_gaps_larger_than_med_ms               935.226               722.258
# Old_dead_time_%                               58.172                69.351

# %%
import os
import pandas as pd
from analysis_IRIS import analyze, quickLook

directory_path = 'data/M0_baud/460800/50_1500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                              inter_sample_delay=50,
                              inter_average_delay=1500,
                              samples_averaged=20)
        quickLook(file_path, save_png=False, plot_all=False, plot_hist_sampletime=True)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_460800 = pd.DataFrame(all_dictionaries).transpose()
df_M0_460800

# 1.5 ms gap & tgf started in the gap causes an issue
# inter sample = 100 us
# 2 ms over which collect 
# inter av = 500 us 
# 20 samples
# Out:
#                                                    0                     1  \
# Filename                        20231210_161126_.txt  20231210_161127_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                          854.0                 854.0
# Median_gap_us                                 1521.0                1530.0
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.644                 0.614
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                     1552.432              1627.384
# dead_vs_expectation                            0.552                 0.627
# dead_time_due_to_gaps                          0.818                 0.906
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                 2.746                 2.793
# Number_of_large_gaps                             211                   354
# Smallest_gap_us                               1193.5                1195.0
# Sum_of_gaps_larger_than_med_ms              1136.176               908.236
# Old_dead_time_%                               73.187                 55.81
#
#                                                    2                     3  \
# Filename                        20231210_161129_.txt  20231210_161130_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                          854.0                 854.0
# Median_gap_us                                 1622.0                1519.5
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.604                 0.639
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                     1655.471              1564.004
# dead_vs_expectation                            0.655                 0.564
# dead_time_due_to_gaps                          0.938                 0.831
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                2.8365                2.8535
# Number_of_large_gaps                             404                   291
# Smallest_gap_us                               1199.0                1194.5
# Sum_of_gaps_larger_than_med_ms                859.47               1004.36
# Old_dead_time_%                               51.917                64.217
#
#                                                    4                     5  \
# Filename                        20231210_161132_.txt  20231210_161134_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                          854.0                 854.0
# Median_gap_us                                 1519.0                1524.5
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.628                 0.638
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                     1591.328              1566.331
# dead_vs_expectation                            0.591                 0.566
# dead_time_due_to_gaps                          0.863                 0.834
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                2.8045                 2.692
# Number_of_large_gaps                             326                   261
# Smallest_gap_us                               1193.5                1207.0
# Sum_of_gaps_larger_than_med_ms               957.992              1058.936
# Old_dead_time_%                               60.201                67.606
#
#                                                    6                     7  \
# Filename                        20231210_161135_.txt  20231210_161137_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                          854.0                 854.0
# Median_gap_us                                 1453.0                1568.5
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                 0.65                 0.619
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                     1539.544              1615.144
# dead_vs_expectation                             0.54                 0.615
# dead_time_due_to_gaps                          0.803                 0.891
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                2.7855                 2.791
# Number_of_large_gaps                             235                   392
# Smallest_gap_us                               1195.0                1192.5
# Sum_of_gaps_larger_than_med_ms              1068.534               864.948
# Old_dead_time_%                               69.406                53.552
#
#                                                    8
# Filename                        20231210_161138_.txt
# Samples_Averaged                                  20
# Inter_Sample_delay_us                             50
# Inter_Average_delay_us                          1500
# Number_of_samples                                 21
# Number_of_gaps                                    20
# Expected_sample_time_us                         1000
# Actual_sample_time_us                          854.0
# Median_gap_us                                 1526.5
# Expected_freq_KHz                                1.0
# Actual_freq_KHz                                0.666
# Expected_file_duration_ms                       21.0
# Actual_file_duration_ms                       31.526
# dead_vs_expectation                            0.501
# dead_time_due_to_gaps                          0.758
# OLD_ANALYSIS                                       -
# Largest_gap_ms                                1.9975
# Number_of_large_gaps                               5
# Smallest_gap_us                               1263.5
# Sum_of_gaps_larger_than_med_ms                22.138
# Old_dead_time_%                               70.223

# %%
import os
import pandas as pd
from analysis_IRIS import analyze, quickLook

directory_path = 'data/M0_baud/500_000/50_1500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                              inter_sample_delay=50,
                              inter_average_delay=1500,
                              samples_averaged=20)
        quickLook(file_path, save_png=False, plot_all=False, plot_hist_sampletime=True)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_500_000 = pd.DataFrame(all_dictionaries).transpose()
df_M0_500_000
# Out:
#                                                    0                     1  \
# Filename                        20231210_161831_.txt  20231210_161832_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                                999                  1000
# Number_of_gaps                                   998                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                          854.0                 854.0
# Median_gap_us                                 1541.5                1576.5
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.629                 0.603
# Expected_file_duration_ms                      999.0                1000.0
# Actual_file_duration_ms                     1588.782              1657.098
# dead_vs_expectation                             0.59                 0.657
# dead_time_due_to_gaps                          0.862                  0.94
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                2.7045                2.7195
# Number_of_large_gaps                             278                   383
# Smallest_gap_us                               1200.0                1199.5
# Sum_of_gaps_larger_than_med_ms              1040.862               877.584
# Old_dead_time_%                               65.513                52.959
#
#                                                    2                     3  \
# Filename                        20231210_161834_.txt  20231210_161836_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                          854.0                 854.0
# Median_gap_us                                 1668.5                1575.0
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.586                 0.615
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                     1707.714              1625.132
# dead_vs_expectation                            0.708                 0.625
# dead_time_due_to_gaps                            1.0                 0.903
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                2.8755                2.7755
# Number_of_large_gaps                             477                   364
# Smallest_gap_us                               1189.5                1205.5
# Sum_of_gaps_larger_than_med_ms               751.236               912.058
# Old_dead_time_%                               43.991                56.122
#
#                                                    4
# Filename                        20231210_161837_.txt
# Samples_Averaged                                  20
# Inter_Sample_delay_us                             50
# Inter_Average_delay_us                          1500
# Number_of_samples                                268
# Number_of_gaps                                   267
# Expected_sample_time_us                         1000
# Actual_sample_time_us                          854.0
# Median_gap_us                                 1513.5
# Expected_freq_KHz                                1.0
# Actual_freq_KHz                                0.625
# Expected_file_duration_ms                      268.0
# Actual_file_duration_ms                      428.761
# dead_vs_expectation                              0.6
# dead_time_due_to_gaps                          0.873
# OLD_ANALYSIS                                       -
# Largest_gap_ms                                2.6085
# Number_of_large_gaps                              74
# Smallest_gap_us                               1194.0
# Sum_of_gaps_larger_than_med_ms               274.964
# Old_dead_time_%                                64.13

# %%
result = pd.concat([df_M0_230400,df_M0_250_000,df_M0_115200,df_M0_460800,df_M0_500_000], axis=1, ignore_index=True)

result
# Out:
#                                                   0                     1   \
# Filename                        20231210_155736_.txt  20231210_155737_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                          854.0                 854.0
# Median_gap_us                                 1354.0                1342.0
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.701                 0.699
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                     1426.806              1430.908
# dead_vs_expectation                            0.427                 0.431
# dead_time_due_to_gaps                          0.671                 0.676
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                2.6715                2.5555
# Number_of_large_gaps                              92                   125
# Smallest_gap_us                               1199.0                1193.0
# Sum_of_gaps_larger_than_med_ms              1256.986               1187.66
# Old_dead_time_%                               88.098                  83.0
#
#                                                   2                     3   \
# Filename                        20231210_155739_.txt  20231210_155740_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                          854.0                 854.0
# Median_gap_us                                 1509.0                1564.0
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.633                 0.613
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                      1579.79               1630.54
# dead_vs_expectation                             0.58                 0.631
# dead_time_due_to_gaps                           0.85                 0.909
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                 2.771                2.7675
# Number_of_large_gaps                             278                   362
# Smallest_gap_us                               1198.0                1201.0
# Sum_of_gaps_larger_than_med_ms              1031.754               917.447
# Old_dead_time_%                                65.31                56.266
#
#                                                   4                     5   \
# Filename                        20231210_155742_.txt  20231210_155743_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                          854.0                 854.0
# Median_gap_us                                 1491.5                1610.5
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                 0.64                 0.605
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                     1561.636              1653.796
# dead_vs_expectation                            0.562                 0.654
# dead_time_due_to_gaps                          0.829                 0.937
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                2.7135                2.7345
# Number_of_large_gaps                             292                   428
# Smallest_gap_us                               1194.5                1196.5
# Sum_of_gaps_larger_than_med_ms               995.696                821.12
# Old_dead_time_%                                63.76                49.651
#
#                                                   6                     7   \
# Filename                        20231210_155745_.txt  20231210_160909_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                                905                   999
# Number_of_gaps                                   904                   998
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                          854.0                 854.0
# Median_gap_us                                 1554.5                1533.0
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                 0.62                 0.628
# Expected_file_duration_ms                      905.0                 999.0
# Actual_file_duration_ms                      1459.64              1591.624
# dead_vs_expectation                            0.613                 0.593
# dead_time_due_to_gaps                          0.889                 0.866
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                 2.777                 2.766
# Number_of_large_gaps                             334                   309
# Smallest_gap_us                               1195.5                1201.5
# Sum_of_gaps_larger_than_med_ms               810.986               991.253
# Old_dead_time_%                               55.561                62.279
#
#                                                   8                     9   \
# Filename                        20231210_160910_.txt  20231210_160912_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                          854.0                 854.0
# Median_gap_us                                 1532.0                1511.0
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                 0.62                  0.63
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                     1612.159              1586.576
# dead_vs_expectation                            0.612                 0.587
# dead_time_due_to_gaps                          0.888                 0.858
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                2.6585                2.6905
# Number_of_large_gaps                             344                   309
# Smallest_gap_us                               1196.0                1203.5
# Sum_of_gaps_larger_than_med_ms               922.826               971.184
# Old_dead_time_%                               57.242                61.213
#
#                                 ...                    25  \
# Filename                        ...  20231210_161132_.txt
# Samples_Averaged                ...                    20
# Inter_Sample_delay_us           ...                    50
# Inter_Average_delay_us          ...                  1500
# Number_of_samples               ...                  1000
# Number_of_gaps                  ...                   999
# Expected_sample_time_us         ...                  1000
# Actual_sample_time_us           ...                 854.0
# Median_gap_us                   ...                1519.0
# Expected_freq_KHz               ...                   1.0
# Actual_freq_KHz                 ...                 0.628
# Expected_file_duration_ms       ...                1000.0
# Actual_file_duration_ms         ...              1591.328
# dead_vs_expectation             ...                 0.591
# dead_time_due_to_gaps           ...                 0.863
# OLD_ANALYSIS                    ...                     -
# Largest_gap_ms                  ...                2.8045
# Number_of_large_gaps            ...                   326
# Smallest_gap_us                 ...                1193.5
# Sum_of_gaps_larger_than_med_ms  ...               957.992
# Old_dead_time_%                 ...                60.201
#
#                                                   26                    27  \
# Filename                        20231210_161134_.txt  20231210_161135_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                          854.0                 854.0
# Median_gap_us                                 1524.5                1453.0
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.638                  0.65
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                     1566.331              1539.544
# dead_vs_expectation                            0.566                  0.54
# dead_time_due_to_gaps                          0.834                 0.803
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                 2.692                2.7855
# Number_of_large_gaps                             261                   235
# Smallest_gap_us                               1207.0                1195.0
# Sum_of_gaps_larger_than_med_ms              1058.936              1068.534
# Old_dead_time_%                               67.606                69.406
#
#                                                   28                    29  \
# Filename                        20231210_161137_.txt  20231210_161138_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                               1000                    21
# Number_of_gaps                                   999                    20
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                          854.0                 854.0
# Median_gap_us                                 1568.5                1526.5
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.619                 0.666
# Expected_file_duration_ms                     1000.0                  21.0
# Actual_file_duration_ms                     1615.144                31.526
# dead_vs_expectation                            0.615                 0.501
# dead_time_due_to_gaps                          0.891                 0.758
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                 2.791                1.9975
# Number_of_large_gaps                             392                     5
# Smallest_gap_us                               1192.5                1263.5
# Sum_of_gaps_larger_than_med_ms               864.948                22.138
# Old_dead_time_%                               53.552                70.223
#
#                                                   30                    31  \
# Filename                        20231210_161831_.txt  20231210_161832_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                                999                  1000
# Number_of_gaps                                   998                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                          854.0                 854.0
# Median_gap_us                                 1541.5                1576.5
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.629                 0.603
# Expected_file_duration_ms                      999.0                1000.0
# Actual_file_duration_ms                     1588.782              1657.098
# dead_vs_expectation                             0.59                 0.657
# dead_time_due_to_gaps                          0.862                  0.94
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                2.7045                2.7195
# Number_of_large_gaps                             278                   383
# Smallest_gap_us                               1200.0                1199.5
# Sum_of_gaps_larger_than_med_ms              1040.862               877.584
# Old_dead_time_%                               65.513                52.959
#
#                                                   32                    33  \
# Filename                        20231210_161834_.txt  20231210_161836_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                          854.0                 854.0
# Median_gap_us                                 1668.5                1575.0
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.586                 0.615
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                     1707.714              1625.132
# dead_vs_expectation                            0.708                 0.625
# dead_time_due_to_gaps                            1.0                 0.903
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                2.8755                2.7755
# Number_of_large_gaps                             477                   364
# Smallest_gap_us                               1189.5                1205.5
# Sum_of_gaps_larger_than_med_ms               751.236               912.058
# Old_dead_time_%                               43.991                56.122
#
#                                                   34
# Filename                        20231210_161837_.txt
# Samples_Averaged                                  20
# Inter_Sample_delay_us                             50
# Inter_Average_delay_us                          1500
# Number_of_samples                                268
# Number_of_gaps                                   267
# Expected_sample_time_us                         1000
# Actual_sample_time_us                          854.0
# Median_gap_us                                 1513.5
# Expected_freq_KHz                                1.0
# Actual_freq_KHz                                0.625
# Expected_file_duration_ms                      268.0
# Actual_file_duration_ms                      428.761
# dead_vs_expectation                              0.6
# dead_time_due_to_gaps                          0.873
# OLD_ANALYSIS                                       -
# Largest_gap_ms                                2.6085
# Number_of_large_gaps                              74
# Smallest_gap_us                               1194.0
# Sum_of_gaps_larger_than_med_ms               274.964
# Old_dead_time_%                                64.13
#
# [21 rows x 35 columns]

# %% [markdown]
# # Conclusions
# As we increase the baud rate the data is more sporadic

# %% [markdown]
# # Quick Look

# %%
subdirs = ["230400","250_000","115200","460800","500_000"]

directory_path = f'data_M0_baud/{subdirs[4]}/50_1500_20/'
print(directory_path)

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        quickLook(file_path,samples_to_av=20)
# Out:
# data_M0_baud/500_000/50_1500_20/
