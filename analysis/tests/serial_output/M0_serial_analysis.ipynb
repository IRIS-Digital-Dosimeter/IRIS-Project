# %%
import os
import pandas as pd
from analysis_IRIS import analyze, quickLook

directory_path = 'data/M0/50_50_4/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                              inter_sample_delay=50,
                              inter_average_delay=50,
                              samples_averaged=4)
        quickLook(file_path, save_png=False, plot_all=False, plot_hist_sampletime=True)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_50_50_4 = pd.DataFrame(all_dictionaries).transpose()
df_M0_50_50_4
# Out:
#                                                    0                     1  \
# Filename                        20231205_174514_.txt  20231205_174515_.txt
# Samples_Averaged                                   4                     4
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                            50                    50
# Number_of_samples                                999                  1000
# Number_of_gaps                                   998                   999
# Expected_sample_time_us                          200                   200
# Actual_sample_time_us                          385.0                 385.0
# Median_gap_us                                 843.25                 839.5
# Expected_freq_KHz                                5.0                   5.0
# Actual_freq_KHz                                1.177                 1.176
# Expected_file_duration_ms                      199.8                 200.0
# Actual_file_duration_ms                      849.037               850.393
# dead_vs_expectation                            3.249                 3.252
# dead_time_due_to_gaps                          1.207                 1.209
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                1.2505                1.3315
# Number_of_large_gaps                             993                   992
# Smallest_gap_us                                764.5                 765.0
# Sum_of_gaps_larger_than_med_ms                 3.841                 5.378
# Old_dead_time_%                                0.452                 0.632
#
#                                                    2                     3  \
# Filename                        20231205_174516_.txt  20231205_174517_.txt
# Samples_Averaged                                   4                     4
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                            50                    50
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                          200                   200
# Actual_sample_time_us                          385.0                 385.0
# Median_gap_us                                  838.5                 840.0
# Expected_freq_KHz                                5.0                   5.0
# Actual_freq_KHz                                1.187                 1.172
# Expected_file_duration_ms                      200.0                 200.0
# Actual_file_duration_ms                      842.694               853.236
# dead_vs_expectation                            3.213                 3.266
# dead_time_due_to_gaps                          1.189                 1.216
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                1.2595                1.4325
# Number_of_large_gaps                             993                   987
# Smallest_gap_us                                765.0                 762.0
# Sum_of_gaps_larger_than_med_ms                 4.598                 9.211
# Old_dead_time_%                                0.546                  1.08
#
#                                                    4                     5  \
# Filename                        20231205_174518_.txt  20231205_174519_.txt
# Samples_Averaged                                   4                     4
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                            50                    50
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                          200                   200
# Actual_sample_time_us                          385.0                 385.0
# Median_gap_us                                  841.0                 840.5
# Expected_freq_KHz                                5.0                   5.0
# Actual_freq_KHz                                1.174                 1.162
# Expected_file_duration_ms                      200.0                 200.0
# Actual_file_duration_ms                      851.588               860.479
# dead_vs_expectation                            3.258                 3.302
# dead_time_due_to_gaps                          1.212                 1.235
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                1.2625                1.6235
# Number_of_large_gaps                             988                   988
# Smallest_gap_us                                763.5                 767.5
# Sum_of_gaps_larger_than_med_ms                 8.452                  8.46
# Old_dead_time_%                                0.992                 0.983
#
#                                                    6                     7  \
# Filename                        20231205_174520_.txt  20231205_174521_.txt
# Samples_Averaged                                   4                     4
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                            50                    50
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                          200                   200
# Actual_sample_time_us                          385.0                 385.0
# Median_gap_us                                  837.5                 832.5
# Expected_freq_KHz                                5.0                   5.0
# Actual_freq_KHz                                1.184                 1.197
# Expected_file_duration_ms                      200.0                 200.0
# Actual_file_duration_ms                       844.95               835.592
# dead_vs_expectation                            3.225                 3.178
# dead_time_due_to_gaps                          1.195                  1.17
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                 1.247                 1.148
# Number_of_large_gaps                             991                   988
# Smallest_gap_us                                765.0                 766.0
# Sum_of_gaps_larger_than_med_ms                 6.145                  8.45
# Old_dead_time_%                                0.727                 1.011
#
#                                                    8
# Filename                        20231205_174522_.txt
# Samples_Averaged                                   4
# Inter_Sample_delay_us                             50
# Inter_Average_delay_us                            50
# Number_of_samples                                403
# Number_of_gaps                                   402
# Expected_sample_time_us                          200
# Actual_sample_time_us                          385.0
# Median_gap_us                                  840.0
# Expected_freq_KHz                                5.0
# Actual_freq_KHz                                 1.17
# Expected_file_duration_ms                       80.6
# Actual_file_duration_ms                      344.527
# dead_vs_expectation                            3.275
# dead_time_due_to_gaps                          1.221
# OLD_ANALYSIS                                       -
# Largest_gap_ms                                1.3155
# Number_of_large_gaps                             396
# Smallest_gap_us                                766.5
# Sum_of_gaps_larger_than_med_ms                  4.61
# Old_dead_time_%                                1.338

# %%
import os
import pandas as pd
from analysis_IRIS import analyze, quickLook

directory_path = 'data/M0/50_500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                              inter_sample_delay=50,
                              inter_average_delay=500,
                              samples_averaged=20)
        quickLook(file_path, save_png=False, plot_all=False, plot_hist_sampletime=True)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_50_500_20 = pd.DataFrame(all_dictionaries).transpose()
df_M0_50_500_20
# Out:
#                                                    0                     1  \
# Filename                        20231205_174832_.txt  20231205_174835_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                           500                   500
# Number_of_samples                                999                  1000
# Number_of_gaps                                   998                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                         1901.0                1901.0
# Median_gap_us                                 3037.0                3085.5
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.328                 0.324
# Expected_file_duration_ms                      999.0                1000.0
# Actual_file_duration_ms                     3045.826              3090.153
# dead_vs_expectation                            2.049                  2.09
# dead_time_due_to_gaps                          0.604                 0.626
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                3.7875                 3.664
# Number_of_large_gaps                               0                     0
# Smallest_gap_us                               2739.0                2767.5
# Sum_of_gaps_larger_than_med_ms              3045.826              3090.153
# Old_dead_time_%                                100.0                 100.0
#
#                                                    2                     3  \
# Filename                        20231205_174838_.txt  20231205_174842_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                           500                   500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                         1901.0                1900.0
# Median_gap_us                                 3091.5                3101.0
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.323                 0.324
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                     3095.944              3087.174
# dead_vs_expectation                            2.096                 2.087
# dead_time_due_to_gaps                          0.629                 0.625
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                3.6975                  3.67
# Number_of_large_gaps                               0                     0
# Smallest_gap_us                               2740.5                2722.5
# Sum_of_gaps_larger_than_med_ms              3095.944              3087.174
# Old_dead_time_%                                100.0                 100.0
#
#                                                    4                     5  \
# Filename                        20231205_174845_.txt  20231205_174848_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                           500                   500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                         1901.0                1901.0
# Median_gap_us                                 3080.5                3101.0
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.325                 0.323
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                     3078.378              3096.356
# dead_vs_expectation                            2.078                 2.096
# dead_time_due_to_gaps                          0.619                 0.629
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                 3.775                 3.622
# Number_of_large_gaps                               0                     0
# Smallest_gap_us                               2734.5                2724.5
# Sum_of_gaps_larger_than_med_ms              3078.378              3096.356
# Old_dead_time_%                                100.0                 100.0
#
#                                                    6                     7
# Filename                        20231205_174851_.txt  20231205_174854_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                           500                   500
# Number_of_samples                               1000                   791
# Number_of_gaps                                   999                   790
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                         1901.0                1900.0
# Median_gap_us                                 3105.5                3120.0
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.322                 0.321
# Expected_file_duration_ms                     1000.0                 791.0
# Actual_file_duration_ms                     3105.834               2463.33
# dead_vs_expectation                            2.106                 2.114
# dead_time_due_to_gaps                          0.634                 0.639
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                  3.67                 3.684
# Number_of_large_gaps                               0                     0
# Smallest_gap_us                               2740.0                2774.5
# Sum_of_gaps_larger_than_med_ms              3105.834               2463.33
# Old_dead_time_%                                100.0                 100.0

# %%
import os
import pandas as pd
from analysis_IRIS import analyze, quickLook

directory_path = 'data/M0/50_1500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                              inter_sample_delay=50,
                              inter_average_delay=1500,
                              samples_averaged=20)
        quickLook(file_path, save_png=False, plot_all=False, plot_hist_sampletime=True)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_50_1500_20 = pd.DataFrame(all_dictionaries).transpose()
df_M0_50_1500_20
# Out:
#                                                    0                     1  \
# Filename                        20231205_174211_.txt  20231205_174215_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                         1900.0                1901.0
# Median_gap_us                                 4164.0                4166.0
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                 0.24                  0.24
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                     4168.188              4162.719
# dead_vs_expectation                            3.168                 3.163
# dead_time_due_to_gaps                          1.194                  1.19
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                 4.784                 4.748
# Number_of_large_gaps                             990                   977
# Smallest_gap_us                               3769.0                3754.5
# Sum_of_gaps_larger_than_med_ms                34.108                 83.25
# Old_dead_time_%                                0.818                   2.0
#
#                                                    2                     3  \
# Filename                        20231205_174219_.txt  20231205_174224_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                         1901.0                1901.0
# Median_gap_us                                 4154.5                4171.5
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.241                  0.24
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                      4152.08              4162.269
# dead_vs_expectation                            3.152                 3.162
# dead_time_due_to_gaps                          1.184                  1.19
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                 4.718                  4.73
# Number_of_large_gaps                             981                   973
# Smallest_gap_us                               3739.5                3747.0
# Sum_of_gaps_larger_than_med_ms                67.999                98.302
# Old_dead_time_%                                1.638                 2.362
#
#                                                    4
# Filename                        20231205_174228_.txt
# Samples_Averaged                                  20
# Inter_Sample_delay_us                             50
# Inter_Average_delay_us                          1500
# Number_of_samples                                695
# Number_of_gaps                                   694
# Expected_sample_time_us                         1000
# Actual_sample_time_us                         1901.0
# Median_gap_us                                4161.75
# Expected_freq_KHz                                1.0
# Actual_freq_KHz                                0.241
# Expected_file_duration_ms                      695.0
# Actual_file_duration_ms                     2887.582
# dead_vs_expectation                            3.155
# dead_time_due_to_gaps                          1.186
# OLD_ANALYSIS                                       -
# Largest_gap_ms                                 4.632
# Number_of_large_gaps                             682
# Smallest_gap_us                               3764.5
# Sum_of_gaps_larger_than_med_ms                 45.38
# Old_dead_time_%                                1.572

# %%
result = pd.concat([df_M0_50_50_4,df_M0_50_500_20,df_M0_50_1500_20], axis=1, ignore_index=True)

result
# Out:
#                                                   0                     1   \
# Filename                        20231205_174514_.txt  20231205_174515_.txt
# Samples_Averaged                                   4                     4
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                            50                    50
# Number_of_samples                                999                  1000
# Number_of_gaps                                   998                   999
# Expected_sample_time_us                          200                   200
# Actual_sample_time_us                          385.0                 385.0
# Median_gap_us                                 843.25                 839.5
# Expected_freq_KHz                                5.0                   5.0
# Actual_freq_KHz                                1.177                 1.176
# Expected_file_duration_ms                      199.8                 200.0
# Actual_file_duration_ms                      849.037               850.393
# dead_vs_expectation                            3.249                 3.252
# dead_time_due_to_gaps                          1.207                 1.209
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                1.2505                1.3315
# Number_of_large_gaps                             993                   992
# Smallest_gap_us                                764.5                 765.0
# Sum_of_gaps_larger_than_med_ms                 3.841                 5.378
# Old_dead_time_%                                0.452                 0.632
#
#                                                   2                     3   \
# Filename                        20231205_174516_.txt  20231205_174517_.txt
# Samples_Averaged                                   4                     4
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                            50                    50
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                          200                   200
# Actual_sample_time_us                          385.0                 385.0
# Median_gap_us                                  838.5                 840.0
# Expected_freq_KHz                                5.0                   5.0
# Actual_freq_KHz                                1.187                 1.172
# Expected_file_duration_ms                      200.0                 200.0
# Actual_file_duration_ms                      842.694               853.236
# dead_vs_expectation                            3.213                 3.266
# dead_time_due_to_gaps                          1.189                 1.216
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                1.2595                1.4325
# Number_of_large_gaps                             993                   987
# Smallest_gap_us                                765.0                 762.0
# Sum_of_gaps_larger_than_med_ms                 4.598                 9.211
# Old_dead_time_%                                0.546                  1.08
#
#                                                   4                     5   \
# Filename                        20231205_174518_.txt  20231205_174519_.txt
# Samples_Averaged                                   4                     4
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                            50                    50
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                          200                   200
# Actual_sample_time_us                          385.0                 385.0
# Median_gap_us                                  841.0                 840.5
# Expected_freq_KHz                                5.0                   5.0
# Actual_freq_KHz                                1.174                 1.162
# Expected_file_duration_ms                      200.0                 200.0
# Actual_file_duration_ms                      851.588               860.479
# dead_vs_expectation                            3.258                 3.302
# dead_time_due_to_gaps                          1.212                 1.235
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                1.2625                1.6235
# Number_of_large_gaps                             988                   988
# Smallest_gap_us                                763.5                 767.5
# Sum_of_gaps_larger_than_med_ms                 8.452                  8.46
# Old_dead_time_%                                0.992                 0.983
#
#                                                   6                     7   \
# Filename                        20231205_174520_.txt  20231205_174521_.txt
# Samples_Averaged                                   4                     4
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                            50                    50
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                          200                   200
# Actual_sample_time_us                          385.0                 385.0
# Median_gap_us                                  837.5                 832.5
# Expected_freq_KHz                                5.0                   5.0
# Actual_freq_KHz                                1.184                 1.197
# Expected_file_duration_ms                      200.0                 200.0
# Actual_file_duration_ms                       844.95               835.592
# dead_vs_expectation                            3.225                 3.178
# dead_time_due_to_gaps                          1.195                  1.17
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                 1.247                 1.148
# Number_of_large_gaps                             991                   988
# Smallest_gap_us                                765.0                 766.0
# Sum_of_gaps_larger_than_med_ms                 6.145                  8.45
# Old_dead_time_%                                0.727                 1.011
#
#                                                   8                     9   \
# Filename                        20231205_174522_.txt  20231205_174832_.txt
# Samples_Averaged                                   4                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                            50                   500
# Number_of_samples                                403                   999
# Number_of_gaps                                   402                   998
# Expected_sample_time_us                          200                  1000
# Actual_sample_time_us                          385.0                1901.0
# Median_gap_us                                  840.0                3037.0
# Expected_freq_KHz                                5.0                   1.0
# Actual_freq_KHz                                 1.17                 0.328
# Expected_file_duration_ms                       80.6                 999.0
# Actual_file_duration_ms                      344.527              3045.826
# dead_vs_expectation                            3.275                 2.049
# dead_time_due_to_gaps                          1.221                 0.604
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                1.3155                3.7875
# Number_of_large_gaps                             396                     0
# Smallest_gap_us                                766.5                2739.0
# Sum_of_gaps_larger_than_med_ms                  4.61              3045.826
# Old_dead_time_%                                1.338                 100.0
#
#                                 ...                    12  \
# Filename                        ...  20231205_174842_.txt
# Samples_Averaged                ...                    20
# Inter_Sample_delay_us           ...                    50
# Inter_Average_delay_us          ...                   500
# Number_of_samples               ...                  1000
# Number_of_gaps                  ...                   999
# Expected_sample_time_us         ...                  1000
# Actual_sample_time_us           ...                1900.0
# Median_gap_us                   ...                3101.0
# Expected_freq_KHz               ...                   1.0
# Actual_freq_KHz                 ...                 0.324
# Expected_file_duration_ms       ...                1000.0
# Actual_file_duration_ms         ...              3087.174
# dead_vs_expectation             ...                 2.087
# dead_time_due_to_gaps           ...                 0.625
# OLD_ANALYSIS                    ...                     -
# Largest_gap_ms                  ...                  3.67
# Number_of_large_gaps            ...                     0
# Smallest_gap_us                 ...                2722.5
# Sum_of_gaps_larger_than_med_ms  ...              3087.174
# Old_dead_time_%                 ...                 100.0
#
#                                                   13                    14  \
# Filename                        20231205_174845_.txt  20231205_174848_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                           500                   500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                         1901.0                1901.0
# Median_gap_us                                 3080.5                3101.0
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.325                 0.323
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                     3078.378              3096.356
# dead_vs_expectation                            2.078                 2.096
# dead_time_due_to_gaps                          0.619                 0.629
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                 3.775                 3.622
# Number_of_large_gaps                               0                     0
# Smallest_gap_us                               2734.5                2724.5
# Sum_of_gaps_larger_than_med_ms              3078.378              3096.356
# Old_dead_time_%                                100.0                 100.0
#
#                                                   15                    16  \
# Filename                        20231205_174851_.txt  20231205_174854_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                           500                   500
# Number_of_samples                               1000                   791
# Number_of_gaps                                   999                   790
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                         1901.0                1900.0
# Median_gap_us                                 3105.5                3120.0
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.322                 0.321
# Expected_file_duration_ms                     1000.0                 791.0
# Actual_file_duration_ms                     3105.834               2463.33
# dead_vs_expectation                            2.106                 2.114
# dead_time_due_to_gaps                          0.634                 0.639
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                  3.67                 3.684
# Number_of_large_gaps                               0                     0
# Smallest_gap_us                               2740.0                2774.5
# Sum_of_gaps_larger_than_med_ms              3105.834               2463.33
# Old_dead_time_%                                100.0                 100.0
#
#                                                   17                    18  \
# Filename                        20231205_174211_.txt  20231205_174215_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                         1900.0                1901.0
# Median_gap_us                                 4164.0                4166.0
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                 0.24                  0.24
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                     4168.188              4162.719
# dead_vs_expectation                            3.168                 3.163
# dead_time_due_to_gaps                          1.194                  1.19
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                 4.784                 4.748
# Number_of_large_gaps                             990                   977
# Smallest_gap_us                               3769.0                3754.5
# Sum_of_gaps_larger_than_med_ms                34.108                 83.25
# Old_dead_time_%                                0.818                   2.0
#
#                                                   19                    20  \
# Filename                        20231205_174219_.txt  20231205_174224_.txt
# Samples_Averaged                                  20                    20
# Inter_Sample_delay_us                             50                    50
# Inter_Average_delay_us                          1500                  1500
# Number_of_samples                               1000                  1000
# Number_of_gaps                                   999                   999
# Expected_sample_time_us                         1000                  1000
# Actual_sample_time_us                         1901.0                1901.0
# Median_gap_us                                 4154.5                4171.5
# Expected_freq_KHz                                1.0                   1.0
# Actual_freq_KHz                                0.241                  0.24
# Expected_file_duration_ms                     1000.0                1000.0
# Actual_file_duration_ms                      4152.08              4162.269
# dead_vs_expectation                            3.152                 3.162
# dead_time_due_to_gaps                          1.184                  1.19
# OLD_ANALYSIS                                       -                     -
# Largest_gap_ms                                 4.718                  4.73
# Number_of_large_gaps                             981                   973
# Smallest_gap_us                               3739.5                3747.0
# Sum_of_gaps_larger_than_med_ms                67.999                98.302
# Old_dead_time_%                                1.638                 2.362
#
#                                                   21
# Filename                        20231205_174228_.txt
# Samples_Averaged                                  20
# Inter_Sample_delay_us                             50
# Inter_Average_delay_us                          1500
# Number_of_samples                                695
# Number_of_gaps                                   694
# Expected_sample_time_us                         1000
# Actual_sample_time_us                         1901.0
# Median_gap_us                                4161.75
# Expected_freq_KHz                                1.0
# Actual_freq_KHz                                0.241
# Expected_file_duration_ms                      695.0
# Actual_file_duration_ms                     2887.582
# dead_vs_expectation                            3.155
# dead_time_due_to_gaps                          1.186
# OLD_ANALYSIS                                       -
# Largest_gap_ms                                 4.632
# Number_of_large_gaps                             682
# Smallest_gap_us                               3764.5
# Sum_of_gaps_larger_than_med_ms                 45.38
# Old_dead_time_%                                1.572
#
# [21 rows x 22 columns]
