# %% [markdown]
# # First look at MDA Testing

# %%
import os
import pandas as pd
from analysis_plotter import analyze, quickLook

directory_path = 'data_MDA_Tests/'

# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=True)
        quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df = pd.DataFrame(all_dictionaries).transpose()
df
# Out:
# Sample Frequency from Median gap (KHz): 2.07
# Median gap (us):  483.0
#
# LARGE GAP ANALYSIS: 50 ms
# Count of long gaps:  11
# Largest gaps (ms):  205.713
#
# SMALL GAP ANALYSIS: 20 ms
# Sum of durations larger than 20 ms (ms): 2375.76
#
# File info & Dead Time
# Time Length of file (ms,s): 9999.29 , 10.00
# Dead time = (sum durations > 20 ms/Time length of file)
# Dead time %: 23.76
# Sample Frequency from Median gap (KHz): 0.47
# Median gap (us):  2121.0
#
# LARGE GAP ANALYSIS: 50 ms
# Count of long gaps:  6
# Largest gaps (ms):  214.718
#
# SMALL GAP ANALYSIS: 20 ms
# Sum of durations larger than 20 ms (ms): 1276.06
#
# File info & Dead Time
# Time Length of file (ms,s): 9888.91 , 9.89
# Dead time = (sum durations > 20 ms/Time length of file)
# Dead time %: 12.90
# Sample Frequency from Median gap (KHz): 0.12
# Median gap (us):  8173.0
#
# LARGE GAP ANALYSIS: 50 ms
# Count of long gaps:  3
# Largest gaps (ms):  212.658
#
# SMALL GAP ANALYSIS: 20 ms
# Sum of durations larger than 20 ms (ms): 1152.61
#
# File info & Dead Time
# Time Length of file (ms,s): 9986.28 , 9.99
# Dead time = (sum durations > 20 ms/Time length of file)
# Dead time %: 11.54
# Sample Frequency from Median gap (KHz): 0.12
# Median gap (us):  8160.0
#
# LARGE GAP ANALYSIS: 50 ms
# Count of long gaps:  2
# Largest gaps (ms):  212.529
#
# SMALL GAP ANALYSIS: 20 ms
# Sum of durations larger than 20 ms (ms): 1052.43
#
# File info & Dead Time
# Time Length of file (ms,s): 9987.39 , 9.99
# Dead time = (sum durations > 20 ms/Time length of file)
# Dead time %: 10.54
# Sample Frequency from Median gap (KHz): 0.12
# Median gap (us):  8110.0
#
# LARGE GAP ANALYSIS: 50 ms
# Count of long gaps:  3
# Largest gaps (ms):  214.214
#
# SMALL GAP ANALYSIS: 20 ms
# Sum of durations larger than 20 ms (ms): 1251.75
#
# File info & Dead Time
# Time Length of file (ms,s): 9991.11 , 9.99
# Dead time = (sum durations > 20 ms/Time length of file)
# Dead time %: 12.53
#                                                       0             1  \
# Filename                                   21100002.TXT  21340001.TXT
# Samples_Averaged                                      4            20
# Inter_Sample_delay                                 None          None
# Inter_Average_delay                                None          None
# Sample_Frequency_KHz                               2.07          0.47
# Median_Gap_us                                     483.0        2121.0
# Large_Gap_Analysis_ms                              50.0          50.0
# Count_of_Long_Gaps                                   11             6
# Largest_Gaps_ms                                  205.71        214.72
# Small_Gap_Analysis_ms                              20.0          20.0
# Sum_of_Durations_Larger_than_Small_Gap_ms       2375.76       1276.06
# Time_Length_of_File_ms                          9999.29       9888.91
# Time_Length_of_File_s                              10.0          9.89
# Dead_Time_Percentage                              23.76          12.9
#
#                                                       2             3  \
# Filename                                   21580001.TXT  21640001.TXT
# Samples_Averaged                                    100           100
# Inter_Sample_delay                                 None          None
# Inter_Average_delay                                None          None
# Sample_Frequency_KHz                               0.12          0.12
# Median_Gap_us                                    8173.0        8160.0
# Large_Gap_Analysis_ms                              50.0          50.0
# Count_of_Long_Gaps                                    3             2
# Largest_Gaps_ms                                  212.66        212.53
# Small_Gap_Analysis_ms                              20.0          20.0
# Sum_of_Durations_Larger_than_Small_Gap_ms       1152.61       1052.43
# Time_Length_of_File_ms                          9986.28       9987.39
# Time_Length_of_File_s                              9.99          9.99
# Dead_Time_Percentage                              11.54         10.54
#
#                                                       4
# Filename                                   21650001.TXT
# Samples_Averaged                                    100
# Inter_Sample_delay                                 None
# Inter_Average_delay                                None
# Sample_Frequency_KHz                               0.12
# Median_Gap_us                                    8110.0
# Large_Gap_Analysis_ms                              50.0
# Count_of_Long_Gaps                                    3
# Largest_Gaps_ms                                  214.21
# Small_Gap_Analysis_ms                              20.0
# Sum_of_Durations_Larger_than_Small_Gap_ms       1251.75
# Time_Length_of_File_ms                          9991.11
# Time_Length_of_File_s                              9.99
# Dead_Time_Percentage                              12.53
