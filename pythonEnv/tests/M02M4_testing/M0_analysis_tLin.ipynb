# %%
import os
import pandas as pd
from analysis_plotter_tLin import analyze, quickLook

directory_path = 'M0_tLinear/50_50_4/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                            #   inter_sample_delay=50,
                            #   inter_average_delay=50,
                            #   samples_to_av=4, 
                              gap_sizeL_us=7_000, 
                              gap_sizeS_us=600)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_50_50_4 = pd.DataFrame(all_dictionaries).transpose()
df_M0_50_50_4
# Out:
#                                                       0             1  \
# Filename                                   05080001.TXT  05080002.TXT
# Samples_Averaged                                      4             4
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                                50.0          50.0
# Theoretical_Frequency_KHz                           4.0           4.0
# Sample_Frequency_KHz                              1.225         1.222
# Large_Gap_selected_ms                               7.0           7.0
# Small_Gap_selected_ms                               0.6           0.6
# Median_Gap_us                                     591.5         592.0
# Count_of_gaps_larger_than_Large_Gap                   3             3
# Largest_Gaps_ms                                   14.27         23.93
# Smallest_Gap_ms                                    0.59          0.59
# Sum_of_Durations_Larger_than_Small_Gap_ms       1581.94       1588.63
# Time_Length_of_File_ms                          4999.83      4999.727
# Time_Length_of_File_s                               5.0           5.0
# Dead_Time_Percentage                              31.64        31.774
#
#                                                       2             3  \
# Filename                                   05080003.TXT  05080004.TXT
# Samples_Averaged                                      4             4
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                                50.0          50.0
# Theoretical_Frequency_KHz                           4.0           4.0
# Sample_Frequency_KHz                              1.224         1.222
# Large_Gap_selected_ms                               7.0           7.0
# Small_Gap_selected_ms                               0.6           0.6
# Median_Gap_us                                     593.0         593.0
# Count_of_gaps_larger_than_Large_Gap                   2             3
# Largest_Gaps_ms                                   12.22         12.35
# Smallest_Gap_ms                                    0.59          0.59
# Sum_of_Durations_Larger_than_Small_Gap_ms       1576.42       1581.46
# Time_Length_of_File_ms                         4999.742      4997.744
# Time_Length_of_File_s                               5.0         4.998
# Dead_Time_Percentage                              31.53        31.643
#
#                                                       4
# Filename                                   05080005.TXT
# Samples_Averaged                                      4
# Inter_Sample_delay                                 50.0
# Inter_Average_delay                                50.0
# Theoretical_Frequency_KHz                           4.0
# Sample_Frequency_KHz                              1.172
# Large_Gap_selected_ms                               7.0
# Small_Gap_selected_ms                               0.6
# Median_Gap_us                                     593.0
# Count_of_gaps_larger_than_Large_Gap                   5
# Largest_Gaps_ms                                  124.96
# Smallest_Gap_ms                                    0.59
# Sum_of_Durations_Larger_than_Small_Gap_ms       1723.46
# Time_Length_of_File_ms                         4999.522
# Time_Length_of_File_s                               5.0
# Dead_Time_Percentage                             34.472

# %%
import os
import pandas as pd
from analysis_plotter_tLin import analyze, quickLook

directory_path = 'M0_tLinear/50_500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                            #   inter_sample_delay=50,
                            #   inter_average_delay=500,
                            #   samples_to_av=20, 
                              gap_sizeL_us=7000, 
                              gap_sizeS_us=2700)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_50_500_20 = pd.DataFrame(all_dictionaries).transpose()
df_M0_50_500_20
# Out:
#                                                       0             1  \
# Filename                                   05090001.TXT  05090002.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                               500.0         500.0
# Theoretical_Frequency_KHz                         0.667         0.667
# Sample_Frequency_KHz                               0.35         0.349
# Large_Gap_selected_ms                               7.0           7.0
# Small_Gap_selected_ms                               2.7           2.7
# Median_Gap_us                                    2626.0        2627.0
# Count_of_gaps_larger_than_Large_Gap                   2             3
# Largest_Gaps_ms                                    8.33          8.39
# Smallest_Gap_ms                                    2.62          2.62
# Sum_of_Durations_Larger_than_Small_Gap_ms        685.61        687.86
# Time_Length_of_File_ms                         4997.105       4998.74
# Time_Length_of_File_s                             4.997         4.999
# Dead_Time_Percentage                              13.72        13.761
#
#                                                       2             3  \
# Filename                                   05090003.TXT  05090004.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                               500.0         500.0
# Theoretical_Frequency_KHz                         0.667         0.667
# Sample_Frequency_KHz                              0.349          0.35
# Large_Gap_selected_ms                               7.0           7.0
# Small_Gap_selected_ms                               2.7           2.7
# Median_Gap_us                                    2627.5        2627.5
# Count_of_gaps_larger_than_Large_Gap                   4             1
# Largest_Gaps_ms                                     8.4          7.86
# Smallest_Gap_ms                                    2.62          2.62
# Sum_of_Durations_Larger_than_Small_Gap_ms        687.93        683.03
# Time_Length_of_File_ms                         4999.542      4997.434
# Time_Length_of_File_s                               5.0         4.997
# Dead_Time_Percentage                              13.76        13.668
#
#                                                       4
# Filename                                   05090005.TXT
# Samples_Averaged                                     20
# Inter_Sample_delay                                 50.0
# Inter_Average_delay                               500.0
# Theoretical_Frequency_KHz                         0.667
# Sample_Frequency_KHz                              0.349
# Large_Gap_selected_ms                               7.0
# Small_Gap_selected_ms                               2.7
# Median_Gap_us                                    2627.5
# Count_of_gaps_larger_than_Large_Gap                   4
# Largest_Gaps_ms                                   11.73
# Smallest_Gap_ms                                    2.62
# Sum_of_Durations_Larger_than_Small_Gap_ms        693.59
# Time_Length_of_File_ms                          4999.83
# Time_Length_of_File_s                               5.0
# Dead_Time_Percentage                             13.872

# %%
import os
import pandas as pd
from analysis_plotter_tLin import analyze, quickLook

directory_path = 'M0_tLinear/50_1500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                            #   inter_sample_delay=50,
                            #   inter_average_delay=1500,
                            #   samples_to_av=20, 
                              gap_sizeL_us=4500, 
                              gap_sizeS_us=4000)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_50_1500_20 = pd.DataFrame(all_dictionaries).transpose()
df_M0_50_1500_20
# Out:
#                                                       0             1  \
# Filename                                   05100001.TXT  05100002.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                              1500.0        1500.0
# Theoretical_Frequency_KHz                           0.4           0.4
# Sample_Frequency_KHz                              0.259         0.259
# Large_Gap_selected_ms                               4.5           4.5
# Small_Gap_selected_ms                               4.0           4.0
# Median_Gap_us                                    3625.0        3625.0
# Count_of_gaps_larger_than_Large_Gap                  78            78
# Largest_Gaps_ms                                    8.76          8.91
# Smallest_Gap_ms                                    3.62          3.62
# Sum_of_Durations_Larger_than_Small_Gap_ms        586.15        588.41
# Time_Length_of_File_ms                         4998.038      4996.579
# Time_Length_of_File_s                             4.998         4.997
# Dead_Time_Percentage                             11.728        11.776
#
#                                                       2             3  \
# Filename                                   05100003.TXT  05100004.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                              1500.0        1500.0
# Theoretical_Frequency_KHz                           0.4           0.4
# Sample_Frequency_KHz                              0.259         0.259
# Large_Gap_selected_ms                               4.5           4.5
# Small_Gap_selected_ms                               4.0           4.0
# Median_Gap_us                                    3625.5        3626.0
# Count_of_gaps_larger_than_Large_Gap                  78            78
# Largest_Gaps_ms                                    8.92          8.85
# Smallest_Gap_ms                                    3.62          3.62
# Sum_of_Durations_Larger_than_Small_Gap_ms        588.55        586.32
# Time_Length_of_File_ms                         4996.984       4999.06
# Time_Length_of_File_s                             4.997         4.999
# Dead_Time_Percentage                             11.778        11.729
#
#                                                       4
# Filename                                   05100005.TXT
# Samples_Averaged                                     20
# Inter_Sample_delay                                 50.0
# Inter_Average_delay                              1500.0
# Theoretical_Frequency_KHz                           0.4
# Sample_Frequency_KHz                              0.238
# Large_Gap_selected_ms                               4.5
# Small_Gap_selected_ms                               4.0
# Median_Gap_us                                    3627.0
# Count_of_gaps_larger_than_Large_Gap                  72
# Largest_Gaps_ms                                  149.83
# Smallest_Gap_ms                                    3.62
# Sum_of_Durations_Larger_than_Small_Gap_ms        944.55
# Time_Length_of_File_ms                         4999.733
# Time_Length_of_File_s                               5.0
# Dead_Time_Percentage                             18.892

# %%
import os
import pandas as pd
from analysis_plotter_tLin import analyze, quickLook

directory_path = 'M0_tLinear/100_500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                            #   inter_sample_delay=50,
                            #   inter_average_delay=1500,
                            #   samples_to_av=20, 
                              gap_sizeL_us=4500, 
                              gap_sizeS_us=4000)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_100_500_20 = pd.DataFrame(all_dictionaries).transpose()
df_M0_100_500_20
# Out:
#                                                       0             1  \
# Filename                                   09060001.TXT  09060002.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                100.0         100.0
# Inter_Average_delay                               500.0         500.0
# Theoretical_Frequency_KHz                           0.4           0.4
# Sample_Frequency_KHz                              0.265         0.265
# Large_Gap_selected_ms                               4.5           4.5
# Small_Gap_selected_ms                               4.0           4.0
# Median_Gap_us                                    3601.5        3601.5
# Count_of_gaps_larger_than_Large_Gap                  75            75
# Largest_Gaps_ms                                    14.4          14.4
# Smallest_Gap_ms                                     3.6           3.6
# Sum_of_Durations_Larger_than_Small_Gap_ms        503.53        500.52
# Time_Length_of_File_ms                         4997.962      4998.692
# Time_Length_of_File_s                             4.998         4.999
# Dead_Time_Percentage                             10.075        10.013
#
#                                                       2
# Filename                                   09060003.TXT
# Samples_Averaged                                     20
# Inter_Sample_delay                                100.0
# Inter_Average_delay                               500.0
# Theoretical_Frequency_KHz                           0.4
# Sample_Frequency_KHz                              0.265
# Large_Gap_selected_ms                               4.5
# Small_Gap_selected_ms                               4.0
# Median_Gap_us                                    3602.0
# Count_of_gaps_larger_than_Large_Gap                  75
# Largest_Gaps_ms                                   14.42
# Smallest_Gap_ms                                     3.6
# Sum_of_Durations_Larger_than_Small_Gap_ms        498.22
# Time_Length_of_File_ms                         4997.021
# Time_Length_of_File_s                             4.997
# Dead_Time_Percentage                               9.97

# %%
result = pd.concat([df_M0_50_50_4,df_M0_50_500_20,df_M0_50_1500_20,df_M0_100_500_20], axis=1, ignore_index=True)

result
# Out:
#                                                      0             1   \
# Filename                                   05080001.TXT  05080002.TXT
# Samples_Averaged                                      4             4
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                                50.0          50.0
# Theoretical_Frequency_KHz                           4.0           4.0
# Sample_Frequency_KHz                              1.225         1.222
# Large_Gap_selected_ms                               7.0           7.0
# Small_Gap_selected_ms                               0.6           0.6
# Median_Gap_us                                     591.5         592.0
# Count_of_gaps_larger_than_Large_Gap                   3             3
# Largest_Gaps_ms                                   14.27         23.93
# Smallest_Gap_ms                                    0.59          0.59
# Sum_of_Durations_Larger_than_Small_Gap_ms       1581.94       1588.63
# Time_Length_of_File_ms                          4999.83      4999.727
# Time_Length_of_File_s                               5.0           5.0
# Dead_Time_Percentage                              31.64        31.774
#
#                                                      2             3   \
# Filename                                   05080003.TXT  05080004.TXT
# Samples_Averaged                                      4             4
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                                50.0          50.0
# Theoretical_Frequency_KHz                           4.0           4.0
# Sample_Frequency_KHz                              1.224         1.222
# Large_Gap_selected_ms                               7.0           7.0
# Small_Gap_selected_ms                               0.6           0.6
# Median_Gap_us                                     593.0         593.0
# Count_of_gaps_larger_than_Large_Gap                   2             3
# Largest_Gaps_ms                                   12.22         12.35
# Smallest_Gap_ms                                    0.59          0.59
# Sum_of_Durations_Larger_than_Small_Gap_ms       1576.42       1581.46
# Time_Length_of_File_ms                         4999.742      4997.744
# Time_Length_of_File_s                               5.0         4.998
# Dead_Time_Percentage                              31.53        31.643
#
#                                                      4             5   \
# Filename                                   05080005.TXT  05090001.TXT
# Samples_Averaged                                      4            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                                50.0         500.0
# Theoretical_Frequency_KHz                           4.0         0.667
# Sample_Frequency_KHz                              1.172          0.35
# Large_Gap_selected_ms                               7.0           7.0
# Small_Gap_selected_ms                               0.6           2.7
# Median_Gap_us                                     593.0        2626.0
# Count_of_gaps_larger_than_Large_Gap                   5             2
# Largest_Gaps_ms                                  124.96          8.33
# Smallest_Gap_ms                                    0.59          2.62
# Sum_of_Durations_Larger_than_Small_Gap_ms       1723.46        685.61
# Time_Length_of_File_ms                         4999.522      4997.105
# Time_Length_of_File_s                               5.0         4.997
# Dead_Time_Percentage                             34.472         13.72
#
#                                                      6             7   \
# Filename                                   05090002.TXT  05090003.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                               500.0         500.0
# Theoretical_Frequency_KHz                         0.667         0.667
# Sample_Frequency_KHz                              0.349         0.349
# Large_Gap_selected_ms                               7.0           7.0
# Small_Gap_selected_ms                               2.7           2.7
# Median_Gap_us                                    2627.0        2627.5
# Count_of_gaps_larger_than_Large_Gap                   3             4
# Largest_Gaps_ms                                    8.39           8.4
# Smallest_Gap_ms                                    2.62          2.62
# Sum_of_Durations_Larger_than_Small_Gap_ms        687.86        687.93
# Time_Length_of_File_ms                          4998.74      4999.542
# Time_Length_of_File_s                             4.999           5.0
# Dead_Time_Percentage                             13.761         13.76
#
#                                                      8             9   \
# Filename                                   05090004.TXT  05090005.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                               500.0         500.0
# Theoretical_Frequency_KHz                         0.667         0.667
# Sample_Frequency_KHz                               0.35         0.349
# Large_Gap_selected_ms                               7.0           7.0
# Small_Gap_selected_ms                               2.7           2.7
# Median_Gap_us                                    2627.5        2627.5
# Count_of_gaps_larger_than_Large_Gap                   1             4
# Largest_Gaps_ms                                    7.86         11.73
# Smallest_Gap_ms                                    2.62          2.62
# Sum_of_Durations_Larger_than_Small_Gap_ms        683.03        693.59
# Time_Length_of_File_ms                         4997.434       4999.83
# Time_Length_of_File_s                             4.997           5.0
# Dead_Time_Percentage                             13.668        13.872
#
#                                                      10            11  \
# Filename                                   05100001.TXT  05100002.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                              1500.0        1500.0
# Theoretical_Frequency_KHz                           0.4           0.4
# Sample_Frequency_KHz                              0.259         0.259
# Large_Gap_selected_ms                               4.5           4.5
# Small_Gap_selected_ms                               4.0           4.0
# Median_Gap_us                                    3625.0        3625.0
# Count_of_gaps_larger_than_Large_Gap                  78            78
# Largest_Gaps_ms                                    8.76          8.91
# Smallest_Gap_ms                                    3.62          3.62
# Sum_of_Durations_Larger_than_Small_Gap_ms        586.15        588.41
# Time_Length_of_File_ms                         4998.038      4996.579
# Time_Length_of_File_s                             4.998         4.997
# Dead_Time_Percentage                             11.728        11.776
#
#                                                      12            13  \
# Filename                                   05100003.TXT  05100004.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                              1500.0        1500.0
# Theoretical_Frequency_KHz                           0.4           0.4
# Sample_Frequency_KHz                              0.259         0.259
# Large_Gap_selected_ms                               4.5           4.5
# Small_Gap_selected_ms                               4.0           4.0
# Median_Gap_us                                    3625.5        3626.0
# Count_of_gaps_larger_than_Large_Gap                  78            78
# Largest_Gaps_ms                                    8.92          8.85
# Smallest_Gap_ms                                    3.62          3.62
# Sum_of_Durations_Larger_than_Small_Gap_ms        588.55        586.32
# Time_Length_of_File_ms                         4996.984       4999.06
# Time_Length_of_File_s                             4.997         4.999
# Dead_Time_Percentage                             11.778        11.729
#
#                                                      14            15  \
# Filename                                   05100005.TXT  09060001.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                 50.0         100.0
# Inter_Average_delay                              1500.0         500.0
# Theoretical_Frequency_KHz                           0.4           0.4
# Sample_Frequency_KHz                              0.238         0.265
# Large_Gap_selected_ms                               4.5           4.5
# Small_Gap_selected_ms                               4.0           4.0
# Median_Gap_us                                    3627.0        3601.5
# Count_of_gaps_larger_than_Large_Gap                  72            75
# Largest_Gaps_ms                                  149.83          14.4
# Smallest_Gap_ms                                    3.62           3.6
# Sum_of_Durations_Larger_than_Small_Gap_ms        944.55        503.53
# Time_Length_of_File_ms                         4999.733      4997.962
# Time_Length_of_File_s                               5.0         4.998
# Dead_Time_Percentage                             18.892        10.075
#
#                                                      16            17
# Filename                                   09060002.TXT  09060003.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                100.0         100.0
# Inter_Average_delay                               500.0         500.0
# Theoretical_Frequency_KHz                           0.4           0.4
# Sample_Frequency_KHz                              0.265         0.265
# Large_Gap_selected_ms                               4.5           4.5
# Small_Gap_selected_ms                               4.0           4.0
# Median_Gap_us                                    3601.5        3602.0
# Count_of_gaps_larger_than_Large_Gap                  75            75
# Largest_Gaps_ms                                    14.4         14.42
# Smallest_Gap_ms                                     3.6           3.6
# Sum_of_Durations_Larger_than_Small_Gap_ms        500.52        498.22
# Time_Length_of_File_ms                         4998.692      4997.021
# Time_Length_of_File_s                             4.999         4.997
# Dead_Time_Percentage                             10.013          9.97
