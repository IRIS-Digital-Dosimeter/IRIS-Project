# %%
import os
import pandas as pd
from analysis_plotter_tLin import analyze, quickLook

directory_path = 'M0_tLinear/50_50_4/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                            #   inter_sample_delay=50,
                            #   inter_average_delay=50,
                            #   samples_to_av=4, 
                              gap_sizeL_us=5_000, 
                              gap_sizeS_us=2000)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_50_50_4 = pd.DataFrame(all_dictionaries).transpose()
df_M0_50_50_4
# Out:
#                                                       0             1  \
# Filename                                   05080001.TXT  05080002.TXT
# Samples_Averaged                                      4             4
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                                50.0          50.0
# Sample_Frequency_KHz                               6.76          6.76
# Median_Gap_us                                     591.5         592.0
# Large_Gap_Analysis_ms                               5.0           5.0
# Count_of_Long_Gaps                                    9            13
# Largest_Gaps_ms                                   14.27         23.93
# Small_Gap_Analysis_ms                               2.0           2.0
# Sum_of_Durations_Larger_than_Small_Gap_ms       1581.94       1588.63
# Time_Length_of_File_ms                          4999.83      4999.726
# Time_Length_of_File_s                               5.0           5.0
# Dead_Time_Percentage                              31.64        31.774
#
#                                                       2             3  \
# Filename                                   05080003.TXT  05080004.TXT
# Samples_Averaged                                      4             4
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                                50.0          50.0
# Sample_Frequency_KHz                               6.75          6.75
# Median_Gap_us                                     593.0         593.0
# Large_Gap_Analysis_ms                               5.0           5.0
# Count_of_Long_Gaps                                   12            19
# Largest_Gaps_ms                                   12.22         12.35
# Small_Gap_Analysis_ms                               2.0           2.0
# Sum_of_Durations_Larger_than_Small_Gap_ms       1576.42       1581.46
# Time_Length_of_File_ms                         4999.742      4997.745
# Time_Length_of_File_s                               5.0         4.998
# Dead_Time_Percentage                              31.53        31.643
#
#                                                       4
# Filename                                   05080005.TXT
# Samples_Averaged                                      4
# Inter_Sample_delay                                 50.0
# Inter_Average_delay                                50.0
# Sample_Frequency_KHz                               6.75
# Median_Gap_us                                     593.0
# Large_Gap_Analysis_ms                               5.0
# Count_of_Long_Gaps                                   15
# Largest_Gaps_ms                                  124.96
# Small_Gap_Analysis_ms                               2.0
# Sum_of_Durations_Larger_than_Small_Gap_ms       1723.45
# Time_Length_of_File_ms                         4999.522
# Time_Length_of_File_s                               5.0
# Dead_Time_Percentage                             34.472

# %%
import os
import pandas as pd
from analysis_plotter_tLin import analyze, quickLook

directory_path = 'M0_tLinear/50_500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                            #   inter_sample_delay=50,
                            #   inter_average_delay=500,
                            #   samples_to_av=20, 
                              gap_sizeL_us=3000, 
                              gap_sizeS_us=3000)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_50_500_20 = pd.DataFrame(all_dictionaries).transpose()
df_M0_50_500_20
# Out:
#                                                       0             1  \
# Filename                                   05090001.TXT  05090002.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                               500.0         500.0
# Sample_Frequency_KHz                               7.62          7.61
# Median_Gap_us                                   2625.95       2627.05
# Large_Gap_Analysis_ms                               3.0           3.0
# Count_of_Long_Gaps                                  105           105
# Largest_Gaps_ms                                    8.33          8.39
# Small_Gap_Analysis_ms                               3.0           3.0
# Sum_of_Durations_Larger_than_Small_Gap_ms        685.62        687.87
# Time_Length_of_File_ms                         4997.104      4998.738
# Time_Length_of_File_s                             4.997         4.999
# Dead_Time_Percentage                              13.72        13.761
#
#                                                       2             3  \
# Filename                                   05090003.TXT  05090004.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                               500.0         500.0
# Sample_Frequency_KHz                               7.61          7.61
# Median_Gap_us                                   2627.85        2627.9
# Large_Gap_Analysis_ms                               3.0           3.0
# Count_of_Long_Gaps                                  105           105
# Largest_Gaps_ms                                     8.4          7.86
# Small_Gap_Analysis_ms                               3.0           3.0
# Sum_of_Durations_Larger_than_Small_Gap_ms        687.93        683.04
# Time_Length_of_File_ms                         4999.543      4997.436
# Time_Length_of_File_s                               5.0         4.997
# Dead_Time_Percentage                              13.76        13.668
#
#                                                       4
# Filename                                   05090005.TXT
# Samples_Averaged                                     20
# Inter_Sample_delay                                 50.0
# Inter_Average_delay                               500.0
# Sample_Frequency_KHz                               7.61
# Median_Gap_us                                   2627.15
# Large_Gap_Analysis_ms                               3.0
# Count_of_Long_Gaps                                  105
# Largest_Gaps_ms                                   11.73
# Small_Gap_Analysis_ms                               3.0
# Sum_of_Durations_Larger_than_Small_Gap_ms        693.59
# Time_Length_of_File_ms                          4999.83
# Time_Length_of_File_s                               5.0
# Dead_Time_Percentage                             13.872

# %%
import os
import pandas as pd
from analysis_plotter_tLin import analyze, quickLook

directory_path = 'M0_tLinear/50_1500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                            #   inter_sample_delay=50,
                            #   inter_average_delay=1500,
                            #   samples_to_av=20, 
                              gap_sizeL_us=4500, 
                              gap_sizeS_us=4000)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_50_1500_20 = pd.DataFrame(all_dictionaries).transpose()
df_M0_50_1500_20
# Out:
#                                                       0             1  \
# Filename                                   05100001.TXT  05100002.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                              1500.0        1500.0
# Sample_Frequency_KHz                               5.52          5.52
# Median_Gap_us                                   3625.05       3625.05
# Large_Gap_Analysis_ms                               4.5           4.5
# Count_of_Long_Gaps                                   78            78
# Largest_Gaps_ms                                    8.76          8.91
# Small_Gap_Analysis_ms                               4.0           4.0
# Sum_of_Durations_Larger_than_Small_Gap_ms        586.14        588.41
# Time_Length_of_File_ms                         4998.038      4996.579
# Time_Length_of_File_s                             4.998         4.997
# Dead_Time_Percentage                             11.727        11.776
#
#                                                       2             3  \
# Filename                                   05100003.TXT  05100004.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                              1500.0        1500.0
# Sample_Frequency_KHz                               5.52          5.52
# Median_Gap_us                                    3625.1        3626.0
# Large_Gap_Analysis_ms                               4.5           4.5
# Count_of_Long_Gaps                                   78            78
# Largest_Gaps_ms                                    8.92          8.86
# Small_Gap_Analysis_ms                               4.0           4.0
# Sum_of_Durations_Larger_than_Small_Gap_ms        588.55        586.32
# Time_Length_of_File_ms                         4996.984      4999.059
# Time_Length_of_File_s                             4.997         4.999
# Dead_Time_Percentage                             11.778        11.729
#
#                                                       4
# Filename                                   05100005.TXT
# Samples_Averaged                                     20
# Inter_Sample_delay                                 50.0
# Inter_Average_delay                              1500.0
# Sample_Frequency_KHz                               5.51
# Median_Gap_us                                   3627.05
# Large_Gap_Analysis_ms                               4.5
# Count_of_Long_Gaps                                   72
# Largest_Gaps_ms                                  149.83
# Small_Gap_Analysis_ms                               4.0
# Sum_of_Durations_Larger_than_Small_Gap_ms        944.57
# Time_Length_of_File_ms                         4999.733
# Time_Length_of_File_s                               5.0
# Dead_Time_Percentage                             18.892

# %%
import os
import pandas as pd
from analysis_plotter_tLin import analyze, quickLook

directory_path = 'M0_tLinear/no_inter_2/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                            #   inter_sample_delay=None,
                            #   inter_average_delay=None,
                            #   samples_to_av=2, 
                              gap_sizeL_us=700, 
                              gap_sizeS_us=450)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_no_inter_2 = pd.DataFrame(all_dictionaries).transpose()
df_no_inter_2
# Out:
#                                                       0             1  \
# Filename                                   05110001.TXT  05110002.TXT
# Samples_Averaged                                      2             2
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                               8.23          8.23
# Median_Gap_us                                     243.0         243.0
# Large_Gap_Analysis_ms                               0.7           0.7
# Count_of_Long_Gaps                                  724           723
# Largest_Gaps_ms                                   11.39         10.73
# Small_Gap_Analysis_ms                              0.45          0.45
# Sum_of_Durations_Larger_than_Small_Gap_ms       2270.43       2274.05
# Time_Length_of_File_ms                         4999.817      4999.765
# Time_Length_of_File_s                               5.0           5.0
# Dead_Time_Percentage                              45.41        45.483
#
#                                                       2             3  \
# Filename                                   05110003.TXT  05110004.TXT
# Samples_Averaged                                      2             2
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                               8.26          8.25
# Median_Gap_us                                     242.0         242.5
# Large_Gap_Analysis_ms                               0.7           0.7
# Count_of_Long_Gaps                                  724           724
# Largest_Gaps_ms                                   10.71         10.62
# Small_Gap_Analysis_ms                              0.45          0.45
# Sum_of_Durations_Larger_than_Small_Gap_ms       2270.43       2271.22
# Time_Length_of_File_ms                         4998.055      4999.955
# Time_Length_of_File_s                             4.998           5.0
# Dead_Time_Percentage                             45.426        45.425
#
#                                                       4
# Filename                                   05110005.TXT
# Samples_Averaged                                      2
# Inter_Sample_delay                                  1.0
# Inter_Average_delay                                 1.0
# Sample_Frequency_KHz                               8.23
# Median_Gap_us                                     243.0
# Large_Gap_Analysis_ms                               0.7
# Count_of_Long_Gaps                                  644
# Largest_Gaps_ms                                  131.98
# Small_Gap_Analysis_ms                              0.45
# Sum_of_Durations_Larger_than_Small_Gap_ms       2570.61
# Time_Length_of_File_ms                         4999.592
# Time_Length_of_File_s                               5.0
# Dead_Time_Percentage                             51.416

# %%
import os
import pandas as pd
from analysis_plotter_tLin import analyze, quickLook

directory_path = 'M0_tLinear/no_inter_4/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                            #   inter_sample_delay=None,
                            #   inter_average_delay=None,
                            #   samples_to_av=4, 
                              gap_sizeL_us=700, 
                              gap_sizeS_us=500)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_no_inter_4 = pd.DataFrame(all_dictionaries).transpose()
# df_no_inter_4

# %%
import os
import pandas as pd
from analysis_plotter_tLin import analyze, quickLook

directory_path = 'M0_tLinear/no_inter_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                            #   inter_sample_delay=None,
                            #   inter_average_delay=None,
                            #   samples_to_av=20, 
                              gap_sizeL_us=1500, 
                              gap_sizeS_us=1200)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_no_inter_20 = pd.DataFrame(all_dictionaries).transpose()
df_no_inter_20
# Out:
#                                                       0             1  \
# Filename                                   05130001.TXT  05130002.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                              18.78         18.78
# Median_Gap_us                                    1065.0       1064.95
# Large_Gap_Analysis_ms                               1.5           1.5
# Count_of_Long_Gaps                                  229           233
# Largest_Gaps_ms                                    80.7         12.56
# Small_Gap_Analysis_ms                               1.2           1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms       1213.58       1152.95
# Time_Length_of_File_ms                         4999.992      4999.759
# Time_Length_of_File_s                               5.0           5.0
# Dead_Time_Percentage                             24.272         23.06
#
#                                                       2             3  \
# Filename                                   05130003.TXT  05130004.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                              18.78         18.78
# Median_Gap_us                                    1065.0        1065.0
# Large_Gap_Analysis_ms                               1.5           1.5
# Count_of_Long_Gaps                                  224           233
# Largest_Gaps_ms                                  125.79         12.39
# Small_Gap_Analysis_ms                               1.2           1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms       1286.78        1152.3
# Time_Length_of_File_ms                          4999.76       4999.55
# Time_Length_of_File_s                               5.0           5.0
# Dead_Time_Percentage                             25.737        23.048
#
#                                                       4
# Filename                                   05130005.TXT
# Samples_Averaged                                     20
# Inter_Sample_delay                                  1.0
# Inter_Average_delay                                 1.0
# Sample_Frequency_KHz                              18.73
# Median_Gap_us                                    1068.0
# Large_Gap_Analysis_ms                               1.5
# Count_of_Long_Gaps                                  243
# Largest_Gaps_ms                                   12.47
# Small_Gap_Analysis_ms                               1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms       1201.08
# Time_Length_of_File_ms                         4999.764
# Time_Length_of_File_s                               5.0
# Dead_Time_Percentage                             24.023

# %%
result = pd.concat([df_M0_50_50_4,df_M0_50_500_20,df_M0_50_1500_20,df_no_inter_2,df_no_inter_4,df_no_inter_20], axis=1, ignore_index=True)

result
# Out:
#                                                      0             1   \
# Filename                                   05080001.TXT  05080002.TXT
# Samples_Averaged                                      4             4
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                                50.0          50.0
# Sample_Frequency_KHz                               6.76          6.76
# Median_Gap_us                                     591.5         592.0
# Large_Gap_Analysis_ms                               5.0           5.0
# Count_of_Long_Gaps                                    9            13
# Largest_Gaps_ms                                   14.27         23.93
# Small_Gap_Analysis_ms                               2.0           2.0
# Sum_of_Durations_Larger_than_Small_Gap_ms       1581.94       1588.63
# Time_Length_of_File_ms                          4999.83      4999.726
# Time_Length_of_File_s                               5.0           5.0
# Dead_Time_Percentage                              31.64        31.774
#
#                                                      2             3   \
# Filename                                   05080003.TXT  05080004.TXT
# Samples_Averaged                                      4             4
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                                50.0          50.0
# Sample_Frequency_KHz                               6.75          6.75
# Median_Gap_us                                     593.0         593.0
# Large_Gap_Analysis_ms                               5.0           5.0
# Count_of_Long_Gaps                                   12            19
# Largest_Gaps_ms                                   12.22         12.35
# Small_Gap_Analysis_ms                               2.0           2.0
# Sum_of_Durations_Larger_than_Small_Gap_ms       1576.42       1581.46
# Time_Length_of_File_ms                         4999.742      4997.745
# Time_Length_of_File_s                               5.0         4.998
# Dead_Time_Percentage                              31.53        31.643
#
#                                                      4             5   \
# Filename                                   05080005.TXT  05090001.TXT
# Samples_Averaged                                      4            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                                50.0         500.0
# Sample_Frequency_KHz                               6.75          7.62
# Median_Gap_us                                     593.0       2625.95
# Large_Gap_Analysis_ms                               5.0           3.0
# Count_of_Long_Gaps                                   15           105
# Largest_Gaps_ms                                  124.96          8.33
# Small_Gap_Analysis_ms                               2.0           3.0
# Sum_of_Durations_Larger_than_Small_Gap_ms       1723.45        685.62
# Time_Length_of_File_ms                         4999.522      4997.104
# Time_Length_of_File_s                               5.0         4.997
# Dead_Time_Percentage                             34.472         13.72
#
#                                                      6             7   \
# Filename                                   05090002.TXT  05090003.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                               500.0         500.0
# Sample_Frequency_KHz                               7.61          7.61
# Median_Gap_us                                   2627.05       2627.85
# Large_Gap_Analysis_ms                               3.0           3.0
# Count_of_Long_Gaps                                  105           105
# Largest_Gaps_ms                                    8.39           8.4
# Small_Gap_Analysis_ms                               3.0           3.0
# Sum_of_Durations_Larger_than_Small_Gap_ms        687.87        687.93
# Time_Length_of_File_ms                         4998.738      4999.543
# Time_Length_of_File_s                             4.999           5.0
# Dead_Time_Percentage                             13.761         13.76
#
#                                                      8             9   ...  \
# Filename                                   05090004.TXT  05090005.TXT  ...
# Samples_Averaged                                     20            20  ...
# Inter_Sample_delay                                 50.0          50.0  ...
# Inter_Average_delay                               500.0         500.0  ...
# Sample_Frequency_KHz                               7.61          7.61  ...
# Median_Gap_us                                    2627.9       2627.15  ...
# Large_Gap_Analysis_ms                               3.0           3.0  ...
# Count_of_Long_Gaps                                  105           105  ...
# Largest_Gaps_ms                                    7.86         11.73  ...
# Small_Gap_Analysis_ms                               3.0           3.0  ...
# Sum_of_Durations_Larger_than_Small_Gap_ms        683.04        693.59  ...
# Time_Length_of_File_ms                         4997.436       4999.83  ...
# Time_Length_of_File_s                             4.997           5.0  ...
# Dead_Time_Percentage                             13.668        13.872  ...
#
#                                                      20            21  \
# Filename                                   05120001.TXT  05120002.TXT
# Samples_Averaged                                      4             4
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                              11.98         11.98
# Median_Gap_us                                     334.0         334.0
# Large_Gap_Analysis_ms                               0.7           0.7
# Count_of_Long_Gaps                                  589           589
# Largest_Gaps_ms                                   13.53         12.77
# Small_Gap_Analysis_ms                               0.5           0.5
# Sum_of_Durations_Larger_than_Small_Gap_ms       1946.52       1947.27
# Time_Length_of_File_ms                         4999.925      4999.904
# Time_Length_of_File_s                               5.0           5.0
# Dead_Time_Percentage                             38.931        38.946
#
#                                                      22            23  \
# Filename                                   05120003.TXT  05120004.TXT
# Samples_Averaged                                      4             4
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                              11.98         11.98
# Median_Gap_us                                     334.0         334.0
# Large_Gap_Analysis_ms                               0.7           0.7
# Count_of_Long_Gaps                                  588           588
# Largest_Gaps_ms                                   13.39         10.94
# Small_Gap_Analysis_ms                               0.5           0.5
# Sum_of_Durations_Larger_than_Small_Gap_ms       1950.34       1948.97
# Time_Length_of_File_ms                         4999.847       4998.49
# Time_Length_of_File_s                               5.0         4.998
# Dead_Time_Percentage                             39.008        38.991
#
#                                                      24            25  \
# Filename                                   05120005.TXT  05130001.TXT
# Samples_Averaged                                      4            20
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                               12.0         18.78
# Median_Gap_us                                    333.25        1065.0
# Large_Gap_Analysis_ms                               0.7           1.5
# Count_of_Long_Gaps                                  468           229
# Largest_Gaps_ms                                   129.8          80.7
# Small_Gap_Analysis_ms                               0.5           1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms       2577.62       1213.58
# Time_Length_of_File_ms                         4999.818      4999.992
# Time_Length_of_File_s                               5.0           5.0
# Dead_Time_Percentage                             51.554        24.272
#
#                                                      26            27  \
# Filename                                   05130002.TXT  05130003.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                              18.78         18.78
# Median_Gap_us                                   1064.95        1065.0
# Large_Gap_Analysis_ms                               1.5           1.5
# Count_of_Long_Gaps                                  233           224
# Largest_Gaps_ms                                   12.56        125.79
# Small_Gap_Analysis_ms                               1.2           1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms       1152.95       1286.78
# Time_Length_of_File_ms                         4999.759       4999.76
# Time_Length_of_File_s                               5.0           5.0
# Dead_Time_Percentage                              23.06        25.737
#
#                                                      28            29
# Filename                                   05130004.TXT  05130005.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                              18.78         18.73
# Median_Gap_us                                    1065.0        1068.0
# Large_Gap_Analysis_ms                               1.5           1.5
# Count_of_Long_Gaps                                  233           243
# Largest_Gaps_ms                                   12.39         12.47
# Small_Gap_Analysis_ms                               1.2           1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms        1152.3       1201.08
# Time_Length_of_File_ms                          4999.55      4999.764
# Time_Length_of_File_s                               5.0           5.0
# Dead_Time_Percentage                             23.048        24.023
#
# [14 rows x 30 columns]
