# %%
import os
import pandas as pd
from analysis_plotter_tLin import analyze, quickLook

directory_path = 'M4_tLinear/50_50_4/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                            #   inter_sample_delay=50,
                            #   inter_average_delay=50,
                            #   samples_to_av=4, 
                              gap_sizeL_us=5_000, 
                              gap_sizeS_us=2000)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_50_50_4 = pd.DataFrame(all_dictionaries).transpose()
df_M0_50_50_4
# Out:
#                                                       0             1  \
# Filename                                   05070001.TXT  05070002.TXT
# Samples_Averaged                                      4             4
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                                50.0          50.0
# Sample_Frequency_KHz                                8.2           8.2
# Median_Gap_us                                     488.0         488.0
# Large_Gap_Analysis_ms                               5.0           5.0
# Count_of_Long_Gaps                                   43            44
# Largest_Gaps_ms                                   53.87        100.32
# Small_Gap_Analysis_ms                               2.0           2.0
# Sum_of_Durations_Larger_than_Small_Gap_ms       2160.63       2267.26
# Time_Length_of_File_ms                         4999.638      4999.665
# Time_Length_of_File_s                               5.0           5.0
# Dead_Time_Percentage                             43.216        45.348
#
#                                                       2             3  \
# Filename                                   05070003.TXT  05070004.TXT
# Samples_Averaged                                      4             4
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                                50.0          50.0
# Sample_Frequency_KHz                                8.2          8.19
# Median_Gap_us                                     488.0        488.25
# Large_Gap_Analysis_ms                               5.0           5.0
# Count_of_Long_Gaps                                   42            45
# Largest_Gaps_ms                                   52.92         55.05
# Small_Gap_Analysis_ms                               2.0           2.0
# Sum_of_Durations_Larger_than_Small_Gap_ms       2099.35       2253.46
# Time_Length_of_File_ms                         4963.646      4999.643
# Time_Length_of_File_s                             4.964           5.0
# Dead_Time_Percentage                             42.294        45.072
#
#                                                       4
# Filename                                   05070005.TXT
# Samples_Averaged                                      4
# Inter_Sample_delay                                 50.0
# Inter_Average_delay                                50.0
# Sample_Frequency_KHz                                8.2
# Median_Gap_us                                     488.0
# Large_Gap_Analysis_ms                               5.0
# Count_of_Long_Gaps                                   43
# Largest_Gaps_ms                                   55.07
# Small_Gap_Analysis_ms                               2.0
# Sum_of_Durations_Larger_than_Small_Gap_ms       2147.93
# Time_Length_of_File_ms                         4999.826
# Time_Length_of_File_s                               5.0
# Dead_Time_Percentage                              42.96

# %%
import os
import pandas as pd
from analysis_plotter_tLin import analyze, quickLook

directory_path = 'M4_tLinear/50_500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                            #   inter_sample_delay=50,
                            #   inter_average_delay=500,
                            #   samples_to_av=20, 
                              gap_sizeL_us=3000, 
                              gap_sizeS_us=3000)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_50_500_20 = pd.DataFrame(all_dictionaries).transpose()
df_M0_50_500_20
# Out:
#                                                       0             1  \
# Filename                                   05080001.TXT  05080002.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                               500.0         500.0
# Sample_Frequency_KHz                                7.7           7.7
# Median_Gap_us                                   2597.95       2597.95
# Large_Gap_Analysis_ms                               3.0           3.0
# Count_of_Long_Gaps                                   13            13
# Largest_Gaps_ms                                   55.37         55.51
# Small_Gap_Analysis_ms                               3.0           3.0
# Sum_of_Durations_Larger_than_Small_Gap_ms        687.63        683.33
# Time_Length_of_File_ms                         4955.475      4997.881
# Time_Length_of_File_s                             4.955         4.998
# Dead_Time_Percentage                             13.876        13.672
#
#                                                       2             3  \
# Filename                                   05080003.TXT  05080004.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                               500.0         500.0
# Sample_Frequency_KHz                                7.7           7.7
# Median_Gap_us                                   2597.95       2597.95
# Large_Gap_Analysis_ms                               3.0           3.0
# Count_of_Long_Gaps                                   13            13
# Largest_Gaps_ms                                    55.6         55.67
# Small_Gap_Analysis_ms                               3.0           3.0
# Sum_of_Durations_Larger_than_Small_Gap_ms         682.3        682.81
# Time_Length_of_File_ms                         4999.549      4997.474
# Time_Length_of_File_s                               5.0         4.997
# Dead_Time_Percentage                             13.647        13.663
#
#                                                       4
# Filename                                   05080005.TXT
# Samples_Averaged                                     20
# Inter_Sample_delay                                 50.0
# Inter_Average_delay                               500.0
# Sample_Frequency_KHz                                7.7
# Median_Gap_us                                   2597.95
# Large_Gap_Analysis_ms                               3.0
# Count_of_Long_Gaps                                   13
# Largest_Gaps_ms                                   59.43
# Small_Gap_Analysis_ms                               3.0
# Sum_of_Durations_Larger_than_Small_Gap_ms         684.9
# Time_Length_of_File_ms                          4999.63
# Time_Length_of_File_s                               5.0
# Dead_Time_Percentage                             13.699

# %%
import os
import pandas as pd
from analysis_plotter_tLin import analyze, quickLook

directory_path = 'M4_tLinear/50_1500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                            #   inter_sample_delay=50,
                            #   inter_average_delay=1500,
                            #   samples_to_av=20, 
                              gap_sizeL_us=4500, 
                              gap_sizeS_us=4000)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_50_1500_20 = pd.DataFrame(all_dictionaries).transpose()
df_M0_50_1500_20
# Out:
#                                                       0             1  \
# Filename                                   05090001.TXT  05090002.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                              1500.0        1500.0
# Sample_Frequency_KHz                               5.56          5.56
# Median_Gap_us                                    3597.9        3598.0
# Large_Gap_Analysis_ms                               4.5           4.5
# Count_of_Long_Gaps                                   10            13
# Largest_Gaps_ms                                   58.27         56.76
# Small_Gap_Analysis_ms                               4.0           4.0
# Sum_of_Durations_Larger_than_Small_Gap_ms        541.77        698.76
# Time_Length_of_File_ms                         4997.374      4999.756
# Time_Length_of_File_s                             4.997           5.0
# Dead_Time_Percentage                             10.841        13.976
#
#                                                       2             3  \
# Filename                                   05090003.TXT  05090004.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                              1500.0        1500.0
# Sample_Frequency_KHz                               5.56          5.56
# Median_Gap_us                                    3597.9       3597.95
# Large_Gap_Analysis_ms                               4.5           4.5
# Count_of_Long_Gaps                                    9             9
# Largest_Gaps_ms                                   54.98         58.83
# Small_Gap_Analysis_ms                               4.0           4.0
# Sum_of_Durations_Larger_than_Small_Gap_ms        479.83        483.67
# Time_Length_of_File_ms                         4996.622      4996.985
# Time_Length_of_File_s                             4.997         4.997
# Dead_Time_Percentage                              9.603         9.679
#
#                                                       4
# Filename                                   05090005.TXT
# Samples_Averaged                                     20
# Inter_Sample_delay                                 50.0
# Inter_Average_delay                              1500.0
# Sample_Frequency_KHz                               5.56
# Median_Gap_us                                   3597.95
# Large_Gap_Analysis_ms                               4.5
# Count_of_Long_Gaps                                    9
# Largest_Gaps_ms                                    58.9
# Small_Gap_Analysis_ms                               4.0
# Sum_of_Durations_Larger_than_Small_Gap_ms        483.92
# Time_Length_of_File_ms                         4997.205
# Time_Length_of_File_s                             4.997
# Dead_Time_Percentage                              9.684

# %%
import os
import pandas as pd
from analysis_plotter_tLin import analyze, quickLook

directory_path = 'M4_tLinear/no_inter_2/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                            #   inter_sample_delay=None,
                            #   inter_average_delay=None,
                            #   samples_to_av=2, 
                              gap_sizeL_us=700, 
                              gap_sizeS_us=450)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_no_inter_2 = pd.DataFrame(all_dictionaries).transpose()
df_no_inter_2
# Out:
#                                                       0             1  \
# Filename                                   05100001.TXT  05100002.TXT
# Samples_Averaged                                      2             2
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                               15.5          15.5
# Median_Gap_us                                     129.0         129.0
# Large_Gap_Analysis_ms                               0.7           0.7
# Count_of_Long_Gaps                                   72            72
# Largest_Gaps_ms                                   53.07         53.41
# Small_Gap_Analysis_ms                              0.45          0.45
# Sum_of_Durations_Larger_than_Small_Gap_ms       3595.53       3599.75
# Time_Length_of_File_ms                         4958.906      4999.878
# Time_Length_of_File_s                             4.959           5.0
# Dead_Time_Percentage                             72.507        71.997
#
#                                                       2             3  \
# Filename                                   05100003.TXT  05100004.TXT
# Samples_Averaged                                      2             2
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                               15.5          15.5
# Median_Gap_us                                     129.0         129.0
# Large_Gap_Analysis_ms                               0.7           0.7
# Count_of_Long_Gaps                                   72            73
# Largest_Gaps_ms                                   99.91         54.59
# Small_Gap_Analysis_ms                              0.45          0.45
# Sum_of_Durations_Larger_than_Small_Gap_ms       3645.37       3623.63
# Time_Length_of_File_ms                         4999.884      4980.108
# Time_Length_of_File_s                               5.0          4.98
# Dead_Time_Percentage                             72.909        72.762
#
#                                                       4
# Filename                                   05100005.TXT
# Samples_Averaged                                      2
# Inter_Sample_delay                                  1.0
# Inter_Average_delay                                 1.0
# Sample_Frequency_KHz                               15.5
# Median_Gap_us                                     129.0
# Large_Gap_Analysis_ms                               0.7
# Count_of_Long_Gaps                                   73
# Largest_Gaps_ms                                   57.24
# Small_Gap_Analysis_ms                              0.45
# Sum_of_Durations_Larger_than_Small_Gap_ms       3636.66
# Time_Length_of_File_ms                         4988.384
# Time_Length_of_File_s                             4.988
# Dead_Time_Percentage                             72.903

# %%
import os
import pandas as pd
from analysis_plotter_tLin import analyze, quickLook

directory_path = 'M4_tLinear/no_inter_4/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                            #   inter_sample_delay=None,
                            #   inter_average_delay=None,
                            #   samples_to_av=4, 
                              gap_sizeL_us=700, 
                              gap_sizeS_us=500)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_no_inter_4 = pd.DataFrame(all_dictionaries).transpose()
# df_no_inter_4

# %%
import os
import pandas as pd
from analysis_plotter_tLin import analyze, quickLook

directory_path = 'M4_tLinear/no_inter_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                            #   inter_sample_delay=None,
                            #   inter_average_delay=None,
                            #   samples_to_av=20, 
                              gap_sizeL_us=1500, 
                              gap_sizeS_us=1200)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_no_inter_20 = pd.DataFrame(all_dictionaries).transpose()
df_no_inter_20
# Out:
#                                                       0             1  \
# Filename                                   05120001.TXT  05120002.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                              18.33         18.33
# Median_Gap_us                                    1091.1        1091.0
# Large_Gap_Analysis_ms                               1.5           1.5
# Count_of_Long_Gaps                                   26            25
# Largest_Gaps_ms                                   57.06          55.7
# Small_Gap_Analysis_ms                               1.2           1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms        1334.7       1277.69
# Time_Length_of_File_ms                          4999.73       4999.33
# Time_Length_of_File_s                               5.0         4.999
# Dead_Time_Percentage                             26.695        25.557
#
#                                                       2             3  \
# Filename                                   05120003.TXT  05120004.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                              18.32         18.32
# Median_Gap_us                                   1091.75       1091.95
# Large_Gap_Analysis_ms                               1.5           1.5
# Count_of_Long_Gaps                                   28            25
# Largest_Gaps_ms                                   57.69         55.95
# Small_Gap_Analysis_ms                               1.2           1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms       1438.21       1275.66
# Time_Length_of_File_ms                         4992.189      4999.126
# Time_Length_of_File_s                             4.992         4.999
# Dead_Time_Percentage                             28.809        25.518
#
#                                                       4
# Filename                                   05120005.TXT
# Samples_Averaged                                     20
# Inter_Sample_delay                                  1.0
# Inter_Average_delay                                 1.0
# Sample_Frequency_KHz                              18.33
# Median_Gap_us                                   1090.95
# Large_Gap_Analysis_ms                               1.5
# Count_of_Long_Gaps                                   25
# Largest_Gaps_ms                                   58.01
# Small_Gap_Analysis_ms                               1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms       1282.51
# Time_Length_of_File_ms                         4992.052
# Time_Length_of_File_s                             4.992
# Dead_Time_Percentage                             25.691

# %%
result = pd.concat([df_M0_50_50_4,df_M0_50_500_20,df_M0_50_1500_20,df_no_inter_2,df_no_inter_4,df_no_inter_20], axis=1, ignore_index=True)

result
# Out:
#                                                      0             1   \
# Filename                                   05070001.TXT  05070002.TXT
# Samples_Averaged                                      4             4
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                                50.0          50.0
# Sample_Frequency_KHz                                8.2           8.2
# Median_Gap_us                                     488.0         488.0
# Large_Gap_Analysis_ms                               5.0           5.0
# Count_of_Long_Gaps                                   43            44
# Largest_Gaps_ms                                   53.87        100.32
# Small_Gap_Analysis_ms                               2.0           2.0
# Sum_of_Durations_Larger_than_Small_Gap_ms       2160.63       2267.26
# Time_Length_of_File_ms                         4999.638      4999.665
# Time_Length_of_File_s                               5.0           5.0
# Dead_Time_Percentage                             43.216        45.348
#
#                                                      2             3   \
# Filename                                   05070003.TXT  05070004.TXT
# Samples_Averaged                                      4             4
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                                50.0          50.0
# Sample_Frequency_KHz                                8.2          8.19
# Median_Gap_us                                     488.0        488.25
# Large_Gap_Analysis_ms                               5.0           5.0
# Count_of_Long_Gaps                                   42            45
# Largest_Gaps_ms                                   52.92         55.05
# Small_Gap_Analysis_ms                               2.0           2.0
# Sum_of_Durations_Larger_than_Small_Gap_ms       2099.35       2253.46
# Time_Length_of_File_ms                         4963.646      4999.643
# Time_Length_of_File_s                             4.964           5.0
# Dead_Time_Percentage                             42.294        45.072
#
#                                                      4             5   \
# Filename                                   05070005.TXT  05080001.TXT
# Samples_Averaged                                      4            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                                50.0         500.0
# Sample_Frequency_KHz                                8.2           7.7
# Median_Gap_us                                     488.0       2597.95
# Large_Gap_Analysis_ms                               5.0           3.0
# Count_of_Long_Gaps                                   43            13
# Largest_Gaps_ms                                   55.07         55.37
# Small_Gap_Analysis_ms                               2.0           3.0
# Sum_of_Durations_Larger_than_Small_Gap_ms       2147.93        687.63
# Time_Length_of_File_ms                         4999.826      4955.475
# Time_Length_of_File_s                               5.0         4.955
# Dead_Time_Percentage                              42.96        13.876
#
#                                                      6             7   \
# Filename                                   05080002.TXT  05080003.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                               500.0         500.0
# Sample_Frequency_KHz                                7.7           7.7
# Median_Gap_us                                   2597.95       2597.95
# Large_Gap_Analysis_ms                               3.0           3.0
# Count_of_Long_Gaps                                   13            13
# Largest_Gaps_ms                                   55.51          55.6
# Small_Gap_Analysis_ms                               3.0           3.0
# Sum_of_Durations_Larger_than_Small_Gap_ms        683.33         682.3
# Time_Length_of_File_ms                         4997.881      4999.549
# Time_Length_of_File_s                             4.998           5.0
# Dead_Time_Percentage                             13.672        13.647
#
#                                                      8             9   ...  \
# Filename                                   05080004.TXT  05080005.TXT  ...
# Samples_Averaged                                     20            20  ...
# Inter_Sample_delay                                 50.0          50.0  ...
# Inter_Average_delay                               500.0         500.0  ...
# Sample_Frequency_KHz                                7.7           7.7  ...
# Median_Gap_us                                   2597.95       2597.95  ...
# Large_Gap_Analysis_ms                               3.0           3.0  ...
# Count_of_Long_Gaps                                   13            13  ...
# Largest_Gaps_ms                                   55.67         59.43  ...
# Small_Gap_Analysis_ms                               3.0           3.0  ...
# Sum_of_Durations_Larger_than_Small_Gap_ms        682.81         684.9  ...
# Time_Length_of_File_ms                         4997.474       4999.63  ...
# Time_Length_of_File_s                             4.997           5.0  ...
# Dead_Time_Percentage                             13.663        13.699  ...
#
#                                                      20            21  \
# Filename                                   05110001.TXT  05110002.TXT
# Samples_Averaged                                      4             4
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                               16.9          16.9
# Median_Gap_us                                    236.75        236.75
# Large_Gap_Analysis_ms                               0.7           0.7
# Count_of_Long_Gaps                                   60            61
# Largest_Gaps_ms                                   53.38         55.34
# Small_Gap_Analysis_ms                               0.5           0.5
# Sum_of_Durations_Larger_than_Small_Gap_ms       3011.82       3073.56
# Time_Length_of_File_ms                         4973.018      4967.988
# Time_Length_of_File_s                             4.973         4.968
# Dead_Time_Percentage                             60.563        61.867
#
#                                                      22            23  \
# Filename                                   05110003.TXT  05110004.TXT
# Samples_Averaged                                      4             4
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                              16.88         16.88
# Median_Gap_us                                     237.0         237.0
# Large_Gap_Analysis_ms                               0.7           0.7
# Count_of_Long_Gaps                                   60            60
# Largest_Gaps_ms                                   99.93          56.1
# Small_Gap_Analysis_ms                               0.5           0.5
# Sum_of_Durations_Larger_than_Small_Gap_ms       3059.81       2983.07
# Time_Length_of_File_ms                         4955.537      4979.716
# Time_Length_of_File_s                             4.956          4.98
# Dead_Time_Percentage                             61.745        59.905
#
#                                                      24            25  \
# Filename                                   05110005.TXT  05120001.TXT
# Samples_Averaged                                      4            20
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                              16.88         18.33
# Median_Gap_us                                     237.0        1091.1
# Large_Gap_Analysis_ms                               0.7           1.5
# Count_of_Long_Gaps                                   62            26
# Largest_Gaps_ms                                   54.64         57.06
# Small_Gap_Analysis_ms                               0.5           1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms       3083.12        1334.7
# Time_Length_of_File_ms                         4999.916       4999.73
# Time_Length_of_File_s                               5.0           5.0
# Dead_Time_Percentage                             61.664        26.695
#
#                                                      26            27  \
# Filename                                   05120002.TXT  05120003.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                              18.33         18.32
# Median_Gap_us                                    1091.0       1091.75
# Large_Gap_Analysis_ms                               1.5           1.5
# Count_of_Long_Gaps                                   25            28
# Largest_Gaps_ms                                    55.7         57.69
# Small_Gap_Analysis_ms                               1.2           1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms       1277.69       1438.21
# Time_Length_of_File_ms                          4999.33      4992.189
# Time_Length_of_File_s                             4.999         4.992
# Dead_Time_Percentage                             25.557        28.809
#
#                                                      28            29
# Filename                                   05120004.TXT  05120005.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                              18.32         18.33
# Median_Gap_us                                   1091.95       1090.95
# Large_Gap_Analysis_ms                               1.5           1.5
# Count_of_Long_Gaps                                   25            25
# Largest_Gaps_ms                                   55.95         58.01
# Small_Gap_Analysis_ms                               1.2           1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms       1275.66       1282.51
# Time_Length_of_File_ms                         4999.126      4992.052
# Time_Length_of_File_s                             4.999         4.992
# Dead_Time_Percentage                             25.518        25.691
#
# [14 rows x 30 columns]
