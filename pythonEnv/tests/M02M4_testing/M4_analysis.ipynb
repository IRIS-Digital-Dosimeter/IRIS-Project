# %%
import os
import pandas as pd
from analysis_plotter_2Pins import analyze_2pins, quickLook_2pins

directory_path = 'M4_t1/50_50_4/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze_2pins(file_path,prints=False,
                            #   inter_sample_delay=50,
                            #   inter_average_delay=50,
                            #   samples_to_av=4, 
                              gap_sizeL_us=5_000, 
                              gap_sizeS_us=2000)
        # quickLook_2pins(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_50_50_4 = pd.DataFrame(all_dictionaries).transpose()
df_M0_50_50_4
# Out:
#                                                       0             1  \
# Filename                                   05010001.TXT  05010002.TXT
# Samples_Averaged                                      4             4
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                                50.0          50.0
# Sample_Frequency_KHz                               2.07          2.07
# Median_Gap_us                                     482.0         482.0
# Large_Gap_Analysis_ms                               5.0           5.0
# Count_of_Long_Gaps                                   35            34
# Largest_Gaps_ms                                   53.46         53.82
# Small_Gap_Analysis_ms                               2.0           2.0
# Sum_of_Durations_Larger_than_Small_Gap_ms       1765.41       1709.56
# Time_Length_of_File_ms                         4999.579      4999.773
# Time_Length_of_File_s                               5.0           5.0
# Dead_Time_Percentage                             35.311        34.193
#
#                                                       2             3  \
# Filename                                   05010003.TXT  05010004.TXT
# Samples_Averaged                                      4             4
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                                50.0          50.0
# Sample_Frequency_KHz                               2.07          2.07
# Median_Gap_us                                     482.0         482.0
# Large_Gap_Analysis_ms                               5.0           5.0
# Count_of_Long_Gaps                                   37            34
# Largest_Gaps_ms                                   55.87         54.27
# Small_Gap_Analysis_ms                               2.0           2.0
# Sum_of_Durations_Larger_than_Small_Gap_ms       1874.84       1712.91
# Time_Length_of_File_ms                         4999.965      4981.544
# Time_Length_of_File_s                               5.0         4.982
# Dead_Time_Percentage                             37.497        34.385
#
#                                                       4
# Filename                                   05010005.TXT
# Samples_Averaged                                      4
# Inter_Sample_delay                                 50.0
# Inter_Average_delay                                50.0
# Sample_Frequency_KHz                               2.07
# Median_Gap_us                                     482.0
# Large_Gap_Analysis_ms                               5.0
# Count_of_Long_Gaps                                   36
# Largest_Gaps_ms                                   98.76
# Small_Gap_Analysis_ms                               2.0
# Sum_of_Durations_Larger_than_Small_Gap_ms       1861.79
# Time_Length_of_File_ms                         4999.698
# Time_Length_of_File_s                               5.0
# Dead_Time_Percentage                             37.238

# %%
import os
import pandas as pd
from analysis_plotter_2Pins import analyze_2pins, quickLook_2pins

directory_path = 'M4_t1/50_500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze_2pins(file_path,prints=False,
                            #   inter_sample_delay=50,
                            #   inter_average_delay=500,
                            #   samples_to_av=20, 
                              gap_sizeL_us=3000, 
                              gap_sizeS_us=3000)
        # quickLook_2pins(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_50_500_20 = pd.DataFrame(all_dictionaries).transpose()
df_M0_50_500_20
# Out:
#                                                       0             1  \
# Filename                                   05020001.TXT  05020002.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                               500.0         500.0
# Sample_Frequency_KHz                               0.39          0.39
# Median_Gap_us                                    2591.0        2591.0
# Large_Gap_Analysis_ms                               3.0           3.0
# Count_of_Long_Gaps                                    9             9
# Largest_Gaps_ms                                   58.39         56.88
# Small_Gap_Analysis_ms                               3.0           3.0
# Sum_of_Durations_Larger_than_Small_Gap_ms        473.84        472.37
# Time_Length_of_File_ms                          4998.98      4997.443
# Time_Length_of_File_s                             4.999         4.997
# Dead_Time_Percentage                              9.479         9.452
#
#                                                       2             3  \
# Filename                                   05020003.TXT  05020004.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                               500.0         500.0
# Sample_Frequency_KHz                               0.39          0.39
# Median_Gap_us                                    2591.0        2591.0
# Large_Gap_Analysis_ms                               3.0           3.0
# Count_of_Long_Gaps                                   10             9
# Largest_Gaps_ms                                   58.57         56.85
# Small_Gap_Analysis_ms                               3.0           3.0
# Sum_of_Durations_Larger_than_Small_Gap_ms         534.0        469.87
# Time_Length_of_File_ms                         4999.488      4997.534
# Time_Length_of_File_s                             4.999         4.998
# Dead_Time_Percentage                             10.681         9.402
#
#                                                       4
# Filename                                   05020005.TXT
# Samples_Averaged                                     20
# Inter_Sample_delay                                 50.0
# Inter_Average_delay                               500.0
# Sample_Frequency_KHz                               0.39
# Median_Gap_us                                    2591.0
# Large_Gap_Analysis_ms                               3.0
# Count_of_Long_Gaps                                    9
# Largest_Gaps_ms                                   56.87
# Small_Gap_Analysis_ms                               3.0
# Sum_of_Durations_Larger_than_Small_Gap_ms        471.91
# Time_Length_of_File_ms                         4999.742
# Time_Length_of_File_s                               5.0
# Dead_Time_Percentage                              9.439

# %%
import os
import pandas as pd
from analysis_plotter_2Pins import analyze_2pins, quickLook_2pins

directory_path = 'M4_t1/50_1500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze_2pins(file_path,prints=False,
                            #   inter_sample_delay=50,
                            #   inter_average_delay=1500,
                            #   samples_to_av=20, 
                              gap_sizeL_us=4500, 
                              gap_sizeS_us=4000)
        # quickLook_2pins(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_50_1500_20 = pd.DataFrame(all_dictionaries).transpose()
df_M0_50_1500_20
# Out:
#                                                       0             1  \
# Filename                                   05030001.TXT  05030002.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                              1500.0        1500.0
# Sample_Frequency_KHz                               0.28          0.28
# Median_Gap_us                                    3591.0        3591.0
# Large_Gap_Analysis_ms                               4.5           4.5
# Count_of_Long_Gaps                                    8             8
# Largest_Gaps_ms                                   56.81         58.67
# Small_Gap_Analysis_ms                               4.0           4.0
# Sum_of_Durations_Larger_than_Small_Gap_ms         427.7        432.09
# Time_Length_of_File_ms                         4999.982      4997.208
# Time_Length_of_File_s                               5.0         4.997
# Dead_Time_Percentage                              8.554         8.647
#
#                                                       2             3  \
# Filename                                   05030003.TXT  05030004.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                              1500.0        1500.0
# Sample_Frequency_KHz                               0.28          0.28
# Median_Gap_us                                    3591.0        3591.0
# Large_Gap_Analysis_ms                               4.5           4.5
# Count_of_Long_Gaps                                    7             8
# Largest_Gaps_ms                                   58.63         56.83
# Small_Gap_Analysis_ms                               4.0           4.0
# Sum_of_Durations_Larger_than_Small_Gap_ms        383.21        427.77
# Time_Length_of_File_ms                         4998.605      4996.579
# Time_Length_of_File_s                             4.999         4.997
# Dead_Time_Percentage                              7.666         8.561
#
#                                                       4
# Filename                                   05030005.TXT
# Samples_Averaged                                     20
# Inter_Sample_delay                                 50.0
# Inter_Average_delay                              1500.0
# Sample_Frequency_KHz                               0.28
# Median_Gap_us                                    3591.0
# Large_Gap_Analysis_ms                               4.5
# Count_of_Long_Gaps                                    7
# Largest_Gaps_ms                                   54.97
# Small_Gap_Analysis_ms                               4.0
# Sum_of_Durations_Larger_than_Small_Gap_ms        374.55
# Time_Length_of_File_ms                         4997.089
# Time_Length_of_File_s                             4.997
# Dead_Time_Percentage                              7.495

# %%
import os
import pandas as pd
from analysis_plotter_2Pins import analyze_2pins, quickLook_2pins

directory_path = 'M4_t1/no_inter_2/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze_2pins(file_path,prints=False,
                            #   inter_sample_delay=None,
                            #   inter_average_delay=None,
                            #   samples_to_av=2, 
                              gap_sizeL_us=700, 
                              gap_sizeS_us=450)
        # quickLook_2pins(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_no_inter_2 = pd.DataFrame(all_dictionaries).transpose()
df_no_inter_2
# Out:
#                                                       0             1  \
# Filename                                   05040001.TXT  05040002.TXT
# Samples_Averaged                                      2             2
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                               8.13          8.13
# Median_Gap_us                                     123.0         123.0
# Large_Gap_Analysis_ms                               0.7           0.7
# Count_of_Long_Gaps                                   66            64
# Largest_Gaps_ms                                   55.47         55.83
# Small_Gap_Analysis_ms                              0.45          0.45
# Sum_of_Durations_Larger_than_Small_Gap_ms       3306.62       3209.05
# Time_Length_of_File_ms                         4999.919      4942.114
# Time_Length_of_File_s                               5.0         4.942
# Dead_Time_Percentage                             66.134        64.933
#
#                                                       2             3  \
# Filename                                   05040003.TXT  05040004.TXT
# Samples_Averaged                                      2             2
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                               8.13          8.13
# Median_Gap_us                                     123.0         123.0
# Large_Gap_Analysis_ms                               0.7           0.7
# Count_of_Long_Gaps                                   64            66
# Largest_Gaps_ms                                   54.37         54.94
# Small_Gap_Analysis_ms                              0.45          0.45
# Sum_of_Durations_Larger_than_Small_Gap_ms       3184.14        3282.8
# Time_Length_of_File_ms                         4974.453      4999.964
# Time_Length_of_File_s                             4.974           5.0
# Dead_Time_Percentage                              64.01        65.656
#
#                                                       4
# Filename                                   05040005.TXT
# Samples_Averaged                                      2
# Inter_Sample_delay                                  1.0
# Inter_Average_delay                                 1.0
# Sample_Frequency_KHz                               8.13
# Median_Gap_us                                     123.0
# Large_Gap_Analysis_ms                               0.7
# Count_of_Long_Gaps                                   73
# Largest_Gaps_ms                                   55.52
# Small_Gap_Analysis_ms                              0.45
# Sum_of_Durations_Larger_than_Small_Gap_ms        3058.5
# Time_Length_of_File_ms                         4980.904
# Time_Length_of_File_s                             4.981
# Dead_Time_Percentage                             61.405

# %%
import os
import pandas as pd
from analysis_plotter_2Pins import analyze_2pins, quickLook_2pins

directory_path = 'M4_t1/no_inter_4/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze_2pins(file_path,prints=False,
                            #   inter_sample_delay=None,
                            #   inter_average_delay=None,
                            #   samples_to_av=4, 
                              gap_sizeL_us=700, 
                              gap_sizeS_us=500)
        # quickLook_2pins(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_no_inter_4 = pd.DataFrame(all_dictionaries).transpose()
# df_no_inter_4

# %%
import os
import pandas as pd
from analysis_plotter_2Pins import analyze_2pins, quickLook_2pins

directory_path = 'M4_t1/no_inter_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze_2pins(file_path,prints=False,
                            #   inter_sample_delay=None,
                            #   inter_average_delay=None,
                            #   samples_to_av=20, 
                              gap_sizeL_us=1500, 
                              gap_sizeS_us=1200)
        # quickLook_2pins(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_no_inter_20 = pd.DataFrame(all_dictionaries).transpose()
df_no_inter_20
# Out:
#                                                       0             1  \
# Filename                                   05060001.TXT  05060002.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                               0.92          0.92
# Median_Gap_us                                    1082.0        1082.0
# Large_Gap_Analysis_ms                               1.5           1.5
# Count_of_Long_Gaps                                   20            19
# Largest_Gaps_ms                                   55.34         54.33
# Small_Gap_Analysis_ms                               1.2           1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms       1026.93        968.38
# Time_Length_of_File_ms                         4999.045      4999.574
# Time_Length_of_File_s                             4.999           5.0
# Dead_Time_Percentage                             20.542        19.369
#
#                                                       2             3  \
# Filename                                   05060003.TXT  05060004.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                               0.92          0.93
# Median_Gap_us                                    1082.0        1081.0
# Large_Gap_Analysis_ms                               1.5           1.5
# Count_of_Long_Gaps                                   19            22
# Largest_Gaps_ms                                   54.36         54.55
# Small_Gap_Analysis_ms                               1.2           1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms        964.99       1129.89
# Time_Length_of_File_ms                         4999.308       4978.94
# Time_Length_of_File_s                             4.999         4.979
# Dead_Time_Percentage                             19.302        22.693
#
#                                                       4
# Filename                                   05060005.TXT
# Samples_Averaged                                     20
# Inter_Sample_delay                                  1.0
# Inter_Average_delay                                 1.0
# Sample_Frequency_KHz                               0.93
# Median_Gap_us                                    1081.0
# Large_Gap_Analysis_ms                               1.5
# Count_of_Long_Gaps                                   19
# Largest_Gaps_ms                                   54.64
# Small_Gap_Analysis_ms                               1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms        970.19
# Time_Length_of_File_ms                         4999.294
# Time_Length_of_File_s                             4.999
# Dead_Time_Percentage                             19.407

# %%
result = pd.concat([df_M0_50_50_4,df_M0_50_500_20,df_M0_50_1500_20,df_no_inter_2,df_no_inter_4,df_no_inter_20], axis=1, ignore_index=True)

result
# Out:
#                                                      0             1   \
# Filename                                   05010001.TXT  05010002.TXT
# Samples_Averaged                                      4             4
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                                50.0          50.0
# Sample_Frequency_KHz                               2.07          2.07
# Median_Gap_us                                     482.0         482.0
# Large_Gap_Analysis_ms                               5.0           5.0
# Count_of_Long_Gaps                                   35            34
# Largest_Gaps_ms                                   53.46         53.82
# Small_Gap_Analysis_ms                               2.0           2.0
# Sum_of_Durations_Larger_than_Small_Gap_ms       1765.41       1709.56
# Time_Length_of_File_ms                         4999.579      4999.773
# Time_Length_of_File_s                               5.0           5.0
# Dead_Time_Percentage                             35.311        34.193
#
#                                                      2             3   \
# Filename                                   05010003.TXT  05010004.TXT
# Samples_Averaged                                      4             4
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                                50.0          50.0
# Sample_Frequency_KHz                               2.07          2.07
# Median_Gap_us                                     482.0         482.0
# Large_Gap_Analysis_ms                               5.0           5.0
# Count_of_Long_Gaps                                   37            34
# Largest_Gaps_ms                                   55.87         54.27
# Small_Gap_Analysis_ms                               2.0           2.0
# Sum_of_Durations_Larger_than_Small_Gap_ms       1874.84       1712.91
# Time_Length_of_File_ms                         4999.965      4981.544
# Time_Length_of_File_s                               5.0         4.982
# Dead_Time_Percentage                             37.497        34.385
#
#                                                      4             5   \
# Filename                                   05010005.TXT  05020001.TXT
# Samples_Averaged                                      4            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                                50.0         500.0
# Sample_Frequency_KHz                               2.07          0.39
# Median_Gap_us                                     482.0        2591.0
# Large_Gap_Analysis_ms                               5.0           3.0
# Count_of_Long_Gaps                                   36             9
# Largest_Gaps_ms                                   98.76         58.39
# Small_Gap_Analysis_ms                               2.0           3.0
# Sum_of_Durations_Larger_than_Small_Gap_ms       1861.79        473.84
# Time_Length_of_File_ms                         4999.698       4998.98
# Time_Length_of_File_s                               5.0         4.999
# Dead_Time_Percentage                             37.238         9.479
#
#                                                      6             7   \
# Filename                                   05020002.TXT  05020003.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                               500.0         500.0
# Sample_Frequency_KHz                               0.39          0.39
# Median_Gap_us                                    2591.0        2591.0
# Large_Gap_Analysis_ms                               3.0           3.0
# Count_of_Long_Gaps                                    9            10
# Largest_Gaps_ms                                   56.88         58.57
# Small_Gap_Analysis_ms                               3.0           3.0
# Sum_of_Durations_Larger_than_Small_Gap_ms        472.37         534.0
# Time_Length_of_File_ms                         4997.443      4999.488
# Time_Length_of_File_s                             4.997         4.999
# Dead_Time_Percentage                              9.452        10.681
#
#                                                      8             9   ...  \
# Filename                                   05020004.TXT  05020005.TXT  ...
# Samples_Averaged                                     20            20  ...
# Inter_Sample_delay                                 50.0          50.0  ...
# Inter_Average_delay                               500.0         500.0  ...
# Sample_Frequency_KHz                               0.39          0.39  ...
# Median_Gap_us                                    2591.0        2591.0  ...
# Large_Gap_Analysis_ms                               3.0           3.0  ...
# Count_of_Long_Gaps                                    9             9  ...
# Largest_Gaps_ms                                   56.85         56.87  ...
# Small_Gap_Analysis_ms                               3.0           3.0  ...
# Sum_of_Durations_Larger_than_Small_Gap_ms        469.87        471.91  ...
# Time_Length_of_File_ms                         4997.534      4999.742  ...
# Time_Length_of_File_s                             4.998           5.0  ...
# Dead_Time_Percentage                              9.402         9.439  ...
#
#                                                      20            21  \
# Filename                                   05050001.TXT  05050002.TXT
# Samples_Averaged                                      4             4
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                               4.35          4.35
# Median_Gap_us                                     230.0         230.0
# Large_Gap_Analysis_ms                               0.7           0.7
# Count_of_Long_Gaps                                   52            53
# Largest_Gaps_ms                                   53.15         53.88
# Small_Gap_Analysis_ms                               0.5           0.5
# Sum_of_Durations_Larger_than_Small_Gap_ms       2606.81       2666.02
# Time_Length_of_File_ms                         4993.451      4957.904
# Time_Length_of_File_s                             4.993         4.958
# Dead_Time_Percentage                             52.205        53.773
#
#                                                      22            23  \
# Filename                                   05050003.TXT  05050004.TXT
# Samples_Averaged                                      4             4
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                               4.35          4.35
# Median_Gap_us                                     230.0         230.0
# Large_Gap_Analysis_ms                               0.7           0.7
# Count_of_Long_Gaps                                   52            52
# Largest_Gaps_ms                                   54.12        100.38
# Small_Gap_Analysis_ms                               0.5           0.5
# Sum_of_Durations_Larger_than_Small_Gap_ms       2606.52       2668.12
# Time_Length_of_File_ms                         4999.828      4961.341
# Time_Length_of_File_s                               5.0         4.961
# Dead_Time_Percentage                             52.132        53.778
#
#                                                      24            25  \
# Filename                                   05050005.TXT  05060001.TXT
# Samples_Averaged                                      4            20
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                               4.35          0.92
# Median_Gap_us                                     230.0        1082.0
# Large_Gap_Analysis_ms                               0.7           1.5
# Count_of_Long_Gaps                                   54            20
# Largest_Gaps_ms                                   56.74         55.34
# Small_Gap_Analysis_ms                               0.5           1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms       2701.32       1026.93
# Time_Length_of_File_ms                         4999.888      4999.045
# Time_Length_of_File_s                               5.0         4.999
# Dead_Time_Percentage                             54.028        20.542
#
#                                                      26            27  \
# Filename                                   05060002.TXT  05060003.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                               0.92          0.92
# Median_Gap_us                                    1082.0        1082.0
# Large_Gap_Analysis_ms                               1.5           1.5
# Count_of_Long_Gaps                                   19            19
# Largest_Gaps_ms                                   54.33         54.36
# Small_Gap_Analysis_ms                               1.2           1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms        968.38        964.99
# Time_Length_of_File_ms                         4999.574      4999.308
# Time_Length_of_File_s                               5.0         4.999
# Dead_Time_Percentage                             19.369        19.302
#
#                                                      28            29
# Filename                                   05060004.TXT  05060005.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                               0.93          0.93
# Median_Gap_us                                    1081.0        1081.0
# Large_Gap_Analysis_ms                               1.5           1.5
# Count_of_Long_Gaps                                   22            19
# Largest_Gaps_ms                                   54.55         54.64
# Small_Gap_Analysis_ms                               1.2           1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms       1129.89        970.19
# Time_Length_of_File_ms                          4978.94      4999.294
# Time_Length_of_File_s                             4.979         4.999
# Dead_Time_Percentage                             22.693        19.407
#
# [14 rows x 30 columns]
