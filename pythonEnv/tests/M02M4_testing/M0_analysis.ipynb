# %%
import os
import pandas as pd
from analysis_plotter_2Pins import analyze_2pins, quickLook_2pins

directory_path = 'M0_t1/50_50_4/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze_2pins(file_path,prints=False,
                            #   inter_sample_delay=50,
                            #   inter_average_delay=50,
                            #   samples_to_av=4, 
                              gap_sizeL_us=5_000, 
                              gap_sizeS_us=2000)
        # quickLook_2pins(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_50_50_4 = pd.DataFrame(all_dictionaries).transpose()
df_M0_50_50_4
# Out:
#                                                       0             1  \
# Filename                                   05010001.TXT  05010002.TXT
# Samples_Averaged                                      4             4
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                                50.0          50.0
# Sample_Frequency_KHz                               1.82          1.82
# Median_Gap_us                                     550.0         550.0
# Large_Gap_Analysis_ms                               5.0           5.0
# Count_of_Long_Gaps                                   12             9
# Largest_Gaps_ms                                   13.74         12.36
# Small_Gap_Analysis_ms                               2.0           2.0
# Sum_of_Durations_Larger_than_Small_Gap_ms       1298.13       1294.13
# Time_Length_of_File_ms                         4997.157      4999.861
# Time_Length_of_File_s                             4.997           5.0
# Dead_Time_Percentage                             25.977        25.883
#
#                                                       2             3  \
# Filename                                   05010003.TXT  05010004.TXT
# Samples_Averaged                                      4             4
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                                50.0          50.0
# Sample_Frequency_KHz                               1.82          1.82
# Median_Gap_us                                     549.0         549.0
# Large_Gap_Analysis_ms                               5.0           5.0
# Count_of_Long_Gaps                                   17            12
# Largest_Gaps_ms                                   12.34         14.96
# Small_Gap_Analysis_ms                               2.0           2.0
# Sum_of_Durations_Larger_than_Small_Gap_ms       1305.82       1297.09
# Time_Length_of_File_ms                         4999.689      4995.285
# Time_Length_of_File_s                               5.0         4.995
# Dead_Time_Percentage                             26.118        25.966
#
#                                                       4
# Filename                                   05010005.TXT
# Samples_Averaged                                      4
# Inter_Sample_delay                                 50.0
# Inter_Average_delay                                50.0
# Sample_Frequency_KHz                               1.82
# Median_Gap_us                                     549.0
# Large_Gap_Analysis_ms                               5.0
# Count_of_Long_Gaps                                   10
# Largest_Gaps_ms                                   15.46
# Small_Gap_Analysis_ms                               2.0
# Sum_of_Durations_Larger_than_Small_Gap_ms       1300.44
# Time_Length_of_File_ms                         4999.137
# Time_Length_of_File_s                             4.999
# Dead_Time_Percentage                             26.013

# %%
import os
import pandas as pd
from analysis_plotter_2Pins import analyze_2pins, quickLook_2pins

directory_path = 'M0_t1/50_500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze_2pins(file_path,prints=False,
                            #   inter_sample_delay=50,
                            #   inter_average_delay=500,
                            #   samples_to_av=20, 
                              gap_sizeL_us=3000, 
                              gap_sizeS_us=3000)
        # quickLook_2pins(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_50_500_20 = pd.DataFrame(all_dictionaries).transpose()
df_M0_50_500_20
# Out:
#                                                       0             1  \
# Filename                                   05020001.TXT  05020002.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                               500.0         500.0
# Sample_Frequency_KHz                               0.39          0.39
# Median_Gap_us                                    2577.0        2577.0
# Large_Gap_Analysis_ms                               3.0           3.0
# Count_of_Long_Gaps                                   78            78
# Largest_Gaps_ms                                     8.0          8.01
# Small_Gap_Analysis_ms                               3.0           3.0
# Sum_of_Durations_Larger_than_Small_Gap_ms        504.62        503.76
# Time_Length_of_File_ms                          4999.15      4998.372
# Time_Length_of_File_s                             4.999         4.998
# Dead_Time_Percentage                             10.094        10.078
#
#                                                       2             3  \
# Filename                                   05020003.TXT  05020004.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                               500.0         500.0
# Sample_Frequency_KHz                               0.39          0.39
# Median_Gap_us                                    2578.0        2578.0
# Large_Gap_Analysis_ms                               3.0           3.0
# Count_of_Long_Gaps                                   78            66
# Largest_Gaps_ms                                    8.02        183.37
# Small_Gap_Analysis_ms                               3.0           3.0
# Sum_of_Durations_Larger_than_Small_Gap_ms        503.94       1194.98
# Time_Length_of_File_ms                         4999.473      4999.852
# Time_Length_of_File_s                             4.999           5.0
# Dead_Time_Percentage                              10.08          23.9
#
#                                                       4
# Filename                                   05020005.TXT
# Samples_Averaged                                     20
# Inter_Sample_delay                                 50.0
# Inter_Average_delay                               500.0
# Sample_Frequency_KHz                               0.39
# Median_Gap_us                                    2578.0
# Large_Gap_Analysis_ms                               3.0
# Count_of_Long_Gaps                                   78
# Largest_Gaps_ms                                    7.38
# Small_Gap_Analysis_ms                               3.0
# Sum_of_Durations_Larger_than_Small_Gap_ms        499.67
# Time_Length_of_File_ms                         4997.922
# Time_Length_of_File_s                             4.998
# Dead_Time_Percentage                              9.998

# %%
import os
import pandas as pd
from analysis_plotter_2Pins import analyze_2pins, quickLook_2pins

directory_path = 'M0_t1/50_1500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze_2pins(file_path,prints=False,
                            #   inter_sample_delay=50,
                            #   inter_average_delay=1500,
                            #   samples_to_av=20, 
                              gap_sizeL_us=4500, 
                              gap_sizeS_us=4000)
        # quickLook_2pins(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_50_1500_20 = pd.DataFrame(all_dictionaries).transpose()
df_M0_50_1500_20
# Out:
#                                                       0             1  \
# Filename                                   05030001.TXT  05030002.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                              1500.0        1500.0
# Sample_Frequency_KHz                               0.28          0.28
# Median_Gap_us                                    3577.0        3577.0
# Large_Gap_Analysis_ms                               4.5           4.5
# Count_of_Long_Gaps                                   57            57
# Largest_Gaps_ms                                    8.52          8.35
# Small_Gap_Analysis_ms                               4.0           4.0
# Sum_of_Durations_Larger_than_Small_Gap_ms        422.88        422.37
# Time_Length_of_File_ms                         4997.566      4997.924
# Time_Length_of_File_s                             4.998         4.998
# Dead_Time_Percentage                              8.462         8.451
#
#                                                       2             3  \
# Filename                                   05030003.TXT  05030004.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                              1500.0        1500.0
# Sample_Frequency_KHz                               0.28          0.28
# Median_Gap_us                                    3578.0        3577.5
# Large_Gap_Analysis_ms                               4.5           4.5
# Count_of_Long_Gaps                                   57            57
# Largest_Gaps_ms                                    8.37          8.36
# Small_Gap_Analysis_ms                               4.0           4.0
# Sum_of_Durations_Larger_than_Small_Gap_ms        421.83        421.43
# Time_Length_of_File_ms                         4997.572      4997.132
# Time_Length_of_File_s                             4.998         4.997
# Dead_Time_Percentage                              8.441         8.433
#
#                                                       4
# Filename                                   05030005.TXT
# Samples_Averaged                                     20
# Inter_Sample_delay                                 50.0
# Inter_Average_delay                              1500.0
# Sample_Frequency_KHz                               0.28
# Median_Gap_us                                    3578.0
# Large_Gap_Analysis_ms                               4.5
# Count_of_Long_Gaps                                   57
# Largest_Gaps_ms                                    7.47
# Small_Gap_Analysis_ms                               4.0
# Sum_of_Durations_Larger_than_Small_Gap_ms        420.84
# Time_Length_of_File_ms                         4996.465
# Time_Length_of_File_s                             4.996
# Dead_Time_Percentage                              8.423

# %%
import os
import pandas as pd
from analysis_plotter_2Pins import analyze_2pins, quickLook_2pins

directory_path = 'M0_t1/no_inter_2/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze_2pins(file_path,prints=False,
                            #   inter_sample_delay=None,
                            #   inter_average_delay=None,
                            #   samples_to_av=2, 
                              gap_sizeL_us=700, 
                              gap_sizeS_us=450)
        # quickLook_2pins(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_no_inter_2 = pd.DataFrame(all_dictionaries).transpose()
df_no_inter_2
# Out:
#                                                       0             1  \
# Filename                                   05040001.TXT  05040002.TXT
# Samples_Averaged                                      2             2
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                               5.21          5.21
# Median_Gap_us                                     192.0         192.0
# Large_Gap_Analysis_ms                               0.7           0.7
# Count_of_Long_Gaps                                  634           643
# Largest_Gaps_ms                                   72.88         11.54
# Small_Gap_Analysis_ms                              0.45          0.45
# Sum_of_Durations_Larger_than_Small_Gap_ms       2007.05       1962.01
# Time_Length_of_File_ms                         4999.819      4997.835
# Time_Length_of_File_s                               5.0         4.998
# Dead_Time_Percentage                             40.143        39.257
#
#                                                       2             3  \
# Filename                                   05040003.TXT  05040004.TXT
# Samples_Averaged                                      2             2
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                               5.21          5.21
# Median_Gap_us                                     192.0         192.0
# Large_Gap_Analysis_ms                               0.7           0.7
# Count_of_Long_Gaps                                  629           633
# Largest_Gaps_ms                                  119.72          83.2
# Small_Gap_Analysis_ms                              0.45          0.45
# Sum_of_Durations_Larger_than_Small_Gap_ms       2028.24       2003.03
# Time_Length_of_File_ms                          4999.24      4998.638
# Time_Length_of_File_s                             4.999         4.999
# Dead_Time_Percentage                             40.571        40.072
#
#                                                       4
# Filename                                   05040005.TXT
# Samples_Averaged                                      2
# Inter_Sample_delay                                  1.0
# Inter_Average_delay                                 1.0
# Sample_Frequency_KHz                               5.21
# Median_Gap_us                                     192.0
# Large_Gap_Analysis_ms                               0.7
# Count_of_Long_Gaps                                  640
# Largest_Gaps_ms                                   15.29
# Small_Gap_Analysis_ms                              0.45
# Sum_of_Durations_Larger_than_Small_Gap_ms       1967.54
# Time_Length_of_File_ms                         4999.894
# Time_Length_of_File_s                               5.0
# Dead_Time_Percentage                             39.352

# %%
import os
import pandas as pd
from analysis_plotter_2Pins import analyze_2pins, quickLook_2pins

directory_path = 'M0_t1/no_inter_4/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze_2pins(file_path,prints=False,
                            #   inter_sample_delay=None,
                            #   inter_average_delay=None,
                            #   samples_to_av=4, 
                              gap_sizeL_us=700, 
                              gap_sizeS_us=500)
        # quickLook_2pins(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_no_inter_4 = pd.DataFrame(all_dictionaries).transpose()
# df_no_inter_4

# %%
import os
import pandas as pd
from analysis_plotter_2Pins import analyze_2pins, quickLook_2pins

directory_path = 'M0_t1/no_inter_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze_2pins(file_path,prints=False,
                            #   inter_sample_delay=None,
                            #   inter_average_delay=None,
                            #   samples_to_av=20, 
                              gap_sizeL_us=1500, 
                              gap_sizeS_us=1200)
        # quickLook_2pins(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_no_inter_20 = pd.DataFrame(all_dictionaries).transpose()
df_no_inter_20
# Out:
#                                                       0             1  \
# Filename                                   05060001.TXT  05060002.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                               0.98          0.98
# Median_Gap_us                                    1019.0        1019.0
# Large_Gap_Analysis_ms                               1.5           1.5
# Count_of_Long_Gaps                                  180           180
# Largest_Gaps_ms                                   14.06         12.76
# Small_Gap_Analysis_ms                               1.2           1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms        894.67        894.76
# Time_Length_of_File_ms                         4998.804      4998.999
# Time_Length_of_File_s                             4.999         4.999
# Dead_Time_Percentage                             17.898        17.899
#
#                                                       2             3  \
# Filename                                   05060003.TXT  05060004.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                               0.98          0.98
# Median_Gap_us                                    1020.0        1021.0
# Large_Gap_Analysis_ms                               1.5           1.5
# Count_of_Long_Gaps                                  180           180
# Largest_Gaps_ms                                   12.64         12.76
# Small_Gap_Analysis_ms                               1.2           1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms        901.43        893.43
# Time_Length_of_File_ms                         4999.499      4999.702
# Time_Length_of_File_s                             4.999           5.0
# Dead_Time_Percentage                              18.03         17.87
#
#                                                       4
# Filename                                   05060005.TXT
# Samples_Averaged                                     20
# Inter_Sample_delay                                  1.0
# Inter_Average_delay                                 1.0
# Sample_Frequency_KHz                               0.98
# Median_Gap_us                                    1021.0
# Large_Gap_Analysis_ms                               1.5
# Count_of_Long_Gaps                                  180
# Largest_Gaps_ms                                   13.65
# Small_Gap_Analysis_ms                               1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms        896.66
# Time_Length_of_File_ms                         4999.087
# Time_Length_of_File_s                             4.999
# Dead_Time_Percentage                             17.937

# %%
result = pd.concat([df_M0_50_50_4,df_M0_50_500_20,df_M0_50_1500_20,df_no_inter_2,df_no_inter_4,df_no_inter_20], axis=1, ignore_index=True)

result
# Out:
#                                                      0             1   \
# Filename                                   05010001.TXT  05010002.TXT
# Samples_Averaged                                      4             4
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                                50.0          50.0
# Sample_Frequency_KHz                               1.82          1.82
# Median_Gap_us                                     550.0         550.0
# Large_Gap_Analysis_ms                               5.0           5.0
# Count_of_Long_Gaps                                   12             9
# Largest_Gaps_ms                                   13.74         12.36
# Small_Gap_Analysis_ms                               2.0           2.0
# Sum_of_Durations_Larger_than_Small_Gap_ms       1298.13       1294.13
# Time_Length_of_File_ms                         4997.157      4999.861
# Time_Length_of_File_s                             4.997           5.0
# Dead_Time_Percentage                             25.977        25.883
#
#                                                      2             3   \
# Filename                                   05010003.TXT  05010004.TXT
# Samples_Averaged                                      4             4
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                                50.0          50.0
# Sample_Frequency_KHz                               1.82          1.82
# Median_Gap_us                                     549.0         549.0
# Large_Gap_Analysis_ms                               5.0           5.0
# Count_of_Long_Gaps                                   17            12
# Largest_Gaps_ms                                   12.34         14.96
# Small_Gap_Analysis_ms                               2.0           2.0
# Sum_of_Durations_Larger_than_Small_Gap_ms       1305.82       1297.09
# Time_Length_of_File_ms                         4999.689      4995.285
# Time_Length_of_File_s                               5.0         4.995
# Dead_Time_Percentage                             26.118        25.966
#
#                                                      4             5   \
# Filename                                   05010005.TXT  05020001.TXT
# Samples_Averaged                                      4            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                                50.0         500.0
# Sample_Frequency_KHz                               1.82          0.39
# Median_Gap_us                                     549.0        2577.0
# Large_Gap_Analysis_ms                               5.0           3.0
# Count_of_Long_Gaps                                   10            78
# Largest_Gaps_ms                                   15.46           8.0
# Small_Gap_Analysis_ms                               2.0           3.0
# Sum_of_Durations_Larger_than_Small_Gap_ms       1300.44        504.62
# Time_Length_of_File_ms                         4999.137       4999.15
# Time_Length_of_File_s                             4.999         4.999
# Dead_Time_Percentage                             26.013        10.094
#
#                                                      6             7   \
# Filename                                   05020002.TXT  05020003.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                 50.0          50.0
# Inter_Average_delay                               500.0         500.0
# Sample_Frequency_KHz                               0.39          0.39
# Median_Gap_us                                    2577.0        2578.0
# Large_Gap_Analysis_ms                               3.0           3.0
# Count_of_Long_Gaps                                   78            78
# Largest_Gaps_ms                                    8.01          8.02
# Small_Gap_Analysis_ms                               3.0           3.0
# Sum_of_Durations_Larger_than_Small_Gap_ms        503.76        503.94
# Time_Length_of_File_ms                         4998.372      4999.473
# Time_Length_of_File_s                             4.998         4.999
# Dead_Time_Percentage                             10.078         10.08
#
#                                                      8             9   ...  \
# Filename                                   05020004.TXT  05020005.TXT  ...
# Samples_Averaged                                     20            20  ...
# Inter_Sample_delay                                 50.0          50.0  ...
# Inter_Average_delay                               500.0         500.0  ...
# Sample_Frequency_KHz                               0.39          0.39  ...
# Median_Gap_us                                    2578.0        2578.0  ...
# Large_Gap_Analysis_ms                               3.0           3.0  ...
# Count_of_Long_Gaps                                   66            78  ...
# Largest_Gaps_ms                                  183.37          7.38  ...
# Small_Gap_Analysis_ms                               3.0           3.0  ...
# Sum_of_Durations_Larger_than_Small_Gap_ms       1194.98        499.67  ...
# Time_Length_of_File_ms                         4999.852      4997.922  ...
# Time_Length_of_File_s                               5.0         4.998  ...
# Dead_Time_Percentage                               23.9         9.998  ...
#
#                                                      20            21  \
# Filename                                   05050001.TXT  05050002.TXT
# Samples_Averaged                                      4             4
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                               3.53          3.53
# Median_Gap_us                                     283.0         283.0
# Large_Gap_Analysis_ms                               0.7           0.7
# Count_of_Long_Gaps                                  457           474
# Largest_Gaps_ms                                   11.89         11.75
# Small_Gap_Analysis_ms                               0.5           0.5
# Sum_of_Durations_Larger_than_Small_Gap_ms       1816.48       1699.53
# Time_Length_of_File_ms                         4999.828      4999.755
# Time_Length_of_File_s                               5.0           5.0
# Dead_Time_Percentage                             36.331        33.992
#
#                                                      22            23  \
# Filename                                   05050003.TXT  05050004.TXT
# Samples_Averaged                                      4             4
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                               3.53          3.52
# Median_Gap_us                                     283.0         284.0
# Large_Gap_Analysis_ms                               0.7           0.7
# Count_of_Long_Gaps                                  453           468
# Largest_Gaps_ms                                   12.18         14.76
# Small_Gap_Analysis_ms                               0.5           0.5
# Sum_of_Durations_Larger_than_Small_Gap_ms       1836.99       1728.08
# Time_Length_of_File_ms                         4997.052      4999.827
# Time_Length_of_File_s                             4.997           5.0
# Dead_Time_Percentage                             36.761        34.563
#
#                                                      24            25  \
# Filename                                   05050005.TXT  05060001.TXT
# Samples_Averaged                                      4            20
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                               3.52          0.98
# Median_Gap_us                                     284.0        1019.0
# Large_Gap_Analysis_ms                               0.7           1.5
# Count_of_Long_Gaps                                  462           180
# Largest_Gaps_ms                                   13.42         14.06
# Small_Gap_Analysis_ms                               0.5           1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms       1772.95        894.67
# Time_Length_of_File_ms                         4999.916      4998.804
# Time_Length_of_File_s                               5.0         4.999
# Dead_Time_Percentage                              35.46        17.898
#
#                                                      26            27  \
# Filename                                   05060002.TXT  05060003.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                               0.98          0.98
# Median_Gap_us                                    1019.0        1020.0
# Large_Gap_Analysis_ms                               1.5           1.5
# Count_of_Long_Gaps                                  180           180
# Largest_Gaps_ms                                   12.76         12.64
# Small_Gap_Analysis_ms                               1.2           1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms        894.76        901.43
# Time_Length_of_File_ms                         4998.999      4999.499
# Time_Length_of_File_s                             4.999         4.999
# Dead_Time_Percentage                             17.899         18.03
#
#                                                      28            29
# Filename                                   05060004.TXT  05060005.TXT
# Samples_Averaged                                     20            20
# Inter_Sample_delay                                  1.0           1.0
# Inter_Average_delay                                 1.0           1.0
# Sample_Frequency_KHz                               0.98          0.98
# Median_Gap_us                                    1021.0        1021.0
# Large_Gap_Analysis_ms                               1.5           1.5
# Count_of_Long_Gaps                                  180           180
# Largest_Gaps_ms                                   12.76         13.65
# Small_Gap_Analysis_ms                               1.2           1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms        893.43        896.66
# Time_Length_of_File_ms                         4999.702      4999.087
# Time_Length_of_File_s                               5.0         4.999
# Dead_Time_Percentage                              17.87        17.937
#
# [14 rows x 30 columns]
