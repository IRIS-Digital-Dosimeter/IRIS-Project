# %%
import os
import pandas as pd
from analysis_plotter import analyze, quickLook

directory_path = 'data_Buffers/'

# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=True)
        quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df = pd.DataFrame(all_dictionaries).transpose()
df
# Out:
# Sample Frequency from Median gap (KHz): 27.78
# Median gap (us):  36.0
#
# LARGE GAP ANALYSIS: 50 ms
# Count of long gaps:  20
# Largest gaps (ms):  152.396
#
# SMALL GAP ANALYSIS: 20 ms
# Sum of durations larger than 20 ms (ms): 4149.48
#
# File info & Dead Time
# Time Length of file (ms,s): 4996.97 , 5.00
# Dead time = (sum durations > 20 ms/Time length of file)
# Dead time %: 83.04
# Sample Frequency from Median gap (KHz): 27.78
# Median gap (us):  36.0
#
# LARGE GAP ANALYSIS: 50 ms
# Count of long gaps:  11
# Largest gaps (ms):  251.141
#
# SMALL GAP ANALYSIS: 20 ms
# Sum of durations larger than 20 ms (ms): 4136.69
#
# File info & Dead Time
# Time Length of file (ms,s): 4962.12 , 4.96
# Dead time = (sum durations > 20 ms/Time length of file)
# Dead time %: 83.37
# Sample Frequency from Median gap (KHz): 15.15
# Median gap (us):  66.0
#
# LARGE GAP ANALYSIS: 50 ms
# Count of long gaps:  8
# Largest gaps (ms):  52.522
#
# SMALL GAP ANALYSIS: 20 ms
# Sum of durations larger than 20 ms (ms): 3560.51
#
# File info & Dead Time
# Time Length of file (ms,s): 4964.20 , 4.96
# Dead time = (sum durations > 20 ms/Time length of file)
# Dead time %: 71.72
# Sample Frequency from Median gap (KHz): 15.15
# Median gap (us):  66.0
#
# LARGE GAP ANALYSIS: 50 ms
# Count of long gaps:  10
# Largest gaps (ms):  101.72
#
# SMALL GAP ANALYSIS: 20 ms
# Sum of durations larger than 20 ms (ms): 3615.63
#
# File info & Dead Time
# Time Length of file (ms,s): 4952.63 , 4.95
# Dead time = (sum durations > 20 ms/Time length of file)
# Dead time %: 73.00
#                                                       0             1  \
# Filename                                   16040001.txt  16040002.txt
# Samples_Averaged                                      1             1
# Inter_Sample_delay                                 None          None
# Inter_Average_delay                                None          None
# Sample_Frequency_KHz                              27.78         27.78
# Median_Gap_us                                      36.0          36.0
# Large_Gap_Analysis_ms                              50.0          50.0
# Count_of_Long_Gaps                                   20            11
# Largest_Gaps_ms                                   152.4        251.14
# Small_Gap_Analysis_ms                              20.0          20.0
# Sum_of_Durations_Larger_than_Small_Gap_ms       4149.48       4136.69
# Time_Length_of_File_ms                          4996.97       4962.12
# Time_Length_of_File_s                               5.0          4.96
# Dead_Time_Percentage                              83.04         83.37
#
#                                                       2             3
# Filename                                   16050001.txt  16050002.txt
# Samples_Averaged                                      1             1
# Inter_Sample_delay                                 None          None
# Inter_Average_delay                                None          None
# Sample_Frequency_KHz                              15.15         15.15
# Median_Gap_us                                      66.0          66.0
# Large_Gap_Analysis_ms                              50.0          50.0
# Count_of_Long_Gaps                                    8            10
# Largest_Gaps_ms                                   52.52        101.72
# Small_Gap_Analysis_ms                              20.0          20.0
# Sum_of_Durations_Larger_than_Small_Gap_ms       3560.51       3615.63
# Time_Length_of_File_ms                           4964.2       4952.63
# Time_Length_of_File_s                              4.96          4.95
# Dead_Time_Percentage                              71.72          73.0
