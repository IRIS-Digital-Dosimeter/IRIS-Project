# %%
import os
import pandas as pd
from analysis_plotter_serial import analyze, quickLook

directory_path = 'data/'

# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,samples_to_av=20, gap_sizeL_us=2_000, gap_sizeS_us=500)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df = pd.DataFrame(all_dictionaries).transpose()
df
# Out:
#                                                               0  \
# Filename                                   20231202_201402_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                         None
# Inter_Average_delay                                        None
# Sample_Frequency_KHz                                       0.24
# Median_Gap_us                                            4163.8
# Large_Gap_Analysis_ms                                       2.0
# Count_of_Long_Gaps                                          999
# Largest_Gaps_ms                                            4.78
# Small_Gap_Analysis_ms                                       0.5
# Sum_of_Durations_Larger_than_Small_Gap_ms               4158.11
# Time_Length_of_File_ms                                 4158.111
# Time_Length_of_File_s                                     4.158
# Dead_Time_Percentage                                      100.0
#
#                                                               1  \
# Filename                                   20231202_201406_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                         None
# Inter_Average_delay                                        None
# Sample_Frequency_KHz                                       0.25
# Median_Gap_us                                            3984.9
# Large_Gap_Analysis_ms                                       2.0
# Count_of_Long_Gaps                                          999
# Largest_Gaps_ms                                            4.63
# Small_Gap_Analysis_ms                                       0.5
# Sum_of_Durations_Larger_than_Small_Gap_ms                4005.2
# Time_Length_of_File_ms                                 4005.201
# Time_Length_of_File_s                                     4.005
# Dead_Time_Percentage                                      100.0
#
#                                                               2  \
# Filename                                   20231202_201410_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                         None
# Inter_Average_delay                                        None
# Sample_Frequency_KHz                                       0.25
# Median_Gap_us                                           4045.55
# Large_Gap_Analysis_ms                                       2.0
# Count_of_Long_Gaps                                          999
# Largest_Gaps_ms                                            4.69
# Small_Gap_Analysis_ms                                       0.5
# Sum_of_Durations_Larger_than_Small_Gap_ms               4052.47
# Time_Length_of_File_ms                                 4052.472
# Time_Length_of_File_s                                     4.052
# Dead_Time_Percentage                                      100.0
#
#                                                               3  \
# Filename                                   20231202_201414_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                         None
# Inter_Average_delay                                        None
# Sample_Frequency_KHz                                       0.25
# Median_Gap_us                                            3995.4
# Large_Gap_Analysis_ms                                       2.0
# Count_of_Long_Gaps                                          999
# Largest_Gaps_ms                                             4.5
# Small_Gap_Analysis_ms                                       0.5
# Sum_of_Durations_Larger_than_Small_Gap_ms                4008.8
# Time_Length_of_File_ms                                 4008.798
# Time_Length_of_File_s                                     4.009
# Dead_Time_Percentage                                      100.0
#
#                                                               4  \
# Filename                                   20231202_201418_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                         None
# Inter_Average_delay                                        None
# Sample_Frequency_KHz                                       0.24
# Median_Gap_us                                            4162.2
# Large_Gap_Analysis_ms                                       2.0
# Count_of_Long_Gaps                                          999
# Largest_Gaps_ms                                            4.73
# Small_Gap_Analysis_ms                                       0.5
# Sum_of_Durations_Larger_than_Small_Gap_ms               4154.66
# Time_Length_of_File_ms                                 4154.663
# Time_Length_of_File_s                                     4.155
# Dead_Time_Percentage                                      100.0
#
#                                                               5  \
# Filename                                   20231202_201422_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                         None
# Inter_Average_delay                                        None
# Sample_Frequency_KHz                                       0.24
# Median_Gap_us                                           4151.85
# Large_Gap_Analysis_ms                                       2.0
# Count_of_Long_Gaps                                          999
# Largest_Gaps_ms                                            6.04
# Small_Gap_Analysis_ms                                       0.5
# Sum_of_Durations_Larger_than_Small_Gap_ms               4151.49
# Time_Length_of_File_ms                                 4151.489
# Time_Length_of_File_s                                     4.151
# Dead_Time_Percentage                                      100.0
#
#                                                               6
# Filename                                   20231202_201426_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                         None
# Inter_Average_delay                                        None
# Sample_Frequency_KHz                                       0.25
# Median_Gap_us                                           4033.55
# Large_Gap_Analysis_ms                                       2.0
# Count_of_Long_Gaps                                          805
# Largest_Gaps_ms                                            4.57
# Small_Gap_Analysis_ms                                       0.5
# Sum_of_Durations_Larger_than_Small_Gap_ms               3251.71
# Time_Length_of_File_ms                                 3251.708
# Time_Length_of_File_s                                     3.252
# Dead_Time_Percentage                                      100.0
