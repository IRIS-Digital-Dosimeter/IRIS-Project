# %%
import os
import pandas as pd
from analysis_plotter_serial import analyze, quickLook

directory_path = 'data_M4/50_50_4/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                              inter_sample_delay=50,
                              inter_average_delay=50,
                              samples_to_av=4, 
                              gap_sizeL_us=900, 
                              gap_sizeS_us=750)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_50_50_4 = pd.DataFrame(all_dictionaries).transpose()
df_M0_50_50_4
# Out:
#                                                               0  \
# Filename                                   20231205_184828_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Theoretical_Frequency_KHz                                   4.0
# Sample_Frequency_KHz                                       1.21
# Large_Gap_selected_ms                                       0.9
# Small_Gap_selected_ms                                      0.75
# Median_Gap_us                                             813.0
# Count_of_gaps_larger_than_Large_Gap                          88
# Largest_Gaps_ms                                             1.4
# Smallest_Gap_ms                                            0.75
# Sum_of_Durations_Larger_than_Small_Gap_ms                825.78
# Time_Length_of_File_ms                                  826.524
# Time_Length_of_File_s                                     0.827
# Dead_Time_Percentage                                     99.909
#
#                                                               1  \
# Filename                                   20231205_184829_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Theoretical_Frequency_KHz                                   4.0
# Sample_Frequency_KHz                                      1.251
# Large_Gap_selected_ms                                       0.9
# Small_Gap_selected_ms                                      0.75
# Median_Gap_us                                             792.0
# Count_of_gaps_larger_than_Large_Gap                          21
# Largest_Gaps_ms                                             1.0
# Smallest_Gap_ms                                            0.75
# Sum_of_Durations_Larger_than_Small_Gap_ms                798.79
# Time_Length_of_File_ms                                   799.54
# Time_Length_of_File_s                                       0.8
# Dead_Time_Percentage                                     99.906
#
#                                                               2  \
# Filename                                   20231205_184830_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Theoretical_Frequency_KHz                                   4.0
# Sample_Frequency_KHz                                      1.223
# Large_Gap_selected_ms                                       0.9
# Small_Gap_selected_ms                                      0.75
# Median_Gap_us                                             800.0
# Count_of_gaps_larger_than_Large_Gap                          84
# Largest_Gaps_ms                                            1.17
# Smallest_Gap_ms                                            0.75
# Sum_of_Durations_Larger_than_Small_Gap_ms                813.31
# Time_Length_of_File_ms                                  817.804
# Time_Length_of_File_s                                     0.818
# Dead_Time_Percentage                                      99.45
#
#                                                               3  \
# Filename                                   20231205_184831_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Theoretical_Frequency_KHz                                   4.0
# Sample_Frequency_KHz                                      1.211
# Large_Gap_selected_ms                                       0.9
# Small_Gap_selected_ms                                      0.75
# Median_Gap_us                                             801.0
# Count_of_gaps_larger_than_Large_Gap                         121
# Largest_Gaps_ms                                            1.27
# Smallest_Gap_ms                                            0.75
# Sum_of_Durations_Larger_than_Small_Gap_ms                824.59
# Time_Length_of_File_ms                                  826.088
# Time_Length_of_File_s                                     0.826
# Dead_Time_Percentage                                     99.819
#
#                                                               4  \
# Filename                                   20231205_184832_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Theoretical_Frequency_KHz                                   4.0
# Sample_Frequency_KHz                                      1.208
# Large_Gap_selected_ms                                       0.9
# Small_Gap_selected_ms                                      0.75
# Median_Gap_us                                             810.5
# Count_of_gaps_larger_than_Large_Gap                         103
# Largest_Gaps_ms                                            1.21
# Smallest_Gap_ms                                            0.75
# Sum_of_Durations_Larger_than_Small_Gap_ms                824.88
# Time_Length_of_File_ms                                  827.874
# Time_Length_of_File_s                                     0.828
# Dead_Time_Percentage                                     99.638
#
#                                                               5  \
# Filename                                   20231205_184833_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Theoretical_Frequency_KHz                                   4.0
# Sample_Frequency_KHz                                      1.223
# Large_Gap_selected_ms                                       0.9
# Small_Gap_selected_ms                                      0.75
# Median_Gap_us                                             796.5
# Count_of_gaps_larger_than_Large_Gap                          85
# Largest_Gaps_ms                                            1.53
# Smallest_Gap_ms                                            0.75
# Sum_of_Durations_Larger_than_Small_Gap_ms                813.26
# Time_Length_of_File_ms                                  817.753
# Time_Length_of_File_s                                     0.818
# Dead_Time_Percentage                                      99.45
#
#                                                               6  \
# Filename                                   20231205_184834_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Theoretical_Frequency_KHz                                   4.0
# Sample_Frequency_KHz                                      1.209
# Large_Gap_selected_ms                                       0.9
# Small_Gap_selected_ms                                      0.75
# Median_Gap_us                                             799.5
# Count_of_gaps_larger_than_Large_Gap                         128
# Largest_Gaps_ms                                            1.31
# Smallest_Gap_ms                                            0.75
# Sum_of_Durations_Larger_than_Small_Gap_ms                823.49
# Time_Length_of_File_ms                                  827.234
# Time_Length_of_File_s                                     0.827
# Dead_Time_Percentage                                     99.547
#
#                                                               7
# Filename                                   20231205_184835_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Theoretical_Frequency_KHz                                   4.0
# Sample_Frequency_KHz                                      1.277
# Large_Gap_selected_ms                                       0.9
# Small_Gap_selected_ms                                      0.75
# Median_Gap_us                                             777.0
# Count_of_gaps_larger_than_Large_Gap                           3
# Largest_Gaps_ms                                            0.99
# Smallest_Gap_ms                                            0.75
# Sum_of_Durations_Larger_than_Small_Gap_ms                  87.9
# Time_Length_of_File_ms                                   91.644
# Time_Length_of_File_s                                     0.092
# Dead_Time_Percentage                                     95.913

# %%
import os
import pandas as pd
from analysis_plotter_serial import analyze, quickLook

directory_path = 'data_M4/50_500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                              inter_sample_delay=50,
                              inter_average_delay=500,
                              samples_to_av=20, 
                              gap_sizeL_us=3000, 
                              gap_sizeS_us=3000)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_50_500_4 = pd.DataFrame(all_dictionaries).transpose()
df_M0_50_500_4
# Out:
#                                                               0  \
# Filename                                   20231205_184952_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                         500
# Theoretical_Frequency_KHz                                 0.667
# Sample_Frequency_KHz                                      0.315
# Large_Gap_selected_ms                                       3.0
# Small_Gap_selected_ms                                       3.0
# Median_Gap_us                                            3172.5
# Count_of_gaps_larger_than_Large_Gap                         787
# Largest_Gaps_ms                                            3.66
# Smallest_Gap_ms                                            2.85
# Sum_of_Durations_Larger_than_Small_Gap_ms                2550.1
# Time_Length_of_File_ms                                  3173.15
# Time_Length_of_File_s                                     3.173
# Dead_Time_Percentage                                     80.365
#
#                                                               1  \
# Filename                                   20231205_184955_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                         500
# Theoretical_Frequency_KHz                                 0.667
# Sample_Frequency_KHz                                      0.311
# Large_Gap_selected_ms                                       3.0
# Small_Gap_selected_ms                                       3.0
# Median_Gap_us                                            3210.5
# Count_of_gaps_larger_than_Large_Gap                         850
# Largest_Gaps_ms                                            3.69
# Smallest_Gap_ms                                            2.86
# Sum_of_Durations_Larger_than_Small_Gap_ms               2776.62
# Time_Length_of_File_ms                                 3215.611
# Time_Length_of_File_s                                     3.216
# Dead_Time_Percentage                                     86.348
#
#                                                               2  \
# Filename                                   20231205_184958_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                         500
# Theoretical_Frequency_KHz                                 0.667
# Sample_Frequency_KHz                                      0.311
# Large_Gap_selected_ms                                       3.0
# Small_Gap_selected_ms                                       3.0
# Median_Gap_us                                            3210.0
# Count_of_gaps_larger_than_Large_Gap                         855
# Largest_Gaps_ms                                            3.76
# Smallest_Gap_ms                                            2.89
# Sum_of_Durations_Larger_than_Small_Gap_ms               2784.56
# Time_Length_of_File_ms                                 3210.553
# Time_Length_of_File_s                                     3.211
# Dead_Time_Percentage                                     86.731
#
#                                                               3  \
# Filename                                   20231205_185002_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                         500
# Theoretical_Frequency_KHz                                 0.667
# Sample_Frequency_KHz                                      0.311
# Large_Gap_selected_ms                                       3.0
# Small_Gap_selected_ms                                       3.0
# Median_Gap_us                                            3217.5
# Count_of_gaps_larger_than_Large_Gap                         885
# Largest_Gaps_ms                                            3.74
# Smallest_Gap_ms                                            2.84
# Sum_of_Durations_Larger_than_Small_Gap_ms               2882.32
# Time_Length_of_File_ms                                 3218.814
# Time_Length_of_File_s                                     3.219
# Dead_Time_Percentage                                     89.546
#
#                                                               4  \
# Filename                                   20231205_185005_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                         500
# Theoretical_Frequency_KHz                                 0.667
# Sample_Frequency_KHz                                      0.311
# Large_Gap_selected_ms                                       3.0
# Small_Gap_selected_ms                                       3.0
# Median_Gap_us                                            3222.0
# Count_of_gaps_larger_than_Large_Gap                         847
# Largest_Gaps_ms                                            3.75
# Smallest_Gap_ms                                            2.85
# Sum_of_Durations_Larger_than_Small_Gap_ms               2769.32
# Time_Length_of_File_ms                                 3217.995
# Time_Length_of_File_s                                     3.218
# Dead_Time_Percentage                                     86.057
#
#                                                               5  \
# Filename                                   20231205_185008_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                         500
# Theoretical_Frequency_KHz                                 0.667
# Sample_Frequency_KHz                                       0.31
# Large_Gap_selected_ms                                       3.0
# Small_Gap_selected_ms                                       3.0
# Median_Gap_us                                            3220.5
# Count_of_gaps_larger_than_Large_Gap                         890
# Largest_Gaps_ms                                            3.81
# Smallest_Gap_ms                                            2.84
# Sum_of_Durations_Larger_than_Small_Gap_ms               2903.56
# Time_Length_of_File_ms                                 3225.049
# Time_Length_of_File_s                                     3.225
# Dead_Time_Percentage                                     90.031
#
#                                                               6
# Filename                                   20231205_185011_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                         500
# Theoretical_Frequency_KHz                                 0.667
# Sample_Frequency_KHz                                      0.317
# Large_Gap_selected_ms                                       3.0
# Small_Gap_selected_ms                                       3.0
# Median_Gap_us                                            3161.5
# Count_of_gaps_larger_than_Large_Gap                         326
# Largest_Gaps_ms                                            3.64
# Smallest_Gap_ms                                            2.86
# Sum_of_Durations_Larger_than_Small_Gap_ms               1051.49
# Time_Length_of_File_ms                                  1331.68
# Time_Length_of_File_s                                     1.332
# Dead_Time_Percentage                                      78.96

# %%
import os
import pandas as pd
from analysis_plotter_serial import analyze, quickLook

directory_path = 'data_M4/50_1500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                              inter_sample_delay=50,
                              inter_average_delay=1500,
                              samples_to_av=20, 
                              gap_sizeL_us=4500, 
                              gap_sizeS_us=4000)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_50_1500_4 = pd.DataFrame(all_dictionaries).transpose()
df_M0_50_1500_4
# Out:
#                                                               0  \
# Filename                                   20231205_185115_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.236
# Large_Gap_selected_ms                                       4.5
# Small_Gap_selected_ms                                       4.0
# Median_Gap_us                                            4233.0
# Count_of_gaps_larger_than_Large_Gap                          87
# Largest_Gaps_ms                                            4.98
# Smallest_Gap_ms                                            3.85
# Sum_of_Durations_Larger_than_Small_Gap_ms               3781.41
# Time_Length_of_File_ms                                 4235.409
# Time_Length_of_File_s                                     4.235
# Dead_Time_Percentage                                     89.281
#
#                                                               1  \
# Filename                                   20231205_185119_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.236
# Large_Gap_selected_ms                                       4.5
# Small_Gap_selected_ms                                       4.0
# Median_Gap_us                                            4225.5
# Count_of_gaps_larger_than_Large_Gap                          96
# Largest_Gaps_ms                                            4.82
# Smallest_Gap_ms                                            3.85
# Sum_of_Durations_Larger_than_Small_Gap_ms               3723.45
# Time_Length_of_File_ms                                 4237.168
# Time_Length_of_File_s                                     4.237
# Dead_Time_Percentage                                     87.876
#
#                                                               2  \
# Filename                                   20231205_185124_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.236
# Large_Gap_selected_ms                                       4.5
# Small_Gap_selected_ms                                       4.0
# Median_Gap_us                                            4247.0
# Count_of_gaps_larger_than_Large_Gap                          91
# Largest_Gaps_ms                                            4.94
# Smallest_Gap_ms                                            3.86
# Sum_of_Durations_Larger_than_Small_Gap_ms               3796.42
# Time_Length_of_File_ms                                 4243.448
# Time_Length_of_File_s                                     4.243
# Dead_Time_Percentage                                     89.465
#
#                                                               3  \
# Filename                                   20231205_185128_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.234
# Large_Gap_selected_ms                                       4.5
# Small_Gap_selected_ms                                       4.0
# Median_Gap_us                                            4272.0
# Count_of_gaps_larger_than_Large_Gap                         119
# Largest_Gaps_ms                                            4.93
# Smallest_Gap_ms                                            3.87
# Sum_of_Durations_Larger_than_Small_Gap_ms               3880.85
# Time_Length_of_File_ms                                 4272.176
# Time_Length_of_File_s                                     4.272
# Dead_Time_Percentage                                      90.84
#
#                                                               4  \
# Filename                                   20231205_185132_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.238
# Large_Gap_selected_ms                                       4.5
# Small_Gap_selected_ms                                       4.0
# Median_Gap_us                                            4204.5
# Count_of_gaps_larger_than_Large_Gap                          68
# Largest_Gaps_ms                                            4.85
# Smallest_Gap_ms                                            3.85
# Sum_of_Durations_Larger_than_Small_Gap_ms               3651.73
# Time_Length_of_File_ms                                 4209.319
# Time_Length_of_File_s                                     4.209
# Dead_Time_Percentage                                     86.753
#
#                                                               5  \
# Filename                                   20231205_185136_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                       0.24
# Large_Gap_selected_ms                                       4.5
# Small_Gap_selected_ms                                       4.0
# Median_Gap_us                                            4141.5
# Count_of_gaps_larger_than_Large_Gap                          59
# Largest_Gaps_ms                                            4.79
# Smallest_Gap_ms                                            3.87
# Sum_of_Durations_Larger_than_Small_Gap_ms               3263.03
# Time_Length_of_File_ms                                 4168.046
# Time_Length_of_File_s                                     4.168
# Dead_Time_Percentage                                     78.287
#
#                                                               6
# Filename                                   20231205_185140_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Theoretical_Frequency_KHz                                   0.4
# Sample_Frequency_KHz                                      0.239
# Large_Gap_selected_ms                                       4.5
# Small_Gap_selected_ms                                       4.0
# Median_Gap_us                                           4184.75
# Count_of_gaps_larger_than_Large_Gap                          22
# Largest_Gaps_ms                                            4.67
# Smallest_Gap_ms                                            3.87
# Sum_of_Durations_Larger_than_Small_Gap_ms               1439.87
# Time_Length_of_File_ms                                 1767.537
# Time_Length_of_File_s                                     1.768
# Dead_Time_Percentage                                     81.462

# %%
result = pd.concat([df_M0_50_50_4,df_M0_50_500_4,df_M0_50_1500_4], axis=1, ignore_index=True)

result
# Out:
#                                                              0   \
# Filename                                   20231205_184828_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Sample_Frequency_KHz                                       1.21
# Median_Gap_us                                             813.0
# Large_Gap_Analysis_ms                                       0.9
# Count_of_Long_Gaps                                           88
# Largest_Gaps_ms                                             1.4
# Small_Gap_Analysis_ms                                      0.75
# Sum_of_Durations_Larger_than_Small_Gap_ms                825.78
# Time_Length_of_File_ms                                  826.524
# Time_Length_of_File_s                                     0.827
# Dead_Time_Percentage                                     99.909
#
#                                                              1   \
# Filename                                   20231205_184829_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Sample_Frequency_KHz                                       1.25
# Median_Gap_us                                             792.0
# Large_Gap_Analysis_ms                                       0.9
# Count_of_Long_Gaps                                           21
# Largest_Gaps_ms                                             1.0
# Small_Gap_Analysis_ms                                      0.75
# Sum_of_Durations_Larger_than_Small_Gap_ms                798.79
# Time_Length_of_File_ms                                   799.54
# Time_Length_of_File_s                                       0.8
# Dead_Time_Percentage                                     99.906
#
#                                                              2   \
# Filename                                   20231205_184830_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Sample_Frequency_KHz                                       1.22
# Median_Gap_us                                             800.0
# Large_Gap_Analysis_ms                                       0.9
# Count_of_Long_Gaps                                           84
# Largest_Gaps_ms                                            1.17
# Small_Gap_Analysis_ms                                      0.75
# Sum_of_Durations_Larger_than_Small_Gap_ms                813.31
# Time_Length_of_File_ms                                  817.804
# Time_Length_of_File_s                                     0.818
# Dead_Time_Percentage                                      99.45
#
#                                                              3   \
# Filename                                   20231205_184831_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Sample_Frequency_KHz                                       1.21
# Median_Gap_us                                             801.0
# Large_Gap_Analysis_ms                                       0.9
# Count_of_Long_Gaps                                          121
# Largest_Gaps_ms                                            1.27
# Small_Gap_Analysis_ms                                      0.75
# Sum_of_Durations_Larger_than_Small_Gap_ms                824.59
# Time_Length_of_File_ms                                  826.088
# Time_Length_of_File_s                                     0.826
# Dead_Time_Percentage                                     99.819
#
#                                                              4   \
# Filename                                   20231205_184832_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Sample_Frequency_KHz                                       1.21
# Median_Gap_us                                             810.5
# Large_Gap_Analysis_ms                                       0.9
# Count_of_Long_Gaps                                          103
# Largest_Gaps_ms                                            1.21
# Small_Gap_Analysis_ms                                      0.75
# Sum_of_Durations_Larger_than_Small_Gap_ms                824.88
# Time_Length_of_File_ms                                  827.874
# Time_Length_of_File_s                                     0.828
# Dead_Time_Percentage                                     99.638
#
#                                                              5   \
# Filename                                   20231205_184833_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Sample_Frequency_KHz                                       1.22
# Median_Gap_us                                             796.5
# Large_Gap_Analysis_ms                                       0.9
# Count_of_Long_Gaps                                           85
# Largest_Gaps_ms                                            1.53
# Small_Gap_Analysis_ms                                      0.75
# Sum_of_Durations_Larger_than_Small_Gap_ms                813.26
# Time_Length_of_File_ms                                  817.753
# Time_Length_of_File_s                                     0.818
# Dead_Time_Percentage                                      99.45
#
#                                                              6   \
# Filename                                   20231205_184834_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Sample_Frequency_KHz                                       1.21
# Median_Gap_us                                             799.5
# Large_Gap_Analysis_ms                                       0.9
# Count_of_Long_Gaps                                          128
# Largest_Gaps_ms                                            1.31
# Small_Gap_Analysis_ms                                      0.75
# Sum_of_Durations_Larger_than_Small_Gap_ms                823.49
# Time_Length_of_File_ms                                  827.234
# Time_Length_of_File_s                                     0.827
# Dead_Time_Percentage                                     99.547
#
#                                                              7   \
# Filename                                   20231205_184835_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Sample_Frequency_KHz                                       1.28
# Median_Gap_us                                             777.0
# Large_Gap_Analysis_ms                                       0.9
# Count_of_Long_Gaps                                            3
# Largest_Gaps_ms                                            0.99
# Small_Gap_Analysis_ms                                      0.75
# Sum_of_Durations_Larger_than_Small_Gap_ms                  87.9
# Time_Length_of_File_ms                                   91.644
# Time_Length_of_File_s                                     0.092
# Dead_Time_Percentage                                     95.913
#
#                                                              8   \
# Filename                                   20231205_184952_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                         500
# Sample_Frequency_KHz                                       0.32
# Median_Gap_us                                            3172.5
# Large_Gap_Analysis_ms                                       3.0
# Count_of_Long_Gaps                                          787
# Largest_Gaps_ms                                            3.66
# Small_Gap_Analysis_ms                                       3.0
# Sum_of_Durations_Larger_than_Small_Gap_ms                2550.1
# Time_Length_of_File_ms                                  3173.15
# Time_Length_of_File_s                                     3.173
# Dead_Time_Percentage                                     80.365
#
#                                                              9   ...  \
# Filename                                   20231205_184955_.txt  ...
# Samples_Averaged                                             20  ...
# Inter_Sample_delay                                           50  ...
# Inter_Average_delay                                         500  ...
# Sample_Frequency_KHz                                       0.31  ...
# Median_Gap_us                                            3210.5  ...
# Large_Gap_Analysis_ms                                       3.0  ...
# Count_of_Long_Gaps                                          850  ...
# Largest_Gaps_ms                                            3.69  ...
# Small_Gap_Analysis_ms                                       3.0  ...
# Sum_of_Durations_Larger_than_Small_Gap_ms               2776.62  ...
# Time_Length_of_File_ms                                 3215.611  ...
# Time_Length_of_File_s                                     3.216  ...
# Dead_Time_Percentage                                     86.348  ...
#
#                                                              34  \
# Filename                                   20231205_185331_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                         None
# Inter_Average_delay                                        None
# Sample_Frequency_KHz                                       1.86
# Median_Gap_us                                             523.5
# Large_Gap_Analysis_ms                                       0.7
# Count_of_Long_Gaps                                           15
# Largest_Gaps_ms                                             1.0
# Small_Gap_Analysis_ms                                       0.5
# Sum_of_Durations_Larger_than_Small_Gap_ms                526.16
# Time_Length_of_File_ms                                  537.632
# Time_Length_of_File_s                                     0.538
# Dead_Time_Percentage                                     97.867
#
#                                                              35  \
# Filename                                   20231205_185332_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                         None
# Inter_Average_delay                                        None
# Sample_Frequency_KHz                                       1.81
# Median_Gap_us                                             539.5
# Large_Gap_Analysis_ms                                       0.7
# Count_of_Long_Gaps                                           25
# Largest_Gaps_ms                                            0.99
# Small_Gap_Analysis_ms                                       0.5
# Sum_of_Durations_Larger_than_Small_Gap_ms                549.07
# Time_Length_of_File_ms                                   553.06
# Time_Length_of_File_s                                     0.553
# Dead_Time_Percentage                                     99.278
#
#                                                              36  \
# Filename                                   20231205_185333_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                         None
# Inter_Average_delay                                        None
# Sample_Frequency_KHz                                       1.83
# Median_Gap_us                                            534.75
# Large_Gap_Analysis_ms                                       0.7
# Count_of_Long_Gaps                                            6
# Largest_Gaps_ms                                            0.78
# Small_Gap_Analysis_ms                                       0.5
# Sum_of_Durations_Larger_than_Small_Gap_ms                186.62
# Time_Length_of_File_ms                                  187.115
# Time_Length_of_File_s                                     0.187
# Dead_Time_Percentage                                     99.733
#
#                                                              37  \
# Filename                                   20231205_185428_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                         None
# Inter_Average_delay                                        None
# Sample_Frequency_KHz                                       0.66
# Median_Gap_us                                            1462.0
# Large_Gap_Analysis_ms                                       1.8
# Count_of_Long_Gaps                                           42
# Largest_Gaps_ms                                            2.06
# Small_Gap_Analysis_ms                                       1.4
# Sum_of_Durations_Larger_than_Small_Gap_ms                1177.7
# Time_Length_of_File_ms                                 1504.423
# Time_Length_of_File_s                                     1.504
# Dead_Time_Percentage                                     78.283
#
#                                                              38  \
# Filename                                   20231205_185429_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                         None
# Inter_Average_delay                                        None
# Sample_Frequency_KHz                                       0.66
# Median_Gap_us                                            1465.5
# Large_Gap_Analysis_ms                                       1.8
# Count_of_Long_Gaps                                           54
# Largest_Gaps_ms                                             2.2
# Small_Gap_Analysis_ms                                       1.4
# Sum_of_Durations_Larger_than_Small_Gap_ms                1197.9
# Time_Length_of_File_ms                                 1511.979
# Time_Length_of_File_s                                     1.512
# Dead_Time_Percentage                                     79.227
#
#                                                              39  \
# Filename                                   20231205_185431_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                         None
# Inter_Average_delay                                        None
# Sample_Frequency_KHz                                       0.67
# Median_Gap_us                                            1465.5
# Large_Gap_Analysis_ms                                       1.8
# Count_of_Long_Gaps                                           23
# Largest_Gaps_ms                                            2.08
# Small_Gap_Analysis_ms                                       1.4
# Sum_of_Durations_Larger_than_Small_Gap_ms               1224.96
# Time_Length_of_File_ms                                 1501.224
# Time_Length_of_File_s                                     1.501
# Dead_Time_Percentage                                     81.597
#
#                                                              40  \
# Filename                                   20231205_185432_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                         None
# Inter_Average_delay                                        None
# Sample_Frequency_KHz                                       0.67
# Median_Gap_us                                            1438.5
# Large_Gap_Analysis_ms                                       1.8
# Count_of_Long_Gaps                                           22
# Largest_Gaps_ms                                            2.09
# Small_Gap_Analysis_ms                                       1.4
# Sum_of_Durations_Larger_than_Small_Gap_ms               1127.39
# Time_Length_of_File_ms                                 1482.858
# Time_Length_of_File_s                                     1.483
# Dead_Time_Percentage                                     76.028
#
#                                                              41  \
# Filename                                   20231205_185434_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                         None
# Inter_Average_delay                                        None
# Sample_Frequency_KHz                                       0.67
# Median_Gap_us                                            1458.0
# Large_Gap_Analysis_ms                                       1.8
# Count_of_Long_Gaps                                           50
# Largest_Gaps_ms                                            2.16
# Small_Gap_Analysis_ms                                       1.4
# Sum_of_Durations_Larger_than_Small_Gap_ms               1212.38
# Time_Length_of_File_ms                                 1500.844
# Time_Length_of_File_s                                     1.501
# Dead_Time_Percentage                                      80.78
#
#                                                              42  \
# Filename                                   20231205_185435_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                         None
# Inter_Average_delay                                        None
# Sample_Frequency_KHz                                       0.67
# Median_Gap_us                                            1458.5
# Large_Gap_Analysis_ms                                       1.8
# Count_of_Long_Gaps                                           46
# Largest_Gaps_ms                                            2.09
# Small_Gap_Analysis_ms                                       1.4
# Sum_of_Durations_Larger_than_Small_Gap_ms               1132.19
# Time_Length_of_File_ms                                 1494.388
# Time_Length_of_File_s                                     1.494
# Dead_Time_Percentage                                     75.763
#
#                                                              43
# Filename                                   20231205_185437_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                         None
# Inter_Average_delay                                        None
# Sample_Frequency_KHz                                       0.67
# Median_Gap_us                                            1453.5
# Large_Gap_Analysis_ms                                       1.8
# Count_of_Long_Gaps                                           15
# Largest_Gaps_ms                                            2.06
# Small_Gap_Analysis_ms                                       1.4
# Sum_of_Durations_Larger_than_Small_Gap_ms                 696.2
# Time_Length_of_File_ms                                  895.588
# Time_Length_of_File_s                                     0.896
# Dead_Time_Percentage                                     77.736
#
# [14 rows x 44 columns]
