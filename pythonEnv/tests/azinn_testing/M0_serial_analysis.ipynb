# %%
import os
import pandas as pd
from analysis_plotter_serial import analyze, quickLook

directory_path = 'data_M0/50_50_4/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                              inter_sample_delay=50,
                              inter_average_delay=50,
                              samples_to_av=4, 
                              gap_sizeL_us=1100, 
                              gap_sizeS_us=800)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_50_50_4 = pd.DataFrame(all_dictionaries).transpose()
df_M0_50_50_4
# Out:
#                                                               0  \
# Filename                                   20231205_174514_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Sample_Frequency_KHz                                       1.18
# Median_Gap_us                                            843.25
# Large_Gap_Analysis_ms                                       1.1
# Count_of_Long_Gaps                                           10
# Largest_Gaps_ms                                            1.25
# Small_Gap_Analysis_ms                                       0.8
# Sum_of_Durations_Larger_than_Small_Gap_ms                 736.3
# Time_Length_of_File_ms                                  849.037
# Time_Length_of_File_s                                     0.849
# Dead_Time_Percentage                                     86.722
#
#                                                               1  \
# Filename                                   20231205_174515_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Sample_Frequency_KHz                                       1.18
# Median_Gap_us                                             839.5
# Large_Gap_Analysis_ms                                       1.1
# Count_of_Long_Gaps                                           15
# Largest_Gaps_ms                                            1.33
# Small_Gap_Analysis_ms                                       0.8
# Sum_of_Durations_Larger_than_Small_Gap_ms                691.41
# Time_Length_of_File_ms                                  850.393
# Time_Length_of_File_s                                      0.85
# Dead_Time_Percentage                                     81.305
#
#                                                               2  \
# Filename                                   20231205_174516_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Sample_Frequency_KHz                                       1.19
# Median_Gap_us                                             838.5
# Large_Gap_Analysis_ms                                       1.1
# Count_of_Long_Gaps                                            5
# Largest_Gaps_ms                                            1.26
# Small_Gap_Analysis_ms                                       0.8
# Sum_of_Durations_Larger_than_Small_Gap_ms                732.74
# Time_Length_of_File_ms                                  842.694
# Time_Length_of_File_s                                     0.843
# Dead_Time_Percentage                                     86.952
#
#                                                               3  \
# Filename                                   20231205_174517_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Sample_Frequency_KHz                                       1.17
# Median_Gap_us                                             840.0
# Large_Gap_Analysis_ms                                       1.1
# Count_of_Long_Gaps                                           24
# Largest_Gaps_ms                                            1.43
# Small_Gap_Analysis_ms                                       0.8
# Sum_of_Durations_Larger_than_Small_Gap_ms                723.54
# Time_Length_of_File_ms                                  853.236
# Time_Length_of_File_s                                     0.853
# Dead_Time_Percentage                                     84.799
#
#                                                               4  \
# Filename                                   20231205_174518_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Sample_Frequency_KHz                                       1.17
# Median_Gap_us                                             841.0
# Large_Gap_Analysis_ms                                       1.1
# Count_of_Long_Gaps                                           17
# Largest_Gaps_ms                                            1.26
# Small_Gap_Analysis_ms                                       0.8
# Sum_of_Durations_Larger_than_Small_Gap_ms                699.66
# Time_Length_of_File_ms                                  851.588
# Time_Length_of_File_s                                     0.852
# Dead_Time_Percentage                                      82.16
#
#                                                               5  \
# Filename                                   20231205_174519_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Sample_Frequency_KHz                                       1.16
# Median_Gap_us                                             840.5
# Large_Gap_Analysis_ms                                       1.1
# Count_of_Long_Gaps                                           34
# Largest_Gaps_ms                                            1.62
# Small_Gap_Analysis_ms                                       0.8
# Sum_of_Durations_Larger_than_Small_Gap_ms                 700.2
# Time_Length_of_File_ms                                  860.479
# Time_Length_of_File_s                                      0.86
# Dead_Time_Percentage                                     81.373
#
#                                                               6  \
# Filename                                   20231205_174520_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Sample_Frequency_KHz                                       1.18
# Median_Gap_us                                             837.5
# Large_Gap_Analysis_ms                                       1.1
# Count_of_Long_Gaps                                           16
# Largest_Gaps_ms                                            1.25
# Small_Gap_Analysis_ms                                       0.8
# Sum_of_Durations_Larger_than_Small_Gap_ms                678.83
# Time_Length_of_File_ms                                   844.95
# Time_Length_of_File_s                                     0.845
# Dead_Time_Percentage                                      80.34
#
#                                                               7  \
# Filename                                   20231205_174521_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Sample_Frequency_KHz                                        1.2
# Median_Gap_us                                             832.5
# Large_Gap_Analysis_ms                                       1.1
# Count_of_Long_Gaps                                            1
# Largest_Gaps_ms                                            1.15
# Small_Gap_Analysis_ms                                       0.8
# Sum_of_Durations_Larger_than_Small_Gap_ms                660.28
# Time_Length_of_File_ms                                  835.592
# Time_Length_of_File_s                                     0.836
# Dead_Time_Percentage                                     79.019
#
#                                                               8
# Filename                                   20231205_174522_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Sample_Frequency_KHz                                       1.17
# Median_Gap_us                                             840.0
# Large_Gap_Analysis_ms                                       1.1
# Count_of_Long_Gaps                                            8
# Largest_Gaps_ms                                            1.32
# Small_Gap_Analysis_ms                                       0.8
# Sum_of_Durations_Larger_than_Small_Gap_ms                276.88
# Time_Length_of_File_ms                                  344.527
# Time_Length_of_File_s                                     0.345
# Dead_Time_Percentage                                     80.365

# %%
import os
import pandas as pd
from analysis_plotter_serial import analyze, quickLook

directory_path = 'data_M0/50_500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                              inter_sample_delay=50,
                              inter_average_delay=500,
                              samples_to_av=20, 
                              gap_sizeL_us=3000, 
                              gap_sizeS_us=3000)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_50_500_20 = pd.DataFrame(all_dictionaries).transpose()
df_M0_50_500_20
# Out:
#                                                               0  \
# Filename                                   20231205_174832_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                         500
# Sample_Frequency_KHz                                       0.33
# Median_Gap_us                                            3037.0
# Large_Gap_Analysis_ms                                       3.0
# Count_of_Long_Gaps                                          588
# Largest_Gaps_ms                                            3.79
# Small_Gap_Analysis_ms                                       3.0
# Sum_of_Durations_Larger_than_Small_Gap_ms               1864.24
# Time_Length_of_File_ms                                 3045.826
# Time_Length_of_File_s                                     3.046
# Dead_Time_Percentage                                     61.206
#
#                                                               1  \
# Filename                                   20231205_174835_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                         500
# Sample_Frequency_KHz                                       0.32
# Median_Gap_us                                            3085.5
# Large_Gap_Analysis_ms                                       3.0
# Count_of_Long_Gaps                                          653
# Largest_Gaps_ms                                            3.66
# Small_Gap_Analysis_ms                                       3.0
# Sum_of_Durations_Larger_than_Small_Gap_ms               2086.07
# Time_Length_of_File_ms                                 3090.153
# Time_Length_of_File_s                                      3.09
# Dead_Time_Percentage                                     67.507
#
#                                                               2  \
# Filename                                   20231205_174838_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                         500
# Sample_Frequency_KHz                                       0.32
# Median_Gap_us                                            3091.5
# Large_Gap_Analysis_ms                                       3.0
# Count_of_Long_Gaps                                          698
# Largest_Gaps_ms                                             3.7
# Small_Gap_Analysis_ms                                       3.0
# Sum_of_Durations_Larger_than_Small_Gap_ms               2221.73
# Time_Length_of_File_ms                                 3095.944
# Time_Length_of_File_s                                     3.096
# Dead_Time_Percentage                                     71.763
#
#                                                               3  \
# Filename                                   20231205_174842_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                         500
# Sample_Frequency_KHz                                       0.32
# Median_Gap_us                                            3101.0
# Large_Gap_Analysis_ms                                       3.0
# Count_of_Long_Gaps                                          670
# Largest_Gaps_ms                                            3.67
# Small_Gap_Analysis_ms                                       3.0
# Sum_of_Durations_Larger_than_Small_Gap_ms               2141.77
# Time_Length_of_File_ms                                 3087.174
# Time_Length_of_File_s                                     3.087
# Dead_Time_Percentage                                     69.376
#
#                                                               4  \
# Filename                                   20231205_174845_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                         500
# Sample_Frequency_KHz                                       0.32
# Median_Gap_us                                            3080.5
# Large_Gap_Analysis_ms                                       3.0
# Count_of_Long_Gaps                                          640
# Largest_Gaps_ms                                            3.78
# Small_Gap_Analysis_ms                                       3.0
# Sum_of_Durations_Larger_than_Small_Gap_ms               2041.77
# Time_Length_of_File_ms                                 3078.378
# Time_Length_of_File_s                                     3.078
# Dead_Time_Percentage                                     66.326
#
#                                                               5  \
# Filename                                   20231205_174848_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                         500
# Sample_Frequency_KHz                                       0.32
# Median_Gap_us                                            3101.0
# Large_Gap_Analysis_ms                                       3.0
# Count_of_Long_Gaps                                          675
# Largest_Gaps_ms                                            3.62
# Small_Gap_Analysis_ms                                       3.0
# Sum_of_Durations_Larger_than_Small_Gap_ms               2161.45
# Time_Length_of_File_ms                                 3096.356
# Time_Length_of_File_s                                     3.096
# Dead_Time_Percentage                                     69.806
#
#                                                               6  \
# Filename                                   20231205_174851_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                         500
# Sample_Frequency_KHz                                       0.32
# Median_Gap_us                                            3105.5
# Large_Gap_Analysis_ms                                       3.0
# Count_of_Long_Gaps                                          674
# Largest_Gaps_ms                                            3.67
# Small_Gap_Analysis_ms                                       3.0
# Sum_of_Durations_Larger_than_Small_Gap_ms                2166.3
# Time_Length_of_File_ms                                 3105.834
# Time_Length_of_File_s                                     3.106
# Dead_Time_Percentage                                     69.749
#
#                                                               7
# Filename                                   20231205_174854_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                         500
# Sample_Frequency_KHz                                       0.32
# Median_Gap_us                                            3120.0
# Large_Gap_Analysis_ms                                       3.0
# Count_of_Long_Gaps                                          567
# Largest_Gaps_ms                                            3.68
# Small_Gap_Analysis_ms                                       3.0
# Sum_of_Durations_Larger_than_Small_Gap_ms               1817.94
# Time_Length_of_File_ms                                  2463.33
# Time_Length_of_File_s                                     2.463
# Dead_Time_Percentage                                       73.8

# %%
import os
import pandas as pd
from analysis_plotter_serial import analyze, quickLook

directory_path = 'data_M0/50_1500_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                              inter_sample_delay=50,
                              inter_average_delay=1500,
                              samples_to_av=20, 
                              gap_sizeL_us=4500, 
                              gap_sizeS_us=4000)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_M0_50_1500_20 = pd.DataFrame(all_dictionaries).transpose()
df_M0_50_1500_20
# Out:
#                                                               0  \
# Filename                                   20231205_174211_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Sample_Frequency_KHz                                       0.24
# Median_Gap_us                                            4164.0
# Large_Gap_Analysis_ms                                       4.5
# Count_of_Long_Gaps                                           38
# Largest_Gaps_ms                                            4.78
# Small_Gap_Analysis_ms                                       4.0
# Sum_of_Durations_Larger_than_Small_Gap_ms               3388.71
# Time_Length_of_File_ms                                 4168.188
# Time_Length_of_File_s                                     4.168
# Dead_Time_Percentage                                     81.299
#
#                                                               1  \
# Filename                                   20231205_174215_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Sample_Frequency_KHz                                       0.24
# Median_Gap_us                                            4166.0
# Large_Gap_Analysis_ms                                       4.5
# Count_of_Long_Gaps                                           53
# Largest_Gaps_ms                                            4.75
# Small_Gap_Analysis_ms                                       4.0
# Sum_of_Durations_Larger_than_Small_Gap_ms                3237.9
# Time_Length_of_File_ms                                 4162.719
# Time_Length_of_File_s                                     4.163
# Dead_Time_Percentage                                     77.783
#
#                                                               2  \
# Filename                                   20231205_174219_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Sample_Frequency_KHz                                       0.24
# Median_Gap_us                                            4154.5
# Large_Gap_Analysis_ms                                       4.5
# Count_of_Long_Gaps                                           37
# Largest_Gaps_ms                                            4.72
# Small_Gap_Analysis_ms                                       4.0
# Sum_of_Durations_Larger_than_Small_Gap_ms               3294.73
# Time_Length_of_File_ms                                  4152.08
# Time_Length_of_File_s                                     4.152
# Dead_Time_Percentage                                     79.351
#
#                                                               3  \
# Filename                                   20231205_174224_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Sample_Frequency_KHz                                       0.24
# Median_Gap_us                                            4171.5
# Large_Gap_Analysis_ms                                       4.5
# Count_of_Long_Gaps                                           40
# Largest_Gaps_ms                                            4.73
# Small_Gap_Analysis_ms                                       4.0
# Sum_of_Durations_Larger_than_Small_Gap_ms               3333.25
# Time_Length_of_File_ms                                 4162.269
# Time_Length_of_File_s                                     4.162
# Dead_Time_Percentage                                     80.082
#
#                                                               4
# Filename                                   20231205_174228_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                           50
# Inter_Average_delay                                        1500
# Sample_Frequency_KHz                                       0.24
# Median_Gap_us                                           4161.75
# Large_Gap_Analysis_ms                                       4.5
# Count_of_Long_Gaps                                           27
# Largest_Gaps_ms                                            4.63
# Small_Gap_Analysis_ms                                       4.0
# Sum_of_Durations_Larger_than_Small_Gap_ms               2240.61
# Time_Length_of_File_ms                                 2887.582
# Time_Length_of_File_s                                     2.888
# Dead_Time_Percentage                                     77.595

# %%
import os
import pandas as pd
from analysis_plotter_serial import analyze, quickLook

directory_path = 'data_M0/no_inter_2/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                              inter_sample_delay=None,
                              inter_average_delay=None,
                              samples_to_av=2, 
                              gap_sizeL_us=700, 
                              gap_sizeS_us=450)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_no_inter_2 = pd.DataFrame(all_dictionaries).transpose()
# df_no_inter_2

# %%
import os
import pandas as pd
from analysis_plotter_serial import analyze, quickLook

directory_path = 'data_M0/no_inter_4/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                              inter_sample_delay=None,
                              inter_average_delay=None,
                              samples_to_av=4, 
                              gap_sizeL_us=700, 
                              gap_sizeS_us=500)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_no_inter_4 = pd.DataFrame(all_dictionaries).transpose()
# df_no_inter_4

# %%
import os
import pandas as pd
from analysis_plotter_serial import analyze, quickLook

directory_path = 'data_M0/no_inter_20/'
# Initialize an empty list to store dictionaries for each file
all_dictionaries = []

for filename in os.listdir(directory_path):
    root, extension = os.path.splitext(filename)
    if extension.lower() == ".txt":
        file_path = os.path.join(directory_path, filename)

        # Apply analyze function and get the resulting dictionary
        result_dict = analyze(file_path,prints=False,
                              inter_sample_delay=None,
                              inter_average_delay=None,
                              samples_to_av=20, 
                              gap_sizeL_us=1500, 
                              gap_sizeS_us=1200)
        # quickLook(file_path)

        # Add a key-value pair for the filename in the dictionary
        result_dict['Filename'] = filename
        # Move File name to 1st entry
        result_dict = {'Filename': filename, **result_dict}

        # Append the modified dictionary to the list
        all_dictionaries.append(result_dict)

# Create a DataFrame directly from the list of dictionaries
df_no_inter_20 = pd.DataFrame(all_dictionaries).transpose()
# df_no_inter_20

# %%
result = pd.concat([df_M0_50_50_4,df_M0_50_500_20,df_M0_50_1500_20,df_no_inter_2,df_no_inter_4,df_no_inter_20], axis=1, ignore_index=True)

result
# Out:
#                                                              0   \
# Filename                                   20231205_174514_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Sample_Frequency_KHz                                       1.18
# Median_Gap_us                                            843.25
# Large_Gap_Analysis_ms                                       1.1
# Count_of_Long_Gaps                                           10
# Largest_Gaps_ms                                            1.25
# Small_Gap_Analysis_ms                                       0.8
# Sum_of_Durations_Larger_than_Small_Gap_ms                 736.3
# Time_Length_of_File_ms                                  849.037
# Time_Length_of_File_s                                     0.849
# Dead_Time_Percentage                                     86.722
#
#                                                              1   \
# Filename                                   20231205_174515_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Sample_Frequency_KHz                                       1.18
# Median_Gap_us                                             839.5
# Large_Gap_Analysis_ms                                       1.1
# Count_of_Long_Gaps                                           15
# Largest_Gaps_ms                                            1.33
# Small_Gap_Analysis_ms                                       0.8
# Sum_of_Durations_Larger_than_Small_Gap_ms                691.41
# Time_Length_of_File_ms                                  850.393
# Time_Length_of_File_s                                      0.85
# Dead_Time_Percentage                                     81.305
#
#                                                              2   \
# Filename                                   20231205_174516_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Sample_Frequency_KHz                                       1.19
# Median_Gap_us                                             838.5
# Large_Gap_Analysis_ms                                       1.1
# Count_of_Long_Gaps                                            5
# Largest_Gaps_ms                                            1.26
# Small_Gap_Analysis_ms                                       0.8
# Sum_of_Durations_Larger_than_Small_Gap_ms                732.74
# Time_Length_of_File_ms                                  842.694
# Time_Length_of_File_s                                     0.843
# Dead_Time_Percentage                                     86.952
#
#                                                              3   \
# Filename                                   20231205_174517_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Sample_Frequency_KHz                                       1.17
# Median_Gap_us                                             840.0
# Large_Gap_Analysis_ms                                       1.1
# Count_of_Long_Gaps                                           24
# Largest_Gaps_ms                                            1.43
# Small_Gap_Analysis_ms                                       0.8
# Sum_of_Durations_Larger_than_Small_Gap_ms                723.54
# Time_Length_of_File_ms                                  853.236
# Time_Length_of_File_s                                     0.853
# Dead_Time_Percentage                                     84.799
#
#                                                              4   \
# Filename                                   20231205_174518_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Sample_Frequency_KHz                                       1.17
# Median_Gap_us                                             841.0
# Large_Gap_Analysis_ms                                       1.1
# Count_of_Long_Gaps                                           17
# Largest_Gaps_ms                                            1.26
# Small_Gap_Analysis_ms                                       0.8
# Sum_of_Durations_Larger_than_Small_Gap_ms                699.66
# Time_Length_of_File_ms                                  851.588
# Time_Length_of_File_s                                     0.852
# Dead_Time_Percentage                                      82.16
#
#                                                              5   \
# Filename                                   20231205_174519_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Sample_Frequency_KHz                                       1.16
# Median_Gap_us                                             840.5
# Large_Gap_Analysis_ms                                       1.1
# Count_of_Long_Gaps                                           34
# Largest_Gaps_ms                                            1.62
# Small_Gap_Analysis_ms                                       0.8
# Sum_of_Durations_Larger_than_Small_Gap_ms                 700.2
# Time_Length_of_File_ms                                  860.479
# Time_Length_of_File_s                                      0.86
# Dead_Time_Percentage                                     81.373
#
#                                                              6   \
# Filename                                   20231205_174520_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Sample_Frequency_KHz                                       1.18
# Median_Gap_us                                             837.5
# Large_Gap_Analysis_ms                                       1.1
# Count_of_Long_Gaps                                           16
# Largest_Gaps_ms                                            1.25
# Small_Gap_Analysis_ms                                       0.8
# Sum_of_Durations_Larger_than_Small_Gap_ms                678.83
# Time_Length_of_File_ms                                   844.95
# Time_Length_of_File_s                                     0.845
# Dead_Time_Percentage                                      80.34
#
#                                                              7   \
# Filename                                   20231205_174521_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Sample_Frequency_KHz                                        1.2
# Median_Gap_us                                             832.5
# Large_Gap_Analysis_ms                                       1.1
# Count_of_Long_Gaps                                            1
# Largest_Gaps_ms                                            1.15
# Small_Gap_Analysis_ms                                       0.8
# Sum_of_Durations_Larger_than_Small_Gap_ms                660.28
# Time_Length_of_File_ms                                  835.592
# Time_Length_of_File_s                                     0.836
# Dead_Time_Percentage                                     79.019
#
#                                                              8   \
# Filename                                   20231205_174522_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                           50
# Inter_Average_delay                                          50
# Sample_Frequency_KHz                                       1.17
# Median_Gap_us                                             840.0
# Large_Gap_Analysis_ms                                       1.1
# Count_of_Long_Gaps                                            8
# Largest_Gaps_ms                                            1.32
# Small_Gap_Analysis_ms                                       0.8
# Sum_of_Durations_Larger_than_Small_Gap_ms                276.88
# Time_Length_of_File_ms                                  344.527
# Time_Length_of_File_s                                     0.345
# Dead_Time_Percentage                                     80.365
#
#                                                              9   ...  \
# Filename                                   20231205_174832_.txt  ...
# Samples_Averaged                                             20  ...
# Inter_Sample_delay                                           50  ...
# Inter_Average_delay                                         500  ...
# Sample_Frequency_KHz                                       0.33  ...
# Median_Gap_us                                            3037.0  ...
# Large_Gap_Analysis_ms                                       3.0  ...
# Count_of_Long_Gaps                                          588  ...
# Largest_Gaps_ms                                            3.79  ...
# Small_Gap_Analysis_ms                                       3.0  ...
# Sum_of_Durations_Larger_than_Small_Gap_ms               1864.24  ...
# Time_Length_of_File_ms                                 3045.826  ...
# Time_Length_of_File_s                                     3.046  ...
# Dead_Time_Percentage                                     61.206  ...
#
#                                                              35  \
# Filename                                   20231205_175405_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                         None
# Inter_Average_delay                                        None
# Sample_Frequency_KHz                                       1.83
# Median_Gap_us                                             541.0
# Large_Gap_Analysis_ms                                       0.7
# Count_of_Long_Gaps                                            3
# Largest_Gaps_ms                                            0.72
# Small_Gap_Analysis_ms                                       0.5
# Sum_of_Durations_Larger_than_Small_Gap_ms                 540.5
# Time_Length_of_File_ms                                  546.482
# Time_Length_of_File_s                                     0.546
# Dead_Time_Percentage                                     98.905
#
#                                                              36  \
# Filename                                   20231205_175406_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                         None
# Inter_Average_delay                                        None
# Sample_Frequency_KHz                                        1.8
# Median_Gap_us                                             542.0
# Large_Gap_Analysis_ms                                       0.7
# Count_of_Long_Gaps                                           27
# Largest_Gaps_ms                                            0.83
# Small_Gap_Analysis_ms                                       0.5
# Sum_of_Durations_Larger_than_Small_Gap_ms                549.86
# Time_Length_of_File_ms                                   554.35
# Time_Length_of_File_s                                     0.554
# Dead_Time_Percentage                                      99.19
#
#                                                              37  \
# Filename                                   20231205_175407_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                         None
# Inter_Average_delay                                        None
# Sample_Frequency_KHz                                        1.8
# Median_Gap_us                                             542.0
# Large_Gap_Analysis_ms                                       0.7
# Count_of_Long_Gaps                                           32
# Largest_Gaps_ms                                            1.04
# Small_Gap_Analysis_ms                                       0.5
# Sum_of_Durations_Larger_than_Small_Gap_ms                553.71
# Time_Length_of_File_ms                                  555.701
# Time_Length_of_File_s                                     0.556
# Dead_Time_Percentage                                     99.641
#
#                                                              38  \
# Filename                                   20231205_175408_.txt
# Samples_Averaged                                              4
# Inter_Sample_delay                                         None
# Inter_Average_delay                                        None
# Sample_Frequency_KHz                                       1.86
# Median_Gap_us                                             527.0
# Large_Gap_Analysis_ms                                       0.7
# Count_of_Long_Gaps                                            3
# Largest_Gaps_ms                                            0.73
# Small_Gap_Analysis_ms                                       0.5
# Sum_of_Durations_Larger_than_Small_Gap_ms                 48.07
# Time_Length_of_File_ms                                   49.566
# Time_Length_of_File_s                                      0.05
# Dead_Time_Percentage                                     96.983
#
#                                                              39  \
# Filename                                   20231205_175457_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                         None
# Inter_Average_delay                                        None
# Sample_Frequency_KHz                                       0.76
# Median_Gap_us                                            1272.0
# Large_Gap_Analysis_ms                                       1.5
# Count_of_Long_Gaps                                          101
# Largest_Gaps_ms                                            1.85
# Small_Gap_Analysis_ms                                       1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms               1259.78
# Time_Length_of_File_ms                                 1317.036
# Time_Length_of_File_s                                     1.317
# Dead_Time_Percentage                                     95.653
#
#                                                              40  \
# Filename                                   20231205_175459_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                         None
# Inter_Average_delay                                        None
# Sample_Frequency_KHz                                       0.76
# Median_Gap_us                                            1274.0
# Large_Gap_Analysis_ms                                       1.5
# Count_of_Long_Gaps                                           75
# Largest_Gaps_ms                                            1.82
# Small_Gap_Analysis_ms                                       1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms                1250.1
# Time_Length_of_File_ms                                 1310.693
# Time_Length_of_File_s                                     1.311
# Dead_Time_Percentage                                     95.377
#
#                                                              41  \
# Filename                                   20231205_175500_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                         None
# Inter_Average_delay                                        None
# Sample_Frequency_KHz                                       0.77
# Median_Gap_us                                            1265.0
# Large_Gap_Analysis_ms                                       1.5
# Count_of_Long_Gaps                                           83
# Largest_Gaps_ms                                             1.9
# Small_Gap_Analysis_ms                                       1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms                1241.9
# Time_Length_of_File_ms                                 1304.995
# Time_Length_of_File_s                                     1.305
# Dead_Time_Percentage                                     95.165
#
#                                                              42  \
# Filename                                   20231205_175501_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                         None
# Inter_Average_delay                                        None
# Sample_Frequency_KHz                                       0.76
# Median_Gap_us                                            1271.5
# Large_Gap_Analysis_ms                                       1.5
# Count_of_Long_Gaps                                           90
# Largest_Gaps_ms                                            1.87
# Small_Gap_Analysis_ms                                       1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms               1275.72
# Time_Length_of_File_ms                                  1311.53
# Time_Length_of_File_s                                     1.312
# Dead_Time_Percentage                                      97.27
#
#                                                              43  \
# Filename                                   20231205_175503_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                         None
# Inter_Average_delay                                        None
# Sample_Frequency_KHz                                       0.79
# Median_Gap_us                                            1255.0
# Large_Gap_Analysis_ms                                       1.5
# Count_of_Long_Gaps                                           29
# Largest_Gaps_ms                                            1.83
# Small_Gap_Analysis_ms                                       1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms               1204.83
# Time_Length_of_File_ms                                 1271.637
# Time_Length_of_File_s                                     1.272
# Dead_Time_Percentage                                     94.746
#
#                                                              44
# Filename                                   20231205_175504_.txt
# Samples_Averaged                                             20
# Inter_Sample_delay                                         None
# Inter_Average_delay                                        None
# Sample_Frequency_KHz                                       0.77
# Median_Gap_us                                            1268.5
# Large_Gap_Analysis_ms                                       1.5
# Count_of_Long_Gaps                                           48
# Largest_Gaps_ms                                            1.82
# Small_Gap_Analysis_ms                                       1.2
# Sum_of_Durations_Larger_than_Small_Gap_ms                986.29
# Time_Length_of_File_ms                                  1012.56
# Time_Length_of_File_s                                     1.013
# Dead_Time_Percentage                                     97.406
#
# [14 rows x 45 columns]
