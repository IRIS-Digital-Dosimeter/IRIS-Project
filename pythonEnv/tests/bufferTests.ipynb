# %%
#import matplotlib
#matplotlib.use('TKAgg',force=True)

import matplotlib.pyplot as plt
import numpy as np
import pdb 
# %matplotlib widget 
# %matplotlib ipympl 
# %matplotlib nbagg 
# %matplotlib notebook 
# %matplotlib inline
# %matplotlib qt 
# %pylab qt
# %matplotlib

def quicklook(infile):
    #read data from file which is the input argument
    
    t,v = np.loadtxt(infile,unpack=True,delimiter=',')
    # t,v = np.loadtxt(infile,skiprows=3,unpack=True,delimiter=',')
    t = t - t[0]
    v = v*(3.3/4096)
    #Make a list of the time differences (gaps) beween adjacent points:
    dt = t - np.roll(t,1)
    dt = dt[1:]
    print('Median gap us: ',np.median(dt))
    h,tax = np.histogram(dt,range=[0,max(dt)],bins=int(max(dt)/100.))

    #print the times, durations,  and positions of the longest gaps:
    w = np.where(dt > 50000.)
    w=w[0]
    # print('Locations of long gaps: ',w)
    print('Times of long gaps s: ',t[w]/10e6)
    print('Durations of long gaps ms: ',dt[w]/1e3)
    print('Count of long gaps ms: ',len(dt[w]))
    print('Largest gaps ms: ',max(dt[w])/1e3)
    print('num of points:', len(v))


    #plot dataset
    plt.figure(num=None,figsize=(25,25) )
    fig, axs = plt.subplots(2)
    fig.tight_layout()
    fig.suptitle(infile)
    fig.subplots_adjust(top=.9)

    ts = t/1e6
    axs[0].scatter(ts,v,s=4)
    axs[0].plot(ts,v,alpha=0.5)
    axs[0].set_xlabel('time, seconds')
    axs[0].set_ylabel('Volts')
    #axs[0].set_xlim([min(ts),min(ts)+40])

    #plot histogram of gaps in milliseconds:
    axs[1].plot(tax[1:]/1e3,h,alpha=0.5)
    axs[1].scatter(tax[1:]/1e3,h,s=4)
    axs[1].set_yscale('log')
    axs[1].set_xlabel('Gap, milliseconds')
    plt.show()




# quicklook("data2/16010001.TXT") 
# quicklook("data2/16010002.TXT") 
# quicklook("data2/16010003.TXT") 
# quicklook("data2/16020001.TXT") 
# print('')
# quicklook("data2/16020002.TXT") 
# print('')
# quicklook("data2/16020003.TXT") 
# quicklook("data2/16030001.TXT") 
# print('')
# quicklook("data2/16030002.TXT") 
quicklook("data2/16040001.TXT") 
print('')
quicklook("data2/16040002.TXT") 
print('')
quicklook("data2/16050001.TXT") 
print('')
quicklook("data2/16050002.TXT")
# Out:
# Median gap us:  36.0
# Times of long gaps s:  [0.0009957 0.0127655 0.0554386 0.1100751 0.1222279 0.1347486 0.1527662
#  0.1587862 0.1648019 0.1769738 0.2853463 0.3218255 0.3338491 0.3698681
#  0.4125021 0.4186711 0.4301702 0.4407891 0.4630178 0.4751927]
# Durations of long gaps ms:  [ 97.124  52.349  51.624  51.631  50.128  50.044  50.05   50.035  51.64
#   51.592  50.005  50.036  50.052  51.695  51.57   50.053 101.212 152.396
#   51.532  50.026]
# Count of long gaps ms:  20
# Largest gaps ms:  152.396
# num of points: 22845
# Median gap us:  36.0
# Times of long gaps s:  [0.0004975 0.0362419 0.0424253 0.1504909 0.1691902 0.1753675 0.1815606
#  0.3494444 0.4279103 0.4340851 0.4641344]
# Durations of long gaps ms:  [102.027  51.715  51.838  51.761  51.655  51.808  51.762  51.552  51.624
#   51.36  251.141]
# Count of long gaps ms:  11
# Largest gaps ms:  251.141
# num of points: 22987
# Median gap us:  66.0
# Times of long gaps s:  [0.0010014 0.0287581 0.090497  0.2137478 0.3106933 0.4000335 0.4414585
#  0.4619961]
# Durations of long gaps ms:  [52.482 51.21  51.568 52.522 51.211 50.996 50.919 50.927]
# Count of long gaps ms:  8
# Largest gaps ms:  52.522
# num of points: 21004
# Median gap us:  66.0
# Times of long gaps s:  [0.0004991 0.0068135 0.0139339 0.0344793 0.0485899 0.0867523 0.0974238
#  0.227122  0.2891534 0.4466918]
# Durations of long gaps ms:  [ 53.057  50.823  50.986  50.941  51.529 101.72   53.132  51.074  51.224
#   51.291]
# Count of long gaps ms:  10
# Largest gaps ms:  101.72
# num of points: 20156
